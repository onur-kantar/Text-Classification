# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import nltk
from sklearn.preprocessing import LabelBinarizer
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from wordcloud import WordCloud,STOPWORDS
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize,sent_tokenize
from bs4 import BeautifulSoup
import re,string,unicodedata
from keras.preprocessing import text, sequence
from nltk.tokenize.toktok import ToktokTokenizer
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
from sklearn.model_selection import train_test_split
from string import punctuation
from nltk import pos_tag
from nltk.corpus import wordnet
import keras
from keras.models import Sequential
from keras.layers import Dense,Embedding,LSTM,Dropout
import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv("3000tweet/3000tweet.csv", sep=';',encoding="utf8")

# %%
df['tweet'] = df['tweet'].str.lower()

# %%
df.isna().sum() # Checking for NaN values
# Out:
# tweet    1
# durum    0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum() # Checking for NaN values
# Out:
# tweet    0
# durum    0
# dtype: int64

# %%
df.head()
# Out:
#                                                tweet  durum
# 0  dun turkcelle tepkilerimizden sonra bugün turk...      1
# 1  girmezmiyim.. turkcell kartim bile var.. yarin...      1
# 2  tam tünelden gecerken 3g cekiyordu :d türkcell...      1
# 3  turkcell superonline fiber internet veya adsl ...      1
# 4  bence gnçtrkcll ark winterfest 2012'de 1.olur ...      1

# %%
sns.set_style("dark")
sns.countplot(df.durum)

# %%
#import nltk
#nltk.download('stopwords')

# %%
# C:\Users\onurk\AppData\Roaming\nltk_data\corpora\stopwords
stop = set(stopwords.words('turkish'))
punctuation = list(string.punctuation)
stop.update(punctuation)

# %%
#BASIC DATA CLEANING

# %%
def strip_html(text):
    soup = BeautifulSoup(text, "html.parser")
    return soup.get_text()

#Removing the square brackets
def remove_between_square_brackets(text):
    return re.sub('\[[^]]*\]', '', text)

# Removing URL's
def remove_between_square_brackets(text):
    return re.sub(r'http\S+', '', text)

#Removing the stopwords from text
def remove_stopwords(text):
    final_text = []
    for i in text.split():
        if i.strip().lower() not in stop:
            final_text.append(i.strip())
    return " ".join(final_text)

#Removing the noisy text
def denoise_text(text):
    text = strip_html(text)
    text = remove_between_square_brackets(text)
    text = remove_stopwords(text)
    return text

#Apply function on review column
df['tweet']=df['tweet'].apply(denoise_text)

# %%
plt.figure(figsize = (20,20)) # Text that is Not Sarcastic
wc = WordCloud(max_words = 2000 , width = 1600 , height = 800).generate(" ".join(df[df.durum == 1].tweet))
plt.imshow(wc , interpolation = 'bilinear')

# %%
plt.figure(figsize = (20,20)) # Text that is Not Sarcastic
wc = WordCloud(max_words = 2000 , width = 1600 , height = 800).generate(" ".join(df[df.durum == 2].tweet))
plt.imshow(wc , interpolation = 'bilinear')

# %%
plt.figure(figsize = (20,20)) # Text that is Not Sarcastic
wc = WordCloud(max_words = 2000 , width = 1600 , height = 800).generate(" ".join(df[df.durum == 3].tweet))
plt.imshow(wc , interpolation = 'bilinear')

# %%
words = []
for i in df.tweet.values:
    l = []
    for j in i.split():
        l.extend(i.split())
        break
    words.append(l)

# %%
import gensim
#Dimension of vectors we are generating
EMBEDDING_DIM = 100

#Creating Word Vectors by Word2Vec Method (takes time...)
w2v_model = gensim.models.Word2Vec(words , size=EMBEDDING_DIM , window = 5 , min_count = 1)

# %%
words
# Out:
# [['dun',
#   'turkcelle',
#   'tepkilerimizden',
#   'sonra',
#   'bugün',
#   'turkcell',
#   'twittera',
#   'sponsor',
#   'olmuş.',
#   'tesadüf',
#   'değil',
#   'mi',
#   ':)'],
#  ['girmezmiyim..',
#   'turkcell',
#   'kartim',
#   'bile',
#   'var..',
#   'yarindan',
#   'itibaren',
#   'onu',
#   'takicam..',
#   'twittersiz',
#   'denedim',
#   'sadece',
#   '3',
#   'gun',
#   'yapabildim:)))))'],
#  ['tam',
#   'tünelden',
#   'gecerken',
#   '3g',
#   'cekiyordu',
#   ':d',
#   "türkcell'in",
#   'reklamlari',
#   "vodafone'",
#   'harekete',
#   'gecirmis',
#   'olmali:)'],
#  ['turkcell',
#   'superonline',
#   'fiber',
#   'internet',
#   'adsl',
#   'sabit',
#   'telefon',
#   'hizmetleri'],
#  ['bence',
#   'gnçtrkcll',
#   'ark',
#   'winterfest',
#   "2012'de",
#   '1.olur',
#   'gelir',
#   ':)'],
#  ['turkcell', 'sana', 'kıyak', 'geçiyor', ':d'],
#  ['turkcelle', 'bağlan', 'hayata', 'diyorum', ';)))'],
#  ['kimse',
#   'takmıyo',
#   'beni',
#   'yaaaaa,',
#   'turkcell',
#   'bana',
#   'mesaj',
#   'aaat',
#   ':d'],
#  ['turkcell',
#   'pusula',
#   'uygulaması',
#   'iphone',
#   'kullanıcıları',
#   'büyük',
#   'nimet.',
#   'oturduğum',
#   'yerden',
#   'nöbetçi',
#   'eczane',
#   'kaç',
#   'metre',
#   'ötemde',
#   'bana',
#   'söylüyor.'],
#  ['zaman',
#   'sorun',
#   'yok',
#   'bende',
#   'turkcell',
#   'iyi',
#   'bir',
#   'tarife',
#   'arıyorum',
#   'yapsam',
#   'karar',
#   'veremedim',
#   'fikir',
#   'versene:)'],
#  ['samsung',
#   'turkcell’den',
#   'kaçırılmayacak',
#   'kampanya:',
#   'samsung',
#   'an',
#   'bağlantıda',
#   'kalmanızı',
#   'sağlayan',
#   'qwerty',
#   'klavyeli',
#   '...'],
#  ['i̇novasyon', 'ödülü', "'turkcell'in"],
#  ['pazar',
#   'gunlerı',
#   'sanslı',
#   'gunummuss',
#   'turkcellılerle',
#   'bedava',
#   'konuscakmısımm',
#   'sagol',
#   'varol',
#   'turkcell',
#   '\x1a',
#   'kahrol',
#   'avea'],
#  ['büyük', 'ödül', 'turkcell', "teknoloji'ye"],
#  ['hadi',
#   'yine',
#   'süpersiniz,',
#   'iyi',
#   'sıyırdınız.',
#   'iphone',
#   '4s',
#   'olayından'],
#  ['superonline',
#   'fiber',
#   'internet',
#   'hizmeti',
#   'adresinizde',
#   'varsa',
#   'tavsiye',
#   'ederim',
#   'cok',
#   'hizli',
#   'hesapli',
#   'kesilmiyor',
#   'kimse',
#   'aramiyor',
#   'arada',
#   '++'],
#  ['kesinlikle',
#   'süperonline.hatta',
#   'tivibuyu',
#   'öneririm.gayet',
#   'güzel',
#   'imkanları',
#   'var;)'],
#  ['hayat',
#   'paylaşınca',
#   'güzel',
#   'la',
#   'la',
#   'laaa',
#   'laa',
#   'laaa',
#   'la',
#   'laaa',
#   '((:'],
#  ['özturkcell',
#   'seninle',
#   'ölmeye',
#   'geldik',
#   'özturkceeeeeellllll',
#   ':)))',
#   'hasan',
#   'doğan',
#   'spor',
#   'kompleksi)'],
#  ['eyvallah,', 'hayat', 'paylaşınca', 'güzel', ':))'],
#  ['bi',
#   'turkcell',
#   'bi',
#   'coca-cola',
#   'reklamları',
#   'beni',
#   'derinden',
#   'etkliyo',
#   'lan'],
#  ['teşekkür', 'ederim', 'selocan:))'],
#  ['akşam',
#   'turkcell',
#   'belejj',
#   'film',
#   'gecesi,yani',
#   'gnç',
#   'turkcell',
#   'şifresi',
#   'paylaşım',
#   'gecesi,',
#   'katkılarınızı',
#   'bekliorum,',
#   'sanata',
#   'sinemaya',
#   'katkı',
#   'babında',
#   ':)'],
#  ['evet',
#   'turkcell',
#   'denedim',
#   'bir',
#   'sıkıntı',
#   'çıkmadı',
#   'jb',
#   'avea',
#   'herhangi',
#   'bir',
#   'çözüm',
#   'varmı',
#   '#avea',
#   '#aveadestek'],
#  ['manga',
#   'konseri,',
#   'bugün',
#   'saat',
#   "15:00'te",
#   'canlı',
#   'yayınla',
#   'adresinde!',
#   'hayat',
#   'müziği',
#   'paylaşınca',
#   'güzel',
#   ':)'],
#  ['çakma',
#   "i̇phone4'üm",
#   'var',
#   'turkcell',
#   '1gb',
#   'tel',
#   'i̇nterneti̇m',
#   'var',
#   'sabah',
#   'akşam',
#   'buradayim',
#   'süper',
#   'li̇mi̇t',
#   'kesi̇nti̇',
#   '"sağol',
#   'çi̇n+turkcell"',
#   'emekli̇ğe',
#   'kiyak!!'],
#  [':)',
#   ':)',
#   'yanlızken',
#   'mutlu',
#   'olmuşki',
#   'seen',
#   'olasın',
#   'kendini',
#   'kandırma',
#   'bak',
#   'sertb',
#   'abla',
#   'diyo',
#   'hayat',
#   'paylaşınca',
#   'güzel'],
#  ['turkcell', 'superonline'],
#  ['turkcell', 'haydi', 'gel', 'paketi..', 'enfes..'],
#  ['photo:',
#   '”dünyaya',
#   'liderlik',
#   'eden',
#   'operatörler”den',
#   'türk',
#   'turkcell',
#   'superonline',
#   'fiber',
#   'internette',
#   'dünya',
#   'lideri...'],
#  ['turkcell', '3', 'tl', 'hediye', 'etse', 'bana', 'güzel', 'olur', '=)'],
#  ['turkcell', 'yedekleme', 'yi', 'kullanmak', 'pratik', 'olabilir'],
#  ['fiyat', 'basl', 'peki', 'cokmu', 'azmi.', 'alablrzz', 'uygunsaa'],
#  ['bugün',
#   'turkcell',
#   'tarafından',
#   'çekilişe',
#   'katıldığım',
#   'tebrik',
#   'aldım.',
#   'zaman',
#   'anladım',
#   'benim',
#   'küçük',
#   'insanlık,',
#   'büyük',
#   'bir',
#   'adım',
#   'atmışım.'],
#  ['ufunett',
#   'bastıı',
#   'yine..keşkee',
#   'turkcell',
#   'olsann..tarifeni',
#   'değiştirsene',
#   'sen',
#   'yaa..=)'],
#  ['onu',
#   'geçen',
#   'hafta',
#   'bende',
#   'yapıyordu',
#   'superonline.',
#   'an',
#   'rahat',
#   'girebiliyorum',
#   'o_o'],
#  ['arada', 'farkettim', 'turkcell', 'kullanıyor:)'],
#  ['hahaha', 'turkcell', 'beni', 'seviyo', ':)'],
#  ['dun',
#   'gecedn',
#   'beri',
#   'turkcell',
#   'mustri',
#   'hzmetlerndeki',
#   'kadinla',
#   'ask',
#   'yasiyrz',
#   'sonunda',
#   'oldu',
#   'oh',
#   'be:))'],
#  ['#mutluyum',
#   '#mutlusun',
#   '#mutluyuz',
#   '...',
#   'hayat',
#   'paylaşınca',
#   'güzel',
#   'lalalalaaaa',
#   ':)'],
#  ['#2012hayallerimin',
#   'ilk',
#   'sırasında',
#   'aylardır',
#   'söyleyip',
#   'durduğum',
#   'numaramı',
#   "turkcell'e",
#   'taşımak',
#   'var.',
#   'hayal',
#   'olarak',
#   'kalmasın',
#   'ama.',
#   'nioğğlur.'],
#  ["turkcell'in", '3g', 'hızı', "abd'de", 'deki', "4g'den", 'hızlı', ':)'],
#  ['turkcell', 'müzik', 'muhabbetini', 'sevdim', ':)'],
#  ['mahalleden', 'superonline', 'geçse', 'iyiymiş.'],
#  ['özturkcell', 'e', 'geciş', 'yap', ';)', ':)))'],
#  ['turkcell',
#   'cok',
#   'iyi',
#   'lan.durduk',
#   'yere',
#   'mesaj',
#   'atıyor,',
#   'kampanyalarıyla',
#   'mutlu',
#   'ediyor',
#   'falan.sevgilim',
#   'gorup',
#   'kıskanır',
#   'umarım.'],
#  ['hayatın', 'beleşçilik', 'git', "turkcell'den", 'al.'],
#  ['turkcell', '4', 'çekiyo', 'yavruş', ':o'],
#  ['selam',
#   'yeniden',
#   'haxball.',
#   'canını',
#   'yiyeyim',
#   'turkcell',
#   'superonline.'],
#  ['ben', 'subtta', 'iphne', 'alcm', '"trkcel"', ':)'],
#  ['turkcell',
#   'gold/platinum',
#   'kullanıcısı',
#   'isen',
#   '%50',
#   'indirim',
#   'hakkı..',
#   "mart'a",
#   'kadar',
#   '3',
#   'kullanma',
#   'hakkın',
#   'var',
#   ';)'],
#  ['sayın',
#   'süreyya',
#   "ciliv'e",
#   "türkiye'ye",
#   'değer',
#   'katanlar',
#   'ödülü',
#   'takdim',
#   'ediliyor.'],
#  ['teşekkürler', 'turkcell'],
#  ['heryone', 'degilim', 'sadece', 'turkcell', 'yuzden'],
#  ['iyisi', 'ben', 'yarın', 'turkcell', 'e', 'gidiyim', '=)'],
#  ["turkcell'deyim", 'şimdi.', 'karşılaşırız', "bi'yerlerde", ';)'],
#  ['teşekkür',
#   'ederim.',
#   'turkcell',
#   'üzerinden',
#   'internete',
#   'bağlanırken',
#   'sorun',
#   'yaşadm',
#   'anlam',
#   'veremedim..',
#   'geçti..',
#   'teşekkürlerr..'],
#  ['#osesturkiye',
#   'turkcell',
#   'sponsorlugunun',
#   'dibine',
#   'vurulmus',
#   '..',
#   'gormeyen',
#   'kalmadi',
#   'sunucudan',
#   'buyuk',
#   'gnctrkcll',
#   'yazisini'],
#  ['hayat', 'paylaşınca', 'güzel...la', 'la', 'la...'],
#  ['yeni', 'yıl', 'reklamı', 'bir', 'harika', '!!'],
#  ['bos', '1', 'numara'],
#  ['#3kelimeyle2011', 'gelecek', 'güzel', 'gelecek'],
#  ['sadece',
#   'quiknet',
#   'mi',
#   'var',
#   'wınnımda',
#   'var',
#   '64',
#   'k',
#   'lik',
#   'micro',
#   'sim',
#   'imde',
#   'var',
#   'i',
#   'pad',
#   'turkcell',
#   '4',
#   'çeker:)'],
#  ['yarin',
#   'kendime',
#   'turksel',
#   'hat',
#   'sey',
#   'aldircaem,',
#   'onu',
#   'veririm',
#   'sana'],
#  ['reklamı',
#   'bana',
#   'reklamlarını',
#   'çağrıştırdı.',
#   'çağrışımı',
#   'yaratan',
#   'turkcellse',
#   'başarılı',
#   'olan',
#   'haliyle',
#   'o!',
#   'değil',
#   'mi?'],
#  ['hahaha',
#   'asil',
#   'sen',
#   'koruosn',
#   ':)',
#   'yok',
#   'ben',
#   'reklama',
#   'taktim',
#   'insana',
#   "avea'yi",
#   'degil',
#   'direk',
#   "turkcell'i",
#   'dusunduruyo'],
#  ['yarında', 'perşembeeee..oohhhhh', 'şükür..', '[gnctrkcll]'],
#  ['is',
#   'uretemedikleri',
#   'ortada..',
#   "avea'yla",
#   'vodafone',
#   'yerde',
#   'çekiyor',
#   'bilemem',
#   'ikisinin',
#   "turkcell'i",
#   'hala',
#   'çekemediği',
#   'net."'],
#  ['iyiki',
#   'varsınız',
#   'olmasanız',
#   'mesaj',
#   'geleceği',
#   'yok,telefon',
#   'özelliğini',
#   'unutacak',
#   'nerdeyse.',
#   'kadar',
#   'yalnızım:)'],
#  ['iyi',
#   'ipad',
#   "2'yi",
#   "turkcell'den",
#   'almışım.',
#   'cam',
#   'lig',
#   'tv',
#   'yerde',
#   ':)',
#   'teşekkürler'],
#  ['hayat', 'paylaşınca', 'güzel', 'lalalalalalalalalal', ':d'],
#  ['kesinlikle', 'superonline'],
#  ['oturduğunuz',
#   'bolgede',
#   'varsa',
#   'superonline',
#   'fiber',
#   'net',
#   'geçmelisiniz.'],
#  ['turkcell',
#   'bana',
#   'komısyon',
#   'baglamalı',
#   'bence',
#   'artık',
#   'kacıncı',
#   'musterısını',
#   'kazandırdım',
#   ':dd'],
#  ['yila',
#   'kadarki',
#   'iyi',
#   'yilbasi',
#   'reklam',
#   'sarkisi',
#   "turkcell'in",
#   "'bu",
#   'sene',
#   'yeni',
#   'bir',
#   'cebin',
#   'olsun',
#   'calain',
#   'arayan',
#   "olsun...'",
#   'baslayandir!'],
#  ['coco', 'cola,turkcell,vestel', 'reklamda', 'onculer', '...'],
#  ['#turkcellmuzik',
#   'bengü',
#   'bitmesinn',
#   'seni',
#   'seviyorummm',
#   'türkcell',
#   'teşkkürler',
#   'bize',
#   'böyle',
#   'bir',
#   'anı',
#   'yaşattıgın'],
#  ['kendimi',
#   'turkcell',
#   'in',
#   'yeni',
#   'yıl',
#   'şarkısını',
#   'söylemekten',
#   'alikoyamiyorum.'],
#  ['oha',
#   'turksel',
#   'bana',
#   'çalışıyo',
#   'resmen',
#   '487',
#   'dakika',
#   'bedava',
#   'vermiş',
#   ':o'],
#  ['#vodafone',
#   'icin',
#   'buyuk',
#   'eksiklik.',
#   'apple',
#   'urunlerinde',
#   'kullanilmak',
#   'uzere',
#   '#turkcell',
#   'online',
#   'islem',
#   'bir',
#   'app',
#   'yapmadilar,',
#   'yapamadilar.'],
#  ['sayın',
#   'sağ',
#   'olsun',
#   'beni',
#   'aradığınızı',
#   'belirtti',
#   'mesajla.',
#   'i̇yi',
#   'seneler',
#   'diler',
#   'sağlık,mutluluk',
#   'bol',
#   'kazançlı',
#   'bir',
#   'yıl',
#   'dilerim.'],
#  ['bahçeşehir', "üniversitesi'nden", 'süreyya', "ciliv'e", 'özel', 'ödül'],
#  ["2012'ye",
#   'kadar',
#   'sms',
#   'hakkinizi',
#   'kullanabilirsin',
#   'diyen',
#   'sevgili',
#   'turkcell',
#   '"allah',
#   'razii',
#   'olsun,',
#   'sen',
#   'olmasan',
#   'napardim"',
#   'demek',
#   'istedim.'],
#  ['turkcell', 'avea', 'varsa', 'alabilirim', '-,-'],
#  ['bahçeşehir',
#   'univ',
#   'tesekkurler..',
#   'türkiye',
#   'ye',
#   'deger',
#   'katanlar',
#   'ödülü',
#   'turkcell',
#   'ceo',
#   'sureyya',
#   'ciliv\'e.."'],
#  ['i̇zmir',
#   'arena',
#   'inanilmazdin..tum',
#   'turkcell',
#   'ekibine',
#   'sonsuz',
#   'tesekkurler:)'],
#  ['başka',
#   'olacaktı',
#   ':)',
#   'ben',
#   "turkcell'in",
#   'yerinde',
#   'olsam',
#   'seni',
#   'dakikası',
#   '5-10',
#   'liraya',
#   'konuştururum',
#   'saatten',
#   'sonra',
#   ':)'],
#  ['murat',
#   'erkan:',
#   "''turkcell",
#   'superonline',
#   'olarak',
#   'misyonumuz',
#   'operatörlerin',
#   'operatörü',
#   "olmak.''"],
#  ['kamil', 'koç', 'un', 'turkcell', 'kornası', 'güzel', 'olmuş', ':)'],
#  ['yeni',
#   'yıl',
#   'kutlama',
#   "msg'ını",
#   'aldım.',
#   'teşekkürler..',
#   'hayat',
#   'paylaşınca',
#   'güzel',
#   'lala',
#   'la',
#   'la',
#   'laaa'],
#  ['bugün', 'perşembe', 'turkcell', 'sinema', 'günleri', '....'],
#  ['akşam',
#   'sinemada',
#   "sherlock'ta",
#   'kullanmak',
#   'bi',
#   'gnctrkcll',
#   'şifresi',
#   'lazım',
#   'gençler.',
#   'bi',
#   'el',
#   'atıverin',
#   'hadi.'],
#  ['askim',
#   'nasil',
#   'yollicaksin',
#   'banaaa',
#   ':d',
#   'ben',
#   'kendime',
#   'yeni',
#   'hat',
#   'alirim',
#   'turkcell',
#   'iyi',
#   'kolay'],
#  ['sagolasin',
#   'el',
#   'öpenlerin',
#   'cok',
#   'olsun',
#   'mesaj',
#   'hakkın',
#   'turkcell',
#   'den',
#   'beles',
#   'gelsin',
#   ':d'],
#  ['onu',
#   'beğendik',
#   'bide',
#   ',twitter',
#   'paketi',
#   'bekliyoruz',
#   'turkcell',
#   'den...sınırsız',
#   'twit'],
#  ['iki',
#   'hafta',
#   'gene',
#   'iyi',
#   'benimki',
#   'bir',
#   'iki',
#   'ayda',
#   'gelmişti.turkcell',
#   'sağolsun:d'],
#  ['off',
#   'ali',
#   'sbh',
#   'sbh',
#   'güldürdün',
#   ':d',
#   'art',
#   'ık',
#   'facebooktanda',
#   'turkcell',
#   'ilişkisi',
#   'war',
#   'yaparsın',
#   'sen',
#   ':d'],
#  ['"çekemeyen',
#   'anten',
#   'taksın"',
#   'sticker',
#   'dağıtmış,',
#   'ben',
#   'yaptırcam',
#   'özel',
#   'olarak',
#   ':)'],
#  ['opuldun',
#   'bebegim',
#   ';)',
#   'tebrikler!',
#   'size',
#   'ozel',
#   '1',
#   'ay',
#   'boyunca',
#   'yurtici',
#   'heryone',
#   '100',
#   'dakika',
#   '300',
#   'sms',
#   'kazandiniz.',
#   'gule',
#   'gule',
#   'kullanin!'],
#  ['divane',
#   'asik',
#   'blog',
#   'turkcell',
#   'blog',
#   'odullerinde',
#   'son',
#   '10`a',
#   'kalmis.',
#   'destek',
#   'veren',
#   'herkese',
#   'tesekkurler...'],
#  ['aynen', 'kanka', 'turkcell', 'iyı'],
#  ['sen',
#   'vodafone',
#   'ani',
#   'yasarken',
#   'ben',
#   'turkcell',
#   'yerde',
#   'seni',
#   'cekemem.'],
#  ['müzik',
#   'ihtiyaçlarınızın',
#   '(dinleme,',
#   'indirme,',
#   'keşfetme',
#   'vb.)',
#   'turkcell',
#   'kalitesiyle',
#   'tek',
#   'bir',
#   'uygulamada',
#   'toplanmış',
#   'olması',
#   'fena',
#   'mı?',
#   ':)'],
#  ['özturkcell', 'reklamı', 'fena', 'komedi'],
#  ['tweetlerini',
#   'sabahtan',
#   'beri',
#   'toplayamadığım',
#   'odamdan',
#   'takip',
#   'ediyorum',
#   'diyorum',
#   'hayat',
#   '140',
#   'karakteri',
#   'paylaşınca',
#   'güzel.'],
#  ['#pazarlamakonferansi',
#   'turkcell',
#   'akademinin',
#   'duzenledigi',
#   'konferansin',
#   'baslamasini',
#   'bekliyoruz'],
#  ['ben',
#   'zaten',
#   'turkcell',
#   'baktım.',
#   "turkcell'den",
#   'vazgeçmem',
#   'türlü',
#   'kaliteli',
#   'bir',
#   'ara',
#   'vodafone',
#   'kullandım',
#   'ikinci',
#   'hat',
#   'yok',
#   'asla..'],
#  ['ev', 'telefonunuzu', "superonline'a", 'devredin..'],
#  ['turkcell',
#   'iyi',
#   'lan.durduk',
#   'yere',
#   'mesaj',
#   'atıyor,',
#   'kampanyalarıyla',
#   'mutlu',
#   'ediyor',
#   'falan.sevgilim',
#   'görüp',
#   'kıskanır',
#   'umarım.'],
#  ['kendisi',
#   'bunu',
#   'açıklamıştı',
#   'turkcell',
#   'teknoloji',
#   'zirvesinde..',
#   'bizde',
#   'terlikle',
#   'bile',
#   'işe',
#   'gelirler',
#   'demişti.',
#   'önemli',
#   'olan',
#   'mutluluğu.'],
#  ['kafama',
#   'takilan',
#   'bir',
#   'konu',
#   'gsm',
#   'operatorlerinin',
#   'mobil',
#   'site',
#   'destegi',
#   'uygulamalarinin',
#   'olmamasi.',
#   'turkcell',
#   'istisna',
#   'tabi'],
#  ['hayat', 'paylaşınca', 'güzel', ':)'],
#  ['dogum',
#   'gunu',
#   'pastasi',
#   'icin',
#   'tesekkurler.',
#   'simartiyosun',
#   'beni',
#   ':)'],
#  ['kami̇l', "koç'tan", 'özel', 'turkcell', 'kampanyasi'],
#  ['sabah',
#   'sabah',
#   'kendimi',
#   "koridorda''turkcell",
#   'beni',
#   'sesimden',
#   "tanir''",
#   'bagirken',
#   'buldum.bir',
#   'internet',
#   'paketi',
#   'icin',
#   'insan',
#   'neler',
#   'yapiyo'],
#  ['*hayat', 'paylaşinca', 'güzel!!!'],
#  ['sabah', '7.30dan', 'itibaren', 'tekrar', "turkcell'm", 'bilginizee', ':)'],
#  ['turkcell', 'e', 'gel'],
#  ['nihayet',
#   'eve',
#   'fiber',
#   'internet',
#   'geldi.',
#   'superonline,',
#   "karamehmet'in",
#   'yıllar',
#   'önce',
#   'döşediği',
#   'fiber',
#   'ağı',
#   'engellemeler',
#   'yüzünden',
#   'anca',
#   'devreye',
#   'sokabildi.'],
#  ['turkcell',
#   'aramız',
#   'kadar',
#   'iyi',
#   'olmasa',
#   'böyle',
#   'hediyeler',
#   'verdikce',
#   'gözüme',
#   'giriyorlar',
#   ':d'],
#  ['hayat', 'paylaşınca', 'güzel', ':))'],
#  ['bir',
#   'cüzdanı',
#   'evde',
#   'unuttum',
#   'turkcell',
#   'mobil',
#   'imza',
#   'sayesinde',
#   "garanti'den",
#   'para',
#   'çekip',
#   'gunumu',
#   'sorunsuz',
#   'götürüyorum',
#   ':)'],
#  ['zekice', ';)'],
#  ['"1',
#   'yeni',
#   'film',
#   'vizyone',
#   'girerken,',
#   'gnctrkcll',
#   'şifresi',
#   'arayan',
#   '3',
#   'milyon',
#   'kişi',
#   'var."',
#   'ahaha'],
#  ['hayat', 'paylaşınca', 'güzel:)'],
#  ['faturalı',
#   'hatlarda',
#   'esnek',
#   'avantajların',
#   'olmasını',
#   'diler',
#   'başarılarınızın',
#   'devamını',
#   'dilerim',
#   'hoşçakalın..'],
#  ['internet',
#   'telefonda',
#   'superonline',
#   "'a",
#   'transfer',
#   'oldum.20',
#   'mgpt',
#   'sınırsız',
#   'internet',
#   '44',
#   'tl',
#   'telefon',
#   'vergiler',
#   'dahil',
#   '7,5',
#   'kr',
#   'sabit',
#   'ücret',
#   'yok'],
#  ['şener',
#   'şen',
#   'ceza',
#   'olgun',
#   'şi̇mşek',
#   'binnur',
#   'kaya',
#   'sana',
#   'söylüyorum',
#   'firmanın',
#   'reklamına',
#   'çıkmayın',
#   'yaşasin'],
#  ['bizde',
#   'biliriz',
#   'çileyi',
#   'zamanında',
#   'çektik',
#   ':)',
#   'yarın',
#   'gel',
#   'sizede',
#   'superonline',
#   'alalım'],
#  ['i', 'phone', 'turkcell', 'müzik', 'application..', 'mutlaka', 'deneyin...'],
#  [':))',
#   '1,5',
#   'saat',
#   'süper..',
#   'normalde',
#   'atatürkden',
#   'gidiyorum',
#   'turkcell',
#   'sunexpress',
#   'kampanyasından',
#   'yararlandım',
#   'ucuza',
#   'geldi',
#   'baya',
#   ':)))'],
#  ['toplu',
#   'tasima',
#   'aracinda',
#   '"turkcell',
#   'bemi',
#   'sesimden',
#   'tanır"',
#   'cilginliginida',
#   'yapti',
#   '#pes'],
#  ['sahan',
#   'in',
#   'oynadığı',
#   'son',
#   'turkcell',
#   'reklamına',
#   'cok',
#   'güldüm',
#   'bsbdbdhdfnbzhgczzvzvzjddhdjdjzg'],
#  ['yöne', 'sms', '12', 'tl', 'bakınız', 'turkcell', ':d'],
#  ["i̇phone'un",
#   'yeni',
#   'modeli',
#   'i̇phone',
#   '4s,',
#   'turkcell',
#   'tarafından',
#   'satışa',
#   'sunulacak.'],
#  ['hayat', 'paylaşınca', 'güzel.', ':)'],
#  ['divandan',
#   'dogum',
#   'gunu',
#   'pastasi',
#   'gondermek!',
#   'valla',
#   'sasirdim',
#   'tesekkurler',
#   '#turkcell',
#   ':):)'],
#  ['bir',
#   'adam',
#   'vardı',
#   'canı',
#   'sıkılıyordu.',
#   'bir',
#   'film',
#   'izledi',
#   'can',
#   'sıkıntısı',
#   'gitti.',
#   'eski',
#   'bir',
#   'turkcell',
#   'reklamı',
#   ':)',
#   'hey',
#   'gidi',
#   'günler'],
#  ['turkcell',
#   'superonline',
#   '1',
#   'milyon',
#   'haneye',
#   'fiber',
#   'i̇nterneti',
#   'taşıdı,',
#   'sabit',
#   'numara',
#   'taşımada',
#   'lider',
#   'oldu.'],
#  ['2012de',
#   'sevgililerimi',
#   'buldum:',
#   'turkcell',
#   '(galp)',
#   'wikipedia',
#   '(galp)',
#   'google',
#   '#finallergeliyorhaci'],
#  ['2',
#   'gundur',
#   'tv',
#   'yayını',
#   'var',
#   'internet',
#   ':(',
#   'turkcell',
#   'mobil',
#   'internet',
#   'olmasa',
#   'yapardım',
#   ':/',
#   '\x1a\x1a\x1a'],
#  ['avea',
#   'dan',
#   'bana',
#   'ay',
#   '250',
#   '300',
#   'tl',
#   'fatura',
#   'gelcek',
#   ':((',
#   'turkcell',
#   'geri',
#   'dönmeyi',
#   'düşünüyorum',
#   ':))'],
#  ['superonline',
#   'mesela',
#   ':)',
#   'evet',
#   'onda',
#   'soru',
#   'oldu',
#   'ttnet',
#   'kadar',
#   'insanı',
#   'baymıyor'],
#  ['ah', "turkcell'm", 'hemende', 'duydu', 'sesimiii:))'],
#  ['bugün',
#   'bana',
#   'yaptığın',
#   'haksızlığı',
#   'sana',
#   'unutturmayacağım..hani',
#   '150',
#   'yöne',
#   'kampanyası..artık',
#   'yaşasın',
#   'turkcell.seni',
#   'terkediyom',
#   'avea..'],
#  ['turkcell', 'var', 'üzülme', ':)'],
#  ['superonline', 'tabiki', ':)'],
#  ['perşembe',
#   'bizim',
#   'olsun',
#   'malum',
#   '#gnctrkcll',
#   'cuma',
#   'sabahı',
#   'hallederiz',
#   ':)'],
#  ['#yeniyildanistegim',
#   'paylaşmayı',
#   'bilen',
#   'bir',
#   'dünya...',
#   'hayat',
#   'paylaşınca',
#   'güzel',
#   ':)'],
#  ['#turkcellfestival',
#   "turkcell'in",
#   'canlı',
#   'konser',
#   'model',
#   'seçimi',
#   'başarılı',
#   'olmuş!!!',
#   'şarkı',
#   'sözleri',
#   'sound',
#   'iyi.',
#   'aynen',
#   'devam',
#   'model!'],
#  ['sadece',
#   'aradiigimda',
#   'musteri',
#   'hizmetlerine',
#   'ulasabildigim',
#   'icin',
#   'turkcell',
#   'kullanirim',
#   'avea',
#   'vodafone.',
#   'bosuna',
#   'kampanya',
#   'vs',
#   'yapmayin'],
#  [':d',
#   'turkcell',
#   'saygı',
#   'çerçevesinde',
#   'düzeyli',
#   'bir',
#   'dostluğumuz',
#   'var',
#   'bana',
#   'yapamazlar',
#   'öyle',
#   'bişey',
#   ':d'],
#  ['hayat', 'paylaşınca', 'güzel', 'türkselli.'],
#  ['fena', 'degil'],
#  ['canli',
#   'performansiyla',
#   '30',
#   'aralik',
#   'cuma',
#   'gunu',
#   'saat',
#   "15:00'da",
#   'turkcell',
#   "muzik'te!"],
#  ['arada',
#   'sevgili',
#   'panpişlerime',
#   'duyurmayi',
#   'unuttum',
#   'vodafone',
#   'un',
#   'ayricaliklarla',
#   'dolu',
#   'dunyasindan',
#   'turkcell',
#   'in',
#   'indirimlerle',
#   'dolu',
#   'dunyasina'],
#  ['idate',
#   'raporundan',
#   '"turkcell',
#   'superonline',
#   "2011'de",
#   'sunmaya',
#   'başladığı',
#   '1000mbs',
#   'hızında',
#   'fiber',
#   'internetle',
#   "avrupa'da",
#   'sayılı',
#   'operatör',
#   'arasına',
#   'girdi"'],
#  ['neye',
#   'uyuz',
#   'olduysam',
#   'reklamlarına',
#   'hayran',
#   'oldum;',
#   'cocacola,',
#   'zaman,',
#   'turkcell..',
#   'reklamcılık',
#   'harikaları..',
#   ':)'],
#  ['kalp',
#   'kalbe',
#   'karşı,',
#   'şimdi',
#   "superonline'ı",
#   'aradım.',
#   'hizmet',
#   'fiyat',
#   'iyi',
#   'oradaymış.'],
#  ['sağlık',
#   'olsun,',
#   'büyüyünce',
#   'bende',
#   'turkcell',
#   'note',
#   'kullanırım...'],
#  ['tabiiki', 'turkcell', 'yurtdisi', 'paketi', 'aldim', ';)'],
#  ['#hayatpaylasincaguzel',
#   'turkcell',
#   'yine',
#   'başarılı',
#   'bir',
#   'iş',
#   'yapıyo,',
#   'yazdıklarımız',
#   'sapphire',
#   "çarşı'nın",
#   'önündeki',
#   'ekranda',
#   'çıkıyor',
#   ':))'],
#  ['1',
#   'sn',
#   'nobetci',
#   'eczaneleri',
#   'bulup',
#   '1',
#   'km',
#   'yakındaki',
#   'eczaneyi',
#   '1',
#   'saat',
#   'aramaya',
#   'gerek',
#   'bırakmayan',
#   'turkcell',
#   'pusula',
#   'uygulaması',
#   'seviyoruz',
#   'seni'],
#  ['zaman',
#   'neymiş,',
#   'hayat',
#   'paylaşınca',
#   'güzel',
#   'lallalalllala,',
#   'paylaşıp',
#   'çoğalınca',
#   'güzel',
#   'lalalallalalala.'],
#  ['superonline',
#   'geç',
#   ';)',
#   'alt',
#   'yapı',
#   'varsa',
#   'sizin',
#   'oralarda',
#   'bence',
#   'fiber',
#   'internet',
#   'al,',
#   'internet',
#   'neymiş',
#   'görüceksin',
#   ';)'],
#  ['nihayet',
#   'temiz',
#   'akıcı',
#   'bir',
#   'canlı',
#   'yayın',
#   'izleyebiliyoruz.',
#   'tebrikler...'],
#  ['#turkcellmuzik', 'yaşasın', 'manga', 'yaşasın', 'turkcell', '«§©µ»', ':)'],
#  ['değil',
#   'yeniden',
#   'para',
#   'yüklemeden',
#   'genç',
#   'avantaja',
#   'geçsem?',
#   'turkcell',
#   'kalitesi...',
#   'internet...',
#   'of',
#   'aman',
#   'ya!'],
#  ["444'lü",
#   'numaraları',
#   'aramanın',
#   'ucuz',
#   'yolu',
#   'thy',
#   '21.5',
#   'dakikalık',
#   'konuşma',
#   'sadece',
#   '40',
#   'kuruş',
#   'tutmuş',
#   ':)'],
#  ['iphone', '4s', "turkcell'le", "türkiye'de"],
#  ['#birazyiyecek',
#   'biraz',
#   'değil',
#   'tam',
#   'hazırlayın,',
#   'temiz',
#   'kaplarda',
#   'yenebilecek',
#   'şekilde',
#   'su',
#   'hazırlayın,ölmezsiniz',
#   'korkmayın,hayat',
#   'paylaşınca',
#   'güzel.'],
#  ['geçip',
#   'taksitle',
#   'bir',
#   'iphone',
#   '4s',
#   'alayım',
#   'dedim,',
#   'ilk',
#   '12',
#   'taksiti',
#   'tek',
#   'çekimde',
#   'peşin',
#   'istediler.',
#   '1400tl',
#   'peşin',
#   'vereceksem',
#   "turkcell'de",
#   'kalırım'],
#  ['i̇ki',
#   'biranın',
#   'verdiği',
#   'hal',
#   'güzel.',
#   'sarhoş',
#   'değil',
#   'bi',
#   'adam',
#   'sen',
#   'decilik',
#   'bi',
#   'boşvermişlik',
#   'bi',
#   'hayat',
#   'paylaşınca',
#   'güzelcilik.',
#   'evet.'],
#  ["turkcell'in",
#   'premium',
#   'musterisi',
#   'olmamama',
#   'ragmen',
#   'cihaz',
#   'temini',
#   'icin',
#   'gostermis',
#   'oldugunuz',
#   'ozel',
#   'ilgiden',
#   'dolayi',
#   'cok',
#   'tesekkur',
#   'ederim.'],
#  ['#pazarlamakonferansi', 'turkcell', "akademi'ye", 'cok', 'tesekkurler!'],
#  ['oha',
#   'amk',
#   'turkcell',
#   'bana',
#   '2',
#   'gündürr',
#   'bedava',
#   'konusma',
#   'hakkı',
#   'gonderiyo',
#   'yaklaşık',
#   '3',
#   'saatlk',
#   'bedava.'],
#  ['sahan',
#   'gokbakarin',
#   'oynadigi',
#   'yeni',
#   'turkcell',
#   'reklami',
#   'baya',
#   'iyi.',
#   'very',
#   'sweet',
#   'you,',
#   'very',
#   'beautiful'],
#  ['re:', 'türkcell', 'vınn', 'çeker', 'hacılar', '..', ':)'],
#  ['sabah',
#   'vapurlarında',
#   'ücretsiz',
#   'dağıtılan',
#   'gazeteleri',
#   'okuyanlar,',
#   '1',
#   'milyon',
#   'kişiye',
#   'ulaştı.',
#   'hayat',
#   'okuduğunu',
#   'paylaşınca',
#   'güzel',
#   ':)'],
#  ['ptesi', 'gelsin', 'bi', 'gnctrkcll', 'yapayım', 'zaman:))'],
#  ['divane', 'aşık', 'gibi:', 'türkcell', 'blog', "ödülleri'nde", 'finaldeyiz'],
#  ['"hayat', 'paylaşınca', 'güzel"'],
#  ['doğum',
#   'günüm',
#   'hediyelerim',
#   "turkcell'den",
#   "divan'dan",
#   "pasta,dominos'tan",
#   'pizzaya',
#   'indirim.beni',
#   'özel',
#   'hissettiren',
#   'başkaları',
#   'olmalıydı',
#   'sanki:)'],
#  ['turkcell', 'can', 'faturali', 'canan:):)'],
#  ['sahanin', 'turkcell', 'reklamlari', 'gercekten', 'cok', 'komik.'],
#  ['superonline',
#   'cok',
#   'iyi',
#   'hele',
#   'ttnetten',
#   'sonra',
#   'baya',
#   'iyi',
#   '3',
#   'aydir',
#   'sorunsuz',
#   'kullaniorm',
#   'hic',
#   'skntı',
#   'cikarmadi'],
#  ['yarın', 'geçn', 'türkcell', 'kullan', 'derim', 'gari..'],
#  ['i̇peğimin',
#   "turkcell'e",
#   'geçmesine',
#   'ben',
#   'sevinmişimdir',
#   'kesinlikle.aykutdan',
#   'hatta',
#   ':d'],
#  ['turkcell',
#   'dört',
#   'çeker,',
#   'benim',
#   'ebrum',
#   'şeker',
#   ':)',
#   'ben',
#   'fotoya',
#   'biterimm'],
#  ['onun', 'icin', 'gecicem', 'tekrar', "turkcell'e", 'kaldi', ':-d'],
#  ['bi',
#   'şarkı',
#   'artık',
#   'favori',
#   'şarkım',
#   ':)',
#   "turkcell'e",
#   'başvurup',
#   'şarkıyı',
#   'çalarken',
#   'dinlet',
#   'yapıcam',
#   ':)'],
#  ["turkcell'le",
#   'bağlan',
#   'hayata...',
#   'turkcell',
#   'zengin',
#   'olmasın',
#   'olsun',
#   'be'],
#  ['ole',
#   'bi',
#   'insan',
#   'olacaksin',
#   'tcell',
#   'gbi',
#   'kaliteli',
#   'vodafone',
#   'gbi',
#   'yerde',
#   'cekmeyen',
#   'avea',
#   'gbi',
#   'gun',
#   'yeni',
#   'musteri',
#   'kazanan',
#   '..',
#   'gnaydin',
#   '\x1a'],
#  ['soz',
#   'verdigi',
#   'aradi,',
#   'gorustuk.',
#   'tesekkurler',
#   'umarim',
#   'kisa',
#   'zamanda',
#   'cozume',
#   'kavusur',
#   'sorunumuz'],
#  ['hım',
#   'valla',
#   'yeni',
#   'dediğin',
#   'cuma',
#   'günü',
#   'turkcell',
#   'müzikte',
#   'saat',
#   '15.00',
#   'te',
#   'canlı',
#   'performansı',
#   'var',
#   'başka',
#   'bişi',
#   'bilmiyorum:)'],
#  ['özetle',
#   'akşamımı',
#   'rezil',
#   'eden',
#   'vodafone',
#   'dan',
#   'artık',
#   'nefret',
#   'ediyorum.',
#   'turkcell',
#   'kazık',
#   'mazık',
#   'hakkaten',
#   'kaliteli.',
#   'donmek',
#   'gerekiyor'],
#  ['turkcell',
#   'timlerde',
#   'hizli',
#   'sarj',
#   'unitesii',
#   'var',
#   'oraya',
#   'git',
#   'olum',
#   'dert',
#   'ettigin',
#   'seye',
#   'bak'],
#  ['bilmediğim',
#   'acayip',
#   'turkcell',
#   'numarası;şu',
#   'kontorsuz',
#   'dar',
#   'zamanlarımda',
#   'mesajlarınla',
#   'bana',
#   'destek',
#   'olduğun',
#   'yalnız',
#   'bırakmadığın',
#   'teşkürler.'],
#  ['hayat', 'paylaşınca', 'güzel', 'turkcell', ':))))'],
#  ['dıtdıtdırıtdıtt',
#   ':d',
#   'of',
#   'turkcell',
#   'reklamı',
#   'aklıma',
#   'geldi',
#   ':d'],
#  ['"hayat', 'paylaşınca', 'güzel"', 'tabi.'],
#  ['turkcellmüzik',
#   'biraz',
#   'gelişsin',
#   'fizy',
#   'yi',
#   'tamamen',
#   'bırakıcam',
#   'söz.'],
#  ['zaman',
#   'bi',
#   'sen',
#   'öyle',
#   'davranma,',
#   'sen',
#   'ataydın',
#   'iyiydi.',
#   'turkcell',
#   'neyine',
#   'yetmiyo',
#   ':('],
#  ['yarına', 'gnctrkcll', 'yok..uykum', 'pahalıya', 'geliyo', 'zaman..'],
#  ["istanbul'dan",
#   "bolu'ya",
#   'kadar',
#   'kopmadan',
#   'internet',
#   'keyfini',
#   'bana',
#   'yaşatan',
#   'turkcell',
#   "3g'ye",
#   'sonsuz',
#   'teşekkürler',
#   '=)..',
#   'hizmet',
#   'budur..'],
#  ['yavrum',
#   'aldım',
#   'mesajını',
#   'turkcell',
#   'değil',
#   'misin',
#   'sen?',
#   'gitmiyo',
#   ':/'],
#  ['oh',
#   'bee',
#   'sonunda',
#   'telefonumun',
#   'hatti',
#   'acildi!',
#   'tesekkurler',
#   '#turkcell,',
#   'yilbasi',
#   'ustu',
#   'telefonsuz',
#   'kalinmazdi'],
#  ['memnun',
#   'kaldımda',
#   'turkcell',
#   'kampanyası',
#   'tekrar',
#   'olsun',
#   'yaw',
#   'pahalı'],
#  ['#superonline',
#   'müşteri',
#   'hizmetleri',
#   'gerçekten',
#   'hızlı',
#   'bir',
#   'şekilde',
#   'sorunumu',
#   'çözdü.'],
#  ['hayat', 'paylaşınca', 'güzel', 'canım', 'benim', ':)'],
#  ['#türkiye',
#   'akbank’ın',
#   'axess’i',
#   'turkcell',
#   'cep-t',
#   'cüzdan’da:',
#   'akbank',
#   'turkcell,',
#   'ödeme',
#   'sistemleri',
#   'mobil',
#   'd...',
#   '#sondakika'],
#  ['sana', 'kadar', 'teşekkür', 'etsem', 'azdır', 'turkcell', ':)'],
#  ['turkcell.in',
#   'böle',
#   'bi',
#   'kıyak',
#   'geçeceği',
#   'aklımın',
#   'ucundan',
#   'geçmezdi'],
#  ['valla',
#   'teknoloji',
#   'ilerledi..kaybolduk',
#   'turkcell',
#   'çekiyor',
#   ':))',
#   'ıssız',
#   'buralar',
#   'terk',
#   'edilmiş',
#   'gibi...'],
#  ['#osesturkiye', 'nurullh', 'insana', 'huzur', 'veriyor', 'sesin'],
#  ['sabah',
#   "05:05'te",
#   "turkcell'e",
#   'numaramın',
#   'taşınması',
#   'tamamlanıyormuş.',
#   'sen',
#   'halen',
#   'komikli',
#   'şakalı',
#   'reklamlara',
#   'devam',
#   'et',
#   'avea',
#   ':)'],
#  ['i̇novasyonda', 'büyük', 'ödül', "turkcell'in!"],
#  ['hayat', 'paylaşınca', 'güzel:)'],
#  ["2011'de",
#   'hangi',
#   'marka',
#   'reklam',
#   'verdi?',
#   'ilk',
#   '3',
#   'aynı',
#   'sektor',
#   '1-turkcell,',
#   '2-vodafone,',
#   '3-',
#   'turktelekom'],
#  ['turkcell',
#   'den',
#   'aradılar',
#   'iş',
#   'görüşmesi',
#   'yarın',
#   'cagırdılar',
#   'geldiye',
#   ':)',
#   'aklımda',
#   'yoktu',
#   'güzel',
#   'olur',
#   'gelebilirim'],
#  ['cıkmadan',
#   'solıyım',
#   'dun',
#   'sms',
#   'yaptiktan',
#   'sonra',
#   'baktiim',
#   'kiiii',
#   'bedava',
#   '100',
#   'dk',
#   'kazanmısım',
#   'arti',
#   'heryone',
#   '300',
#   'sms.',
#   'turkcell',
#   'sms',
#   'yapmami',
#   'bekliyomus.'],
#  ['oha',
#   'yeni',
#   'yüklediğim',
#   'araba',
#   'yarısını',
#   'sevdim',
#   'lan',
#   'ilk',
#   'hemen',
#   '10',
#   'arabadan',
#   '1.lige',
#   'geçebildim',
#   'azıcık',
#   'zor',
#   'olsa',
#   'sağol',
#   'turkcell!'],
#  ['ping',
#   '600',
#   'ms',
#   'olurmu?',
#   'oldu',
#   'diyelim,',
#   'müş.hizm.buna',
#   'normal',
#   'dermi?',
#   'yazıklar',
#   'olsun..',
#   'iptal',
#   'ettireceğim..',
#   'turkcell',
#   'superonline',
#   'a',
#   'var..'],
#  ['hadı',
#   'bırlıkte',
#   'ıphone',
#   '4',
#   'e',
#   'gecelım',
#   'bıze',
#   'sponsor',
#   'olsun',
#   ':)'],
#  ['hayata', 'bağlan', 'turkcelleeeee'],
#  ['numaramı', "turkcell'e", 'mi', 'taşısam'],
#  ['ben', 'ttnet', 'kullanıyorum', 'bence', 'superonline', 'iyi', '-,-'],
#  ['manga',
#   'konseri',
#   'harikydı.acun',
#   "ilıcalı'ya,manga'ya",
#   "turkcell'e",
#   'teşekkür',
#   'ediyorum.'],
#  ['servis',
#   'sağlayıcın',
#   'geçiriyosa',
#   "android'in",
#   'suçu',
#   'ne?',
#   "turkcell'den",
#   'gayet',
#   'memnunum',
#   "vodafone'un",
#   'sınırsız',
#   'paketleri',
#   'var',
#   'makul'],
#  ['gayet',
#   'tabii',
#   ':)',
#   'turkcell',
#   'aylik',
#   '7tl',
#   'internet',
#   'bbm',
#   'kullanimi',
#   'sagliyor.butun',
#   'bb',
#   'uygulamalarini',
#   'paketle',
#   'kullanabiliyorsun.'],
#  ['keşke',
#   'bugün',
#   'süreyya',
#   'ciliv',
#   'in',
#   'ödül',
#   'töreninde',
#   'bulunma',
#   'şansım',
#   'olsaydı'],
#  ['turkcell', 'yeni', 'yildizini', 'bulmus'],
#  ['i̇novasyonda', 'büyük', 'ödül', "turkcell'in"],
#  ['cok', 'sukur', "bb'mi", 'kurtardi', 'turkcell\x1a'],
#  ['sonunda',
#   'turkcell',
#   'bayiine',
#   'götürmeniz',
#   'iyi',
#   'olur',
#   'diyorlar.',
#   ':)'],
#  ['turkcell', 'hayatımdakı', 'kolaylık', 'ondan', ':)'],
#  ['evet,', 'guzel', 'olmus.'],
#  ['turkcell',
#   'internet',
#   'sitesinde',
#   'detayli',
#   'aciklama',
#   'var',
#   'ordan',
#   'bakabilirsin'],
#  ['zaten',
#   'iletişim',
#   'kalitesi',
#   'kötü.',
#   'ben',
#   'memnun',
#   'kalmadım',
#   'avea',
#   'dan.',
#   'türkcell',
#   'pahalı',
#   'hizmet',
#   'iyi'],
#  ['huzur', 'bereket', 'sukunet'],
#  ['#turklereozgudavranislar',
#   'pazartesi',
#   'persembe',
#   'turkcell',
#   'sınema',
#   'gunu',
#   'gelsede',
#   'sınemaya',
#   'gıtsek',
#   'dıye',
#   'beklemek'],
#  ['hayat', 'paylaşınca', 'güzel'],
#  ['#turkcellmuzik', 'konser', 'i̇çin', 'teşekkürler', 'turkcell', 'manga'],
#  ['kopuyoruz', 'alperenle', ':d', 'teşekkürler', 'turkcell', ':d'],
#  ['türkcell',
#   'beni',
#   'seviyor.',
#   'yoksa',
#   '13.13ten',
#   'başka',
#   'msj',
#   'atacak',
#   'zaman',
#   'yok.'],
#  ['hayat',
#   'paylaşınca',
#   'güzel',
#   'lalala',
#   'lay',
#   'laay',
#   'la',
#   'lay.',
#   'bir',
#   'gün',
#   'iyi',
#   'oluyorsun,',
#   'öteki',
#   'gün',
#   'melenkolik',
#   'ruh',
#   'halinde.'],
#  ['bi',
#   'turkcell',
#   'calisani',
#   'olarak',
#   'soylemek',
#   'istedim',
#   'superonline=turkcell',
#   ',hizmet',
#   'kalitemzden',
#   'hic',
#   'suphe',
#   'yok:)tabiki',
#   'superonline'],
#  ['off',
#   'yazık',
#   'turkcell',
#   'müzik',
#   'sahensindeki',
#   'konserinize',
#   'gelemeyeceğim',
#   'cunku',
#   'okulum',
#   'var',
#   'off.sizi',
#   'çoook',
#   'seviyoruuuuuum!'],
#  ['kahve',
#   'dünyası',
#   'yaptığınız',
#   'kampanya',
#   'süper',
#   'bitmesinnn:seviyorum',
#   'seni',
#   'turkcell):):)'],
#  ['aynen', ':)', 'kos', 'bi', 'turkcell', 'al', 'hemen:)'],
#  ['2',
#   'buçuk',
#   'aydır',
#   'tanımayan',
#   'turkcell',
#   'beni',
#   'sesimden',
#   'tanımış',
#   'bulunmaktadır!!',
#   'bunu',
#   'kutlamalı.'],
#  ['avea',
#   'kullanmaya',
#   'devam',
#   'edersen',
#   'çoooook',
#   'koparsın.',
#   'turkcell',
#   'le',
#   'bağlan',
#   'hayataa',
#   ':)'],
#  ['benim',
#   'dikkatimi',
#   'turkcell',
#   'cekti',
#   'huyumdan',
#   'sanirim',
#   'zirvedekiler',
#   'dikkatimi',
#   'ceker',
#   'takip',
#   'ederim:)'],
#  ['superonline',
#   'warken',
#   'ttnet',
#   'e',
#   'laf',
#   'dusmez',
#   'bence..',
#   'siddetle',
#   'tawsiye',
#   'ederim..'],
#  ["capstone'u", 'boşverip', "superonline'a", 'başladım', 'şuan,,ah', 'ahh'],
#  ['hayat', 'paylaşınca', 'güzel', 'ebruş', ':))))'],
#  ['diyorum',
#   'sana',
#   'bizim',
#   'baba',
#   'gelmicek',
#   'sene',
#   'bana',
#   'dedi',
#   'sen',
#   'halledersin',
#   'bana',
#   'söyle',
#   'isteklerini',
#   'benim',
#   'hat',
#   'turkcell',
#   ':)'],
#  ["'e",
#   'yasattigimiz',
#   'super',
#   'musteri',
#   'deneyimi',
#   'icin',
#   'onurlu',
#   'gururluyuz.',
#   'turkcell',
#   'superonline)'],
#  ['paylaşma',
#   'muhabbetinden',
#   'dolayı',
#   "turkcell'in",
#   'makarasını',
#   'yaptım',
#   'vapurda',
#   'gazete',
#   'rafı',
#   'olayı',
#   'iyi',
#   'oldu.',
#   'yancılık',
#   'kurumu',
#   'hala',
#   'yaşıyor',
#   ':)'],
#  ['bize', 'gec', 'turkcell', 'e', ':)))'],
#  ['oyle',
#   'huzurluyum',
#   'ki,',
#   'turkcell',
#   'bile',
#   'ariza',
#   'cikarmadi',
#   'kez,',
#   'derece!',
#   ':))'],
#  ['hattin',
#   'ne?',
#   'turkcell',
#   'i',
#   'tavsiye',
#   'ederim',
#   'degilsen',
#   'eger',
#   'ben',
#   'tr',
#   'e',
#   'tasittim',
#   'direk',
#   'memnunum',
#   ':)'],
#  ['yatak', 'aldim,', 'yorgan', 'yastigi', 'turkcell', 'verdi', ':)'],
#  ['ganga', 'superonline', 'alsın', 'yea', ':d'],
#  ['benım',
#   'bedava',
#   'sms',
#   'hakkım',
#   'var',
#   'turkcell',
#   'bana',
#   'yenı',
#   'yıl',
#   'hedıyeesınıı',
#   'erken',
#   'yollamıss',
#   'serefsızzz',
#   'hahahah\x1a'],
#  ['#turkcell',
#   '#ozturkmatik',
#   'reklami',
#   'allah',
#   'belanizi',
#   'vermesin!!',
#   'vapurda',
#   'deli',
#   'guldurdun',
#   'beni...'],
#  ['abi',
#   'gnctrkcll',
#   '2',
#   'bilet',
#   '8tl',
#   'mi',
#   'yaptın',
#   'pazartesi',
#   'sinemaya',
#   'gittiğine',
#   'göre',
#   ':d'],
#  ['hayat', 'paylaşınca', 'güzel', 'hayatım', ':))'],
#  ['evet',
#   'yeniden',
#   'pin',
#   'alacağım',
#   'sırf',
#   'bbm',
#   ':d',
#   'turkcell',
#   'hat',
#   'alacağım',
#   ':)'],
#  ['beni', 'bir', 'tek', 'dusunen', 'turkcell', 'ahey', 'ahey'],
#  ['bitanesinnnnnnnnnnnnnn:d', '#turkcell'],
#  ['5326833306',
#   'nolu',
#   'hattımın',
#   'ipone4',
#   's',
#   'kontratlı',
#   'tekliften',
#   'yararlanmak',
#   'istiyorum',
#   'teşekkürler'],
#  ['yeni', 'laptop', 'superonline', 'bağlanınca', 'görecem', 'seni', ':d'],
#  ['zaman', 'heryerden', 'böyle'],
#  ['hayat',
#   'paylaşınca',
#   'güzel',
#   'nara',
#   'naa',
#   'naa',
#   'na',
#   'na',
#   'turkcel',
#   'ceo',
#   'suyum',
#   'ben',
#   ':)'],
#  ['sadece',
#   'mutluluk',
#   'vaadi',
#   'veren',
#   'reklamlardan',
#   'baydim.bana',
#   'yaratici',
#   'reklam',
#   'mesajlariyla',
#   'gel.',
#   'bkz.',
#   'eti,',
#   'coca-cola,',
#   'turkcell'],
#  ['aıle', 'operatorumuz', 'turkcell', ':d'],
#  ['basit',
#   'bir',
#   'maile',
#   'bile',
#   'dönüş',
#   'yaparak',
#   'sorularıma',
#   'cevap',
#   'veren',
#   'superonline',
#   'müşteri',
#   'hizmetlerini',
#   'kutluyorum.',
#   '#supersinsuperonline'],
#  ['hayat', 'paylaşinca', 'güzel...geri̇si̇', 'teferruat...'],
#  ["superonline'a", 'geç', 'hayatını', 'yaşa', ':p'],
#  ['turkcell',
#   'sun',
#   'exspres',
#   'arasindaki',
#   'anlasmaya',
#   'bi',
#   'goz',
#   'at',
#   'hemen',
#   'fiyatlar',
#   'yari',
#   'yariya',
#   ';)'],
#  ['cocacola',
#   "turkcell'in",
#   'reklamcilarini',
#   'alinlarindan',
#   'opmek',
#   'istiyorum'],
#  ['bis', 'paketi', 'hakkında', 'bilgi', 'istiyorum'],
#  ['hayat', 'paylaşınca', 'güzel', 'lalalalalalalalalalaaaaaaaaaaaa', ':d'],
#  ['karşıyaka',
#   '10',
#   'bin',
#   'daire',
#   'turkcell',
#   'superonline',
#   'tanışmaya',
#   'hazır.',
#   'son',
#   '4',
#   'gün.'],
#  ['i̇yi',
#   "turkcell'in",
#   'hava',
#   'durumu',
#   'paketine',
#   'aboneyim.',
#   'olmasa',
#   'mesaj',
#   'atacak',
#   'bana'],
#  ['bugün',
#   'turkcell',
#   'müzik',
#   'konserlerinde',
#   "manga'yla",
#   'birlikteyiz',
#   'saat',
#   '15:00',
#   'itibariyle',
#   'manga',
#   'sizlerle',
#   'iyi',
#   'seyirler',
#   '(www.turkcellmuzik.com)'],
#  ['emme', 'benimki', 'turkcell', 'olanlar', 'düşünsün:)))'],
#  ['cnm',
#   'turkcell',
#   'magazalarnda',
#   'diger',
#   'telefn',
#   'magazalarnda',
#   'satılıo',
#   ':))'],
#  ['askıım', 'ay', 'acıcam', 'bı', 'turkcell', 'e', 'geciyim'],
#  ['beni', 'bekleyen', 'dogumgunu', 'pastam', 'icin', 'cok', 'tesekkurler'],
#  ['değilde',
#   'ben',
#   'turkcell',
#   'reklamında',
#   'zamanın',
#   'selocanlarındandım',
#   'ona',
#   'göre'],
#  ['bıde', 'turkcell', 'cekmıo', 'derler', 'dımı', 'sed', '(:'],
#  ['tutturamadim', 'ya.', 'kahretsin.', 'turkcell', 'iyi', 'tabii', ':d'],
#  ['can',
#   'sıkıntısından',
#   'ölmek',
#   'üzereyim.',
#   'turkcell-im',
#   'mi',
#   'varya',
#   'onun',
#   'gelsede',
#   'kurtulsam...'],
#  ['manga', 'turkcell', "muzik.com'da", 'saat', "15:00'te."],
#  ['#bukutudanevar', 'nin', 'sağlam', 'reklamı', 'oldu', '#turkcell'],
#  ['sayın',
#   'süreyya',
#   "ciliv'in",
#   'teşekkür',
#   'konuşmasındaki',
#   'mesajı',
#   'netti;',
#   "'siz",
#   'değerli',
#   'öğrenciler',
#   'içinizdeki',
#   'potansiyeli',
#   'keşfedin',
#   'kendinize',
#   "güvenin!'"],
#  ['çekmiyormuş',
#   'diyerek',
#   'çekmediğini',
#   'dedikodusunu',
#   'tasdik',
#   'eden',
#   'vodafone,',
#   'kalitelisi',
#   'pahalıymış',
#   'diyerek',
#   "turkcell'e",
#   'kaliteli',
#   'dedi',
#   'sanki?'],
#  ['he',
#   'valla',
#   'gectim.',
#   'lan?',
#   'turkcell',
#   'iyi',
#   'ya,',
#   'avea',
#   'apaci',
#   'isi',
#   'artik'],
#  ['demiş', 'turkcell', ';)', 'hayat', 'paylaşınca', 'güzel', ';)'],
#  ['çekmeyenin', 'reklamını', "turkcell'i", 'çekemeyenler', 'yapsın', ':)'],
#  ['ben', 'turkcell', 'e', 'taşıttım'],
#  ['iphone',
#   '4',
#   's',
#   'kanyon',
#   'turkcell',
#   'var',
#   'ilgilenenlere',
#   'duyurulur',
#   '..cok',
#   'kalabalik',
#   'tukenmeden',
#   'alin',
#   'derim',
#   '..'],
#  ['kalite', 'ortada', '#turkcellfestival'],
#  ['hayat', 'kesinlikle', 'paylaşınca', 'güzel', ':)'],
#  ['medyaplus',
#   'turkcell',
#   "superonline'dan",
#   '1',
#   'milyon',
#   'eve',
#   'fiber',
#   'internet'],
#  ['#pazarlamakonferansi',
#   'ndayiz',
#   'sabah.',
#   'turkcell',
#   'charlene',
#   "li'yi",
#   'getirmiş.'],
#  ['tesekkurler', 'turkcell'],
#  ['merhaba,',
#   'turkcell',
#   'i̇letişim',
#   'merkezlerimizde',
#   'cihaz',
#   'satışlarımız',
#   'bulunmaktadır.',
#   'teşekkür',
#   'ederiz.'],
#  ['önemli',
#   'değil',
#   'cnm..ne',
#   'demişler',
#   'hayat',
#   'paylaşınca',
#   'güzel:))yazımında',
#   'kendi',
#   'çapında',
#   'bir',
#   'karakteristiği',
#   'yok',
#   'değil:)))teşekkürler:p'],
#  ['bizim',
#   'blog',
#   'turkcell',
#   'blog',
#   'ödülleri',
#   'spor',
#   'dalında',
#   'ilk10a',
#   'girmiş,',
#   'kazananlar',
#   '5',
#   'ocak',
#   'perşembe',
#   'point',
#   "otel'de",
#   'yapılacak',
#   'törende',
#   'açıklanacakmış.'],
#  ['turkcell',
#   'cephesinden',
#   'beklemiyordum',
#   'böyle',
#   'bir',
#   'telefonu,',
#   'öneri',
#   'sağolasın!'],
#  ['iş', 'dönüşü', 'nimbuzz', 'la', 'bağlan', 'hayata', ';-)'],
#  ['kadi̇rle', 'bağlan', 'hayata', ':=))'],
#  ['"tesekkurler"', ';)'],
#  ['şarkıya',
#   'bayıldım',
#   'o_o',
#   'cok',
#   'yakında',
#   'turkcell',
#   'inde',
#   'yeni',
#   'yıl',
#   'jingle',
#   'cıkar',
#   'o-0'],
#  ['yeni',
#   'iyi',
#   'iphone',
#   '4s',
#   'interneti',
#   'birlikte',
#   '99',
#   "tl'den",
#   'başlayan',
#   'tekliflerle',
#   'turkcell',
#   'farkıyla....'],
#  ['superonline', ':)'],
#  ['bugün',
#   'kesilen',
#   'internet',
#   'kendi',
#   'kendine',
#   'yeniden',
#   'açıldı',
#   'süperonline',
#   'yaptığı',
#   'hatayı',
#   'kendi',
#   'kendine',
#   'anladı',
#   ':d'],
#  ['turkcell',
#   'zaman',
#   'cevap',
#   'verir',
#   'bizlerin',
#   'yanında',
#   'olur',
#   ':))',
#   'turkcell',
#   'candır',
#   ':))'],
#  ["konseri,bugünsaat15:00'tecanlı",
#   'yayınla',
#   'hayat',
#   'müziği',
#   'paylaşınca',
#   'güzel',
#   ':)'],
#  ['turkcell', 'beni', 'sesimden', 'tanir.'],
#  ['#turkcell',
#   'attıgı',
#   'yıl',
#   'bası',
#   'mesajlarını',
#   'özledim.',
#   'burdaki',
#   '#rogers',
#   '#bell',
#   'filan',
#   'yalan...'],
#  ['ortaya',
#   'çıktığından',
#   'beri',
#   'turkcell',
#   'beni',
#   'yalnız',
#   'bırakmayan',
#   '"city',
#   'ville"',
#   'isteklerine',
#   'burdan',
#   'teşekkürlerimi',
#   'iletiyorum,',
#   'sağolun',
#   'var',
#   'olun.'],
#  ['goturun', 'bizi', 'gidelim', 'vallaaa', 'gnctrkcll'],
#  ['abe',
#   'ben',
#   'nedem',
#   'yaw',
#   'sorun',
#   'bende',
#   'değil',
#   'superonline',
#   'bekliyem',
#   ':)'],
#  ['ailem', 'turkcell.', 'benim', 'baska', 'hatta', 'gecmem', 'olmaz', ':d'],
#  ['turkcell', 'le', 'baglansak', 'hayata', 'hersey', 'kolay', 'olur:)'],
#  ['süperonline',
#   'interneti',
#   'ttnet',
#   'e',
#   'kiralıyormuş',
#   'ben',
#   '2',
#   'ay',
#   'önce',
#   'geçtim',
#   'süperonline',
#   'a',
#   'memnunum:)'],
#  ['turkcel', 'kanka'],
#  ['alsana',
#   'lan',
#   'beklıyosun',
#   ':d',
#   'hatta',
#   'yanında',
#   'bıde',
#   'hat',
#   'l',
#   'turkcell',
#   'olursa',
#   'sevınırım',
#   ':d'],
#  ['evet',
#   'tahmin',
#   'etmistim',
#   'bunu',
#   ':d',
#   'orda',
#   'yok',
#   'bb',
#   'icin',
#   'boyle',
#   'hat',
#   'kampanyalari',
#   ':/',
#   'turkcell',
#   'europe',
#   'uygulamaya',
#   'gecti',
#   'mi',
#   'super',
#   'zaman'],
#  ['aa',
#   'nasi',
#   'kacirdik',
#   'yaa!bizim',
#   'ayibimiz',
#   'olsun',
#   'doomgnn',
#   'kutlu',
#   'mutlu',
#   'olsun',
#   'selocan;))'],
#  ['arkadaş',
#   'tcell',
#   'bir',
#   'kere',
#   'bile',
#   'yaşamadığım',
#   'eziyeti',
#   'vodafone',
#   'yaşattı',
#   'bana..',
#   'kısa',
#   'zamanda',
#   'tekrar',
#   'dönücem'],
#  ['21',
#   'milyon',
#   '913',
#   'bin:',
#   'billboardlarındaki',
#   'sevgi',
#   'sözcüklerinin',
#   '20',
#   'günde',
#   'ücretsiz',
#   'resimli',
#   'mesaj',
#   'olarak',
#   'gönderilme',
#   'sayısı.'],
#  ['#vodafone',
#   'yeterince',
#   'başarılı',
#   'olabildi',
#   'mi',
#   'bilmiorum',
#   "#turkcell'den",
#   'sinir',
#   'bozucu',
#   'reklam',
#   'yapabilmekte',
#   'epey',
#   'başarılılar',
#   'orası',
#   'net..'],
#  ['superonline', 'tabii', 'kii!'],
#  ['tabi',
#   'canım',
#   'yüzden',
#   'genç',
#   'turkcell',
#   'kampanyasıyla',
#   'gidiyoruz',
#   'sinemaya',
#   ':))))'],
#  ['evet', 'begendim'],
#  ['hahahahah',
#   ':d',
#   'birisi',
#   'benimle',
#   'turkcell',
#   'bayisine',
#   'gelirse',
#   'bbmimi',
#   'actiririm',
#   'tek',
#   'basima',
#   'ı-ıhh'],
#  ['coca', 'cola', 'turkcell', 'cok', 'guzel', 'reklam', 'yapiyo', ':)'],
#  ['turkcell`in',
#   'abone',
#   'sayisi',
#   'cook',
#   'oldugu',
#   'icin',
#   'yuzde',
#   'olarak',
#   'sayilar',
#   'kucuk',
#   'kalacak,',
#   'istediginiz',
#   'mudur?'],
#  ['20',
#   'saatte',
#   'bir',
#   'bayi',
#   'açan,',
#   '2',
#   'saatte',
#   'bir',
#   'baz',
#   'istasyonu',
#   'diken',
#   'bir',
#   'türlü',
#   'çekemeyen',
#   'bir',
#   'operatör',
#   'varmış.',
#   'acınası',
#   'çok.',
#   'büyüksün'],
#  ['3',
#   'sene',
#   'önce',
#   'turkcell',
#   'reklemi',
#   'vardı',
#   '2',
#   '0',
#   '0',
#   '9',
#   'hazırız',
#   'bekliyoruz',
#   'diye:)',
#   'çabuk',
#   'gecmis,',
#   'simdi',
#   'çabuk',
#   'gecer',
#   'umarimm'],
#  ['i̇stanbul',
#   'sanayi',
#   "odası'na",
#   'göre',
#   "2011'in",
#   'inovatif',
#   'şirketi',
#   'turkcell',
#   'teknoloji',
#   'oldu.',
#   'tebrikler:)'],
#  ['2011',
#   'turkcell',
#   'blog',
#   "ödülleri'nde",
#   'ilk',
#   "3'te",
#   'yokuz.',
#   'dilimin',
#   'ayarı',
#   "yok'u",
#   '143',
#   'blog',
#   'arasından',
#   'ilk',
#   "10'a",
#   'taşıyan',
#   'herkese',
#   'teşekkürler...',
#   ':))'],
#  ['soğuk',
#   '1',
#   'sıcak',
#   'kahveye',
#   'ısınırsın',
#   'hayat',
#   'paylaşınca',
#   'güzel',
#   'kahvemi',
#   'paylaşabilirim',
#   'seninle',
#   '<3'],
#  ['dünyaya',
#   'liderlik',
#   'eden',
#   'operatör!:',
#   'turkcell',
#   'superonline,',
#   'türkiye’yi',
#   'bir',
#   'fiber',
#   'internetin',
#   'liderleri',
#   'arası...'],
#  ['ben', '3,5g', 'hızındayım', 'memnunum.', 'teşekkürler', 'turkcell', ':))'],
#  ['oy',
#   'oyy',
#   '90lar..',
#   ':))',
#   'maşallah',
#   'afiyet',
#   'olsun',
#   'kuzum',
#   'hayat',
#   'paylaşınca',
#   'güzel',
#   'hehe',
#   ':pp'],
#  ['nolursa', 'olsun', 'turkcell', 'candır', ':)'],
#  ['hayat', 'paylaşınca', 'güzel'],
#  ['beni', 'bağrınıza', 'bastığınız', 'muck'],
#  ['hayat', 'yeni', 'yıl', 'mutlulugunu', 'paylaşınca', 'güzellll', ':)))'],
#  ['\x1a',
#   '\x1ahayat',
#   'paylaşınca',
#   'güzel',
#   'la',
#   'la',
#   'laaa',
#   'laa',
#   '\x1a',
#   '\x1a'],
#  ['heee',
#   'mesele',
#   'evet',
#   'ttneti',
#   'kapattırdık',
#   'yerine',
#   'superonline',
#   'bağlattırdık',
#   'hamdolsun',
#   'ayrılık',
#   'bi',
#   'hafta',
#   'sürdü',
#   ':d',
#   'geri',
#   'döndüm',
#   'gene',
#   ':d'],
#  ['reklam', 'sloganının', 'ötesindeymiş,', 'hayat', 'paylaşınca', 'güzel'],
#  ['***alem***',
#   'artık',
#   'daraldıysan',
#   'herşeyden',
#   'eğerki',
#   'bıktıysan',
#   'kotuysan',
#   'hayattan,,,',
#   'türkselle',
#   'bağlan',
#   'hayata',
#   ':)'],
#  ['hayat', 'paylaşınca', 'güzel', ':))'],
#  ['hayat', 'paylaşınca', 'güzel', 'la', 'la', 'la', 'la', 'la', 'la.'],
#  ['kötü',
#   'espiri',
#   'yapanları',
#   'seçiyorlar',
#   'yaw',
#   'nokiada',
#   '3',
#   'hafta',
#   'boyunca',
#   'çektiğimi',
#   'gördün',
#   'sn',
#   'turkcell',
#   '15',
#   'dakikada',
#   'hediye',
#   'etti',
#   ':)'],
#  ['superonline', 'cok', 'iyi'],
#  ['turkcell',
#   'isi',
#   'biliyor.',
#   "4'te",
#   'aynı',
#   'sey',
#   'olmuştu.',
#   'kontratli',
#   'alicaksan',
#   'turkcell',
#   "'de",
#   'rahat',
#   'bulursun.'],
#  ['seni',
#   'seviyorum',
#   'turkcell',
#   'ben',
#   'tl',
#   'derdine',
#   'düşmüşken',
#   '600',
#   'dakikam',
#   'oldu',
#   ',iyiki',
#   'varsın'],
#  ['uygun',
#   'iphone4s',
#   'paketi',
#   'sanırım',
#   'gold',
#   'paket:turkcell:5000dk',
#   'yöne:2000dk',
#   'data:4gb',
#   'iphone',
#   '4s',
#   '16gb',
#   '177',
#   'tl'],
#  ['zaman', "turkcell'le", 'bağlan', 'hayata:d'],
#  ['bugün', "turkcell'de", '"hayat', 'paylaşınca', 'güzel"', 'anı', 'yaşadım'],
#  ['bebeğimmm',
#   'güzel',
#   'bunları',
#   'duyunca',
#   'bnm',
#   'keyfim',
#   'yerine',
#   'geliyo',
#   'hayat',
#   'paylaşınca',
#   'güzel',
#   'lalalalalaaayy',
#   'hahahah',
#   ':d'],
#  ['turkcell', ':)'],
#  ['hahaha', 'kanka', 'turkcell', '4', 'ceker', ':d'],
#  ['turkcell',
#   'bayileri',
#   'ucuzu.',
#   "selin'in",
#   'blackberry',
#   'oradan',
#   'aldım',
#   'ben'],
#  ['hizliyim',
#   'hayirsiz',
#   'degilimm',
#   ':)',
#   'bencede',
#   'goruselim',
#   ':)',
#   'turkcell',
#   'boy',
#   ':)'],
#  ['i̇nandirici', 'marka', 'yi̇ne', 'turkcell', 'zaman', 'turkcell'],
#  ['turkcell',
#   'cvp',
#   'atmis.',
#   'knka',
#   'sitemzden',
#   'bakabilirsiniz',
#   ':p.',
#   'hala',
#   'kitaptayim'],
#  ['burda', 'turkcell', 'olaydi', 'iyiydi.'],
#  ['allahtan', 'gencim', "turkcell'liyim", ':)', 'eglenmenize', 'sevindim'],
#  ['i̇novasyonda', 'büyük', 'ödül', "turkcell'in", 'kurumsal-'],
#  ['#turkcellmuzik',
#   "turkcell'e",
#   'teşekkürler',
#   '"fly',
#   'to',
#   'stay',
#   'alive"',
#   'güzel',
#   'anadolu',
#   'kartallarında',
#   'duyduğmda',
#   'resmen',
#   'uçmuş',
#   'oldm',
#   'fly',
#   'baby',
#   'fly'],
#  ['sevdiğim',
#   'şarkı',
#   "kubat'ın",
#   'hayat',
#   'paylaşınca',
#   'güzel',
#   'şarkısı.',
#   'son',
#   'aldığım',
#   'albüm,',
#   "kubat'ın",
#   '"hayat',
#   'paylaşınca',
#   'güzel"',
#   'albümü.'],
#  [':d', 'kediyi', 'getir', 'gidelim', 'türkcell', 'bayiye', ':))'],
#  ['bir',
#   'tim',
#   'calisani',
#   'bana',
#   'kahve',
#   'ismarliyor',
#   ':))',
#   'tesekkurler',
#   '=)',
#   'kahve',
#   'dünyası)'],
#  ['haftasonu',
#   'farklı',
#   'geçsin',
#   'istiyorsanız',
#   'gidin',
#   'suç',
#   "ceza'yı",
#   'okuyun',
#   'bitirin',
#   'sonra',
#   'bana',
#   'anlatın',
#   'hayat',
#   'paylaşınca',
#   'güzel',
#   'lalalalalaaa'],
#  ['çarsamba',
#   'gecesi',
#   'suadiye',
#   'türkcell',
#   'çalısanlarının',
#   'düzenlemiş',
#   'olduğu',
#   'karaoke',
#   'gecesinde',
#   'görüşmek',
#   'üzere,,,,'],
#  ['pazarlama',
#   'i̇lkeleri',
#   'dersimize',
#   'konuk',
#   'olarak',
#   'öğrencilerimize',
#   'dijital',
#   'pazarlama',
#   'i̇letişimi',
#   'vizyonu',
#   'katan',
#   'teşekkürler'],
#  ['küçük',
#   'kardeşim',
#   'geldi',
#   '"oyundayım',
#   'ayten"',
#   'dedi',
#   'bana.',
#   'oğlum',
#   '3',
#   'yaşındasın',
#   'yaşına',
#   'göre',
#   'davran',
#   ':)',
#   'turkcell',
#   'reklamı',
#   'hastası',
#   'nolcak:)'],
#  ['snn',
#   'icin',
#   'gnctrkcll',
#   'hat',
#   'alicam',
#   'ahahaha',
#   'huzurumsun',
#   'muah!'],
#  [':)))',
#   ':(((',
#   'hayat',
#   'paylaşınca',
#   'güzel',
#   'mutlu',
#   'olmak',
#   'varken',
#   'bizler',
#   'kıymetini',
#   'bilmeyiz'],
#  ["diyarbakir'a", 'gidiyoruz!', 'gece', 'turkcell', 'icin', 'sahne!', ';)'],
#  ["mudo'dan",
#   'iki',
#   'hediye',
#   'alan',
#   "turkcell'lilere",
#   'üçüncüsü',
#   'hediye'],
#  ['i̇novasyonda',
#   'büyük',
#   'ödül',
#   "turkcell'in..bakalim",
#   'sene',
#   'hangi',
#   'firma',
#   'alacak?'],
#  ['e',
#   'ozaman',
#   'senin',
#   'karsına',
#   'cıkan',
#   'denyoların',
#   'türkcell',
#   'in',
#   'yöne',
#   'msj',
#   'kampanyasından',
#   'haberleri',
#   'yoktu:d:d:d'],
#  ['#teknoloji',
#   "samsung'un",
#   'kompakt',
#   'cebi',
#   'galaxy',
#   'y',
#   'qwerty',
#   'klavyeli',
#   'cep',
#   'ch',
#   'turkcell',
#   'avantajlarıyla',
#   "türkiye'de!"],
#  ['sagolsun', 'bir', 'turkcell', 'beni', 'yalniz', 'birakmiyor.'],
#  ['$u',
#   'turkcell',
#   'reklamina',
#   'bayiliyorum..',
#   '"mekanigini',
#   'anlayamadin"',
#   'hahahaha',
#   'ozturkselli',
#   'olmak',
#   'istiyorum',
#   ':d'],
#  ['3g',
#   'problemleri',
#   'icin',
#   'basvurabiliriz?',
#   'kayseri/talas',
#   'erciyes',
#   'unv.',
#   'civarı',
#   '5',
#   'gündür',
#   'edge.',
#   'turkcell',
#   'bile',
#   'çekiyor',
#   'yahu',
#   ':)',
#   'help..'],
#  ['öztürkcell', 'e', 'geçmenin', 'vakti', 'geldide', 'geçiyor', ':))'],
#  ['gencler',
#   'kendini',
#   'genc',
#   'hisseden',
#   'herkes',
#   'gnctrkcll',
#   'li',
#   'degil',
#   'mi;))'],
#  ['hayat', 'paylaşınca', 'güzel', ';)'],
#  ['#2012tahminleri',
#   "turkcell'deki",
#   'sesli',
#   'komut',
#   'anlama',
#   'sistemi',
#   'hayatın',
#   'alanına',
#   'yayılacak.'],
#  ['#turkcell', 'mudo', 'indirimin', 'güzel', 'olmuş', 'valla', 'ya.'],
#  ['geç',
#   'kurtul',
#   'tarık',
#   'abi',
#   'ellerinden',
#   'ben',
#   'öyle',
#   'yaptım',
#   'an',
#   'rahatım'],
#  ['adam',
#   'düzenli',
#   'olarak',
#   'turkcell',
#   'iletişim',
#   'merkezine',
#   'keyfinin',
#   'mekanına',
#   'gidiyor...'],
#  ['turkcell', 'kendini', 'aşmış'],
#  ['di̇kkat!',
#   'ti̇vi̇t',
#   'kiskançlik',
#   'i̇çerebi̇li̇r..fizy',
#   'nin',
#   'kapatılması',
#   'bir',
#   'pr',
#   'çalışması',
#   'mıydı',
#   'acaba?türksel',
#   'zekisin..'],
#  ['sen', 'yine', 'turkcell', 'e', 'mi', 'döndün', 'kanki'],
#  ['muhendisler',
# ...
#   'olan',
#   'ilişkimi',
#   'bitiriyorum,ilanen',
#   'duyrulur..'],
#  ['ondan',
#   'önce',
#   'seninle',
#   'bi',
#   'turkcell',
#   'hattan',
#   'konuşmamız',
#   'gereek',
#   'geçen',
#   'gün',
#   'senle',
#   'mesajlaştıktan',
#   'sonra',
#   'bütün',
#   'kontrlerim',
#   'bitti',
#   ':d'],
#  ['#hayatpaylasincaguzel', '3g', 'm', 'calismiyor', 'turkcell', 'duy', 'beni'],
#  ['uzgunum',
#   'aslinda,',
#   'nursen',
#   'duy',
#   'beni',
#   'turkcell',
#   'bizi',
#   'ayirmasin',
#   'artik,',
#   'beril',
#   'sende',
#   'ac',
#   'su',
#   'telefonu',
#   'soru',
#   'cozucektin',
#   'bana'],
#  ['canım',
#   'sevgilim',
#   'turkcell',
#   'yeter',
#   'artık',
#   'terket',
#   'beni!',
#   'birinden',
#   'msj',
#   'beklediğim',
#   'bi',
#   'zaman',
#   'atarsın',
#   'msjlarını.'],
#  ['bir',
#   'haftadir',
#   'gezdigim',
#   '4.',
#   'turkcel',
#   'timdeym',
#   'kimse',
#   'modem',
#   'teslimi',
#   'almaya',
#   'yanasmiyor',
#   'beceremiyor',
#   'istemiyolar...adami',
#   'cildirttilar'],
#  ['kimbilir',
#   'kaç',
#   'para',
#   'olacak',
#   'ayağına',
#   'kadar',
#   'getiriyorlar',
#   'turkcell',
#   "ti̇m'de",
#   'saatlerce',
#   'bekletiyorlar',
#   'bir',
#   'işlem',
#   'için..'],
#  ['kubatin',
#   'sesiyle',
#   'katkida',
#   'bulundugu',
#   'igrenc',
#   'turkcell',
#   'reklami',
#   'kaldrilsin'],
#  ['bi', 'uyarsaydın', 'hani', 'turkcell!', ':s'],
#  ['#turkcell',
#   'in',
#   'hayat',
#   'paylasinca',
#   'guzel',
#   'reklami',
#   'emotional',
#   'selling',
#   'olayini',
#   'fazla',
#   'abartmis!bilincaltina',
#   'calismasi',
#   'gerekirken,kor',
#   'goze',
#   'parmak',
#   'sokms'],
#  ['268,60', 'tl', '#turkcell', 'faturam.', 'amk'],
#  ['bravo', '12.', 'katta', 'bile', 'cekmiyosun', 'ya,', 'pessss'],
#  ['pis', 'adama', 'bulastin', 'trcell;)'],
#  ['turkcelde',
#   'bir',
#   'hizmet',
#   'ucretle',
#   'sessz',
#   'sedasiz',
#   'bulusms',
#   'oldu',
#   '7565',
#   'telesekreter',
#   'aman',
#   'dkt'],
#  ['kadar',
#   'yaparsa',
#   'yapsın',
#   "türkiye'nin",
#   'internetinden',
#   'bi',
#   'çacık',
#   'olmaz.i̇nternet',
#   ',teknoloji',
#   'geride',
#   'bi',
#   'istihbarat',
#   'desen',
#   'seviye',
#   '1...'],
#  ['ohh',
#   'allaha',
#   'sukur',
#   'turkcell',
#   'selo',
#   'canlarina',
#   'yilbasi',
#   'reklami',
#   'yapmamiss',
#   ':)',
#   'buyuk',
#   'eksiklikkk',
#   'anlatamam'],
#  ['turkcell',
#   'vodafone',
#   'u',
#   'baş',
#   'göz',
#   'etmek',
#   'lazım',
#   'ekürim.',
#   'zaman',
#   'beraber',
#   'kurtuluruz',
#   'bunlardan',
#   ':))'],
#  ['bir',
#   "türkcell'i",
#   'olarak',
#   'aveanın',
#   'yeni',
#   'reklamına',
#   'bayıldım.',
#   'i̇yi',
#   'g.t',
#   'etmiş',
#   'şerefsizler.',
#   ':d'],
#  ['arada',
#   '3430',
#   'omurilik',
#   'felçlilerine',
#   'gönderilen',
#   'sms',
#   'den',
#   '2',
#   'sms',
#   'bedel',
#   'kesmek',
#   'nedir',
#   '#turkcell'],
#  ['elim',
#   'telefona',
#   'gidiyor',
#   'şunu',
#   'bir',
#   'arasam',
#   'diyorum',
#   'hemen',
#   'turkcell',
#   'mantığımı',
#   'harakete',
#   'geçiriyor',
#   'no',
#   'many',
#   ':('],
#  ['laaan',
#   'turkcell',
#   'kendi',
#   'kendine',
#   'mms',
#   'lerimi',
#   'yiyo',
#   'sikicem',
#   'busefer',
#   'kavga',
#   'etmicem'],
#  ['sabah',
#   'vapurda',
#   'turkcell',
#   'hayat',
#   'paylaşınca',
#   'güzel',
#   'diyerek',
#   'gazete',
#   'dağtyor',
#   'cumhuryet',
#   'hariç',
#   'bence',
#   'güzel',
#   'değil.'],
#  ['turkcell',
#   'in',
#   'onca',
#   'sacmaligindan',
#   'sonra',
#   'vodafone',
#   'tek',
#   'bi',
#   'kabahat',
#   'islemis',
#   'bise',
#   'mi.',
#   'op',
#   'basina',
#   'koy',
#   'bence',
#   ':)'],
#  ['eksik',
#   'bilgi',
#   'sonrası',
#   'maduriyetiniz',
#   'özür',
#   'dileriz',
#   'yok!',
#   'azından',
#   'bundan',
#   'sonra',
#   'işlemlerin',
#   "'extra'",
#   'taife',
#   'dışı'],
#  ['götürdüler',
#   'aldıkları',
#   'turkcel',
#   'bayiine',
#   'program',
#   'çökmüş',
#   'içinde',
#   'demişler',
#   'geri',
#   'gönderdiler',
#   'tel'],
#  ['iphone', 'paket', 'aboneliginiz', 'iptal', 'edilmistir.', 'demek'],
#  ["i̇zmir'in",
#   'sokaklarında',
#   "turkcell'in",
#   'özel',
#   'aşkımlı',
#   'canımlı',
#   'bitanemli',
#   'kelimeleri',
#   'yok',
#   'lan'],
#  ['zamman',
#   'tunelını',
#   'ıptal',
#   'etmek',
#   'ıstıyorum',
#   'yardımcı',
#   'olurmusunuz'],
#  ['yok',
#   'yolda',
#   'kaldık',
#   'gel',
#   'lastik',
#   'değiş',
#   'desek',
#   'anlarız',
#   'zor',
#   'iş',
#   'basit',
#   'turkcell',
#   'seni',
#   'mahvetmiş',
#   'adamım'],
#  ['50tl',
#   'yakıt',
#   'alıyoruz',
#   '50dakika',
#   'kazanmak',
#   'şifre',
#   'yolluyoruz.',
#   'sonra',
#   'mesaj',
#   'geliyor',
#   'arama',
#   'yapıyoruz',
#   'kontör',
#   'gidiyor',
#   'kazanılan',
#   'dk'],
#  ['kapalı',
#   'alanlarda',
#   'sıkıntılı',
#   'yine',
#   'işimi',
#   'görüyor.',
#   "avea'nın",
#   'benzer',
#   'paketi',
#   "turkcell'de",
#   '55',
#   'lira.'],
#  ['i̇nsan',
#   'kendisine',
#   'kazık',
#   'atanlardan',
#   'vaz',
#   'geçemiyor.',
#   'mesela',
#   'türksel.',
#   'soktukca',
#   'sokuyorlar.',
#   'vazgeçilmez.',
#   'herkes',
#   'türksel.'],
#  ['edge',
#   'hizinda',
#   'internetin',
#   'allah',
#   'belasini',
#   'versin.',
#   'turkcell',
#   'duy',
#   'sesimi'],
#  ['bir',
#   'sure',
#   'once',
#   'ben',
#   'ayni',
#   'durumdaydim',
#   'amac',
#   'nedir',
#   'bilniyorum:(',
#   'sonra',
#   'kesildi',
#   'aramalar...'],
#  ['turkcell',
#   'sasmis',
#   'lan',
#   '30',
#   'tlye',
#   'internet',
#   'paketi',
#   'mi',
#   'olur'],
#  ['ayni',
#   'sorunu',
#   'ayin',
#   'yedisinde',
#   'bildirmistim',
#   'su',
#   'an',
#   'cozulmedi',
#   'turkcell',
#   'mobil',
#   'tv',
#   'uygulamasinda',
#   'lig',
#   'tv',
#   'den',
#   'mac',
#   'izlerken',
#   'ekran'],
#  ['turkcell', 'tam', 'kaltak', ':d'],
#  ['hahahahah',
#   ':d',
#   'yemin',
#   'ederim',
#   'bok',
#   'superonline',
#   'ttnet',
#   'iyidi',
#   ':d'],
#  ['mesajlarım',
#   'iletilmiyor',
#   'boktan',
#   'bir',
#   'operatördür',
#   'turkcell',
#   '!!!'],
#  ['umarim', 'mesajdan', 'sonra', 'bana', 'geri', 'donus', 'yaparlar'],
#  ['cok', 'sovdugun', 'tcell', 'e', 'geri', 'mi', 'dondun', ':d'],
#  ['bırak',
#   'bis',
#   'nedir',
#   ',ara',
#   'git',
#   "tcell'e",
#   'faturayı',
#   'kesip',
#   'göndersin',
#   'hallederiz',
#   ':d'],
#  ['lanet',
#   'olası',
#   'bir',
#   'turkcell',
#   'li',
#   'olarak',
#   'vallahi',
#   'aynı',
#   'nağmelerden',
#   'sıkıldım',
#   'lan..',
#   'üşenmesem',
#   'sırf',
#   'cıvık',
#   'reklam',
#   'geçicem.'],
#  ['yalancı',
#   'superonline',
#   '14',
#   'aydır',
#   'sınırsız',
#   'olan',
#   'internt',
#   'hızını',
#   'düşürmeye',
#   'başladılar',
#   'kotasız',
#   'olan',
#   'bağlantımın',
#   'kotasını',
#   'aşmışım'],
#  ['ilk', 'tek', 'askim', 'olan', 'turkcell', 'birak', 'artik', 'pesimii'],
#  ['benim',
#   'bulunduğum',
#   'şehirde',
#   'yok',
#   'ee',
#   'şansımı',
#   'kayıp',
#   'etmiş',
#   'oluyorum:(('],
#  ['bukadr',
#   'yuksekk',
#   'fiyataa',
#   'helal',
#   'olsnnn',
#   'kampanyaa',
#   'dieee',
#   'yolladnzz'],
#  ['hayır', 'yaaa', 'turkcell', 'gayet', ':('],
#  ['burdan',
#   'gsm',
#   'operatörlerine',
#   'sesleniyorum.',
#   'sen',
#   'turkcell',
#   'sen',
#   'vodafone',
#   'sende',
#   'avea.',
#   'vapurda',
#   'artik',
#   'telefonlar',
#   'çeksin.',
#   'you',
#   'can',
#   'easily',
#   'realize.'],
#  ['kendilerinden',
#   'haberleri',
#   'yok',
#   '“',
#   'turkcell',
#   'superonline',
#   'bolge',
#   'yetkili',
#   'bayisinin',
#   'beni',
#   '542',
#   'li',
#   'numaradan',
#   'aramasina',
#   'demeli”'],
#  ['internet',
#   'kadar',
#   'yavaş',
#   'premium',
#   "account'dan",
#   'download',
#   'yaptığım',
#   'halde',
#   'free',
#   "user'dan",
#   'bi',
#   'farkım',
#   'yok',
#   'resmen',
#   '#superonline'],
#  ['yaaaaaa',
#   'tam',
#   'kızıp',
#   'iphone4s',
#   'almayacağım',
#   'dediğim',
#   'anda',
#   'bana',
#   'yapılamaz!',
#   'isyan',
#   'ediyorum!'],
#  ['#parasineyseverelimde',
#   'türkcell',
#   'boş',
#   'yere',
#   'ikide',
#   'bir',
#   'mesaj',
#   'göndermesin!!!'],
#  ['2012', "ayvalık'ında", 'turkcell', 'çekmiyor'],
#  ['27',
#   'ağustos,',
#   'turkcell',
#   'tarife',
#   'bitişi.',
#   'dokuz',
#   'yıl',
#   'önceki',
#   '250',
#   'tl',
#   'yi',
#   'bir',
#   'türlü',
#   'unutamadım.',
#   'ihanet',
#   'edersem',
#   'unutabilirim'],
#  ['o.c.',
#   'turkcell',
#   '2',
#   'senedır',
#   'bana',
#   'evde',
#   'vınn',
#   'kullandırıyosun',
#   'ınsallah',
#   'batarsın'],
#  ['yok', 'dava', 'acmam', 'terk', 'ederim'],
#  ['twitten',
#   'sonra',
#   'dönmeyecekler',
#   "dönmesinler,turkcell'e",
#   'aylar',
#   'oldu',
#   'başvuralı,hiç',
#   'başvurmayanı',
#   "turkcell'e",
#   'aldılar,bana',
#   'hala',
#   'dönmediler!'],
#  ['lazım',
#   ':))',
#   "acun'a",
#   'milyon',
#   'verecez',
#   'faturada',
#   'bize',
#   'döşüyor',
#   'turkcell',
#   ':)'],
#  ['>>faturala,',
#   'müsteri',
#   'uyanık',
#   'cıkıp',
#   'hakkında',
#   'ısrar',
#   'ederse',
#   'uzatmadan',
#   'faturadan',
#   'düş.',
#   'ben',
#   'uzatmadaım,',
#   'cunku',
#   "türkiye'de",
#   'artık',
#   '>>'],
#  ['bir',
#   'gün',
#   'turkcell',
#   'şöyle',
#   'bir',
#   'msj',
#   'atıcak;',
#   'kadar',
#   'msj',
#   'attım',
#   'cevap',
#   'vermiyorsun.!'],
#  ['sozlesmesini',
#   'yaptiginiz',
#   'aramadiginiz',
#   'aramalarina',
#   'donmediginiz',
#   'aboneleriniz',
#   'dahil',
#   'mi',
#   'buna'],
#  ['yapsam',
#   'istek',
#   'gecersizdir',
#   'diyo',
#   'twitter,',
#   'sokucam',
#   'once',
#   'twitter',
#   'a',
#   'sonra',
#   'turkcell',
#   'e'],
#  ['cep',
#   'telefonuma',
#   'gelen',
#   'mesajlardaki',
#   'kıran',
#   'kırana',
#   'kapışma,',
#   'emniyet,',
#   'garanti',
#   'bankası,',
#   'turkcell',
#   'beşiktaş',
#   'bld',
#   'arasında',
#   'devam',
#   'ediyor.'],
#  ['20',
#   'mbit/s',
#   'fiber',
#   'internet',
#   'hattimdan',
#   'hala',
#   'buffer',
#   'beklemeden',
#   'video',
#   'seyredemiyorum',
#   '#rezalet',
#   '#superonline'],
#  ['in',
#   'yaptigi',
#   'seyahat',
#   'kampanyasi',
#   'yerinde',
#   'aralik',
#   'ayinda',
#   'uyguladiklari',
#   'sistem',
#   'cok',
#   'yanlis.'],
#  ['neredeyse',
#   'kurulduğundan',
#   'beri',
#   'turkcell',
#   'kullandım',
#   'gece',
#   'mobil',
#   'modemle',
#   'saatlerdir',
#   '56',
#   'k',
#   'modem',
#   'bağlanınca',
#   'seni',
#   'terk',
#   'zamadır'],
#  ['3tl', 'durduk', 'yere', 'gitti', 'turkcell', 'sürekli', 'soyuyo', ':)'],
#  ['beni', 'kucakladı.', 'pess!'],
#  ['hayat',
#   'paylaşınca',
#   'güzel',
#   'iğrençliğinin',
#   'yanında',
#   'oskar',
#   'alır',
#   'fasulye',
#   'reklamı',
#   ':)'],
#  ['varmı',
#   'turkcellde',
#   'öyle',
#   'temsilci',
#   'bir',
#   'sorun',
#   'çözemeyen',
#   'çözemezde',
#   'vatandası',
#   'sömürmek',
#   'üzerine',
#   'kurulu',
#   'düzende',
#   'başka',
#   'paket',
#   'sunalım'],
#  ['ay',
#   'turkcell',
#   'faturamda',
#   'kendi',
#   'rekorumu',
#   'kırdım',
#   'heyoooo',
#   '(ölçü',
#   'kullanmak',
#   'gerekirse',
#   'de:',
#   'kol',
#   '....dıt',
#   'dıt',
#   'dırıt',
#   'dıt.'],
#  ['kadarıda',
#   'olmaz',
#   'turkcell',
#   'reklamında',
#   'telefonla',
#   'ses',
#   'kalitesi',
#   'yapan',
#   'reklam',
#   'filmi',
#   'çakma',
#   'çıktı',
#   ':d',
#   'buyrun',
#   'kanıtı'],
#  ['superonline', 'fiber', 'rezalet', 'devam', 'ediyor'],
#  ['arada',
#   'telefonumu',
#   'açtım,',
#   'turkcell',
#   'art',
#   'arda',
#   '5',
#   'mesaj',
#   'attı.',
#   'korkmaya',
#   'başladım.',
#   'ben',
#   "turkcell'i",
#   'arkadaş',
#   'olarak',
#   'sevmiştim',
#   'ama:('],
#  ['"ayda',
#   'saaaadece',
#   '20',
#   'liraya',
#   'yöne',
#   '200',
#   'dakika',
#   'artııı',
#   '100',
#   'sms',
#   'veeeee',
#   'tam',
#   'tamına',
#   '100',
#   'mb',
#   'internet"diye',
#   'reklam',
#   'yapan',
#   'türkcell',
#   'kafası',
#   'yaşıyor?'],
#  ['kimselere',
#   'vermediğim',
#   'diğer',
#   'numaramı',
#   'vereyim',
#   'ben',
#   'sana',
#   'ordan',
#   'şaapalım',
#   "turkcell'in",
#   'boku',
#   'çıktı',
#   'zaten.'],
#  ['turkcell', 'harbi', 'pic'],
#  ['merhabalar,',
#   'internet',
#   'paketlerinde',
#   'bir',
#   'düzenlemeye',
#   'gitmezseniz',
#   '12',
#   'senelik',
#   'bir',
#   "'turkcell'liyi",
#   'artık',
#   'tamamen',
#   'kaybedeceksiniz'],
#  ["mecidiyeköy'de",
#   'edge.',
#   "asmalı'da",
#   'edge.',
#   'taksim',
#   'göbeği',
#   '18.',
#   'katta',
#   'arşta',
#   'yine',
#   'edge.',
#   'bazen',
#   'canımı',
#   'sıkıyorsun',
#   '#turkcell'],
#  ['afedersin', 'turkcell', 'cok', 'kazik', ':d'],
#  ['in',
#   'benle',
#   'alıp',
#   'veremedigi',
#   'nedir',
#   'i̇s',
#   'yerimde',
#   'çekmez',
#   'evimde',
#   'çekmez.',
#   'bide',
#   'bangir',
#   'bangir',
#   'reklam',
#   'yapar',
#   'hd',
#   'ses',
#   'kalitesi',
#   'diye,',
#   'palavra'],
#  ['4',
#   'çeker',
#   '5',
#   'çeker',
#   'hikayeeeeee',
#   '4-5',
#   'cagrı',
#   'merkezine',
#   'telefon',
#   'acmama',
#   'rağmen',
#   "trabzon'da",
#   'şehir',
#   'merkezinde',
#   'telefon',
#   'cekmiyor'],
#  ['merhaba,ben',
#   'sevgilinizden',
#   'mesaj',
#   'beklerken',
#   'gelen',
#   'turkcell',
#   'mesaji,bana',
#   'ettiginiz',
#   'kufurleri',
#   'biliyorum...'],
#  ['milleti',
#   'kandırmayın',
#   'lannn',
#   ':turkcell+vodafone+avea',
#   'ayaginizi',
#   'denk',
#   'alınnn',
#   ';)'],
#  ['ben',
#   '3',
#   'yıldır',
#   'turkcell',
#   'kullanıyorum',
#   'faturamın',
#   'sabıt',
#   'fıyatı',
#   '80',
#   'lira',
#   '100',
#   'un',
#   'altına',
#   'ınmıyor.',
#   'al',
#   'reyis',
#   '2000',
#   'dk',
#   'vodafone',
#   'mis:)'],
#  ['basarili',
#   'musteri',
#   'elinde',
#   'tutma',
#   'politikalari',
#   'bekliyorum',
#   'turkcell',
#   'den'],
#  ['bi',
#   'sesli',
#   'mesajim',
#   'var',
#   'sevinirken',
#   'turkcell',
#   'çıktı',
#   'ya,',
#   'diyim',
#   'sana',
#   'turkcell!',
#   'defol',
#   'git',
#   'turkcell!'],
#  ['#turkcell', 'icloud', 'reklamı', 'yapıyor,', 'yürü', 'len'],
#  ['burdan',
#   'yetkılılere',
#   'seslenıorm',
#   'se',
#   'se',
#   '!!!',
#   'sattıgınız',
#   'blackberryı',
#   'turkcel',
#   'desteklıo',
#   'dıosunuz',
#   'turkcell',
#   'merkezı',
#   'yerde',
#   'cekmıo?',
#   'ayaksınız'],
#  ['canım',
#   '#turkcell',
#   'msj',
#   'göndermiş,',
#   'hediye',
#   'kazandın',
#   "msj'larına",
#   'itibar',
#   'etme',
#   'diye.',
#   'beni',
#   'seviyo.',
#   '(gelip',
#   'konuşmasını',
#   'beklesem',
#   'mi',
#   'ben',
#   'mi',
#   'teklif',
#   'etsem)'],
#  ['ayda',
#   '6tl',
#   'cok,',
#   'fiyati',
#   'indirin,',
#   'ayda',
#   '3tl',
#   'yeterli,',
#   'fiyati',
#   'indirin',
#   'abone',
#   'olalim.'],
#  ['durduk', 'yere', 'kontorlerimi', 'yiyosun', 'turkcell?'],
#  ['"sayın',
#   'süreyya',
#   'ciliv,',
#   'klasör',
#   'yok',
#   'sizi',
#   'olumsuz',
#   'haberler',
#   'konteynırına',
#   'götürelim',
#   'isterseniz"',
#   ':))'],
#  ['ayrilik', 'zamani', 'geli̇yor', 'kazikcilar.'],
#  ['cumartesileri', 'çalışmıyor', 'musunuz?'],
#  ['allah', 'belanı', 'versinnn'],
#  ['hattınız',
#   'turkcell',
#   'yalnız',
#   'değilsiniz',
#   'demektir.',
#   'yoksa',
#   'hergün',
#   'düzenli',
#   'olarak',
#   'mesaj',
#   'gönderir.'],
#  ["vodofone'u",
#   'yurtdışında',
#   'kullanmak',
#   'mantıklı',
#   'ben',
#   'turkcell',
#   'aveada',
#   'sorun',
#   'yaşayanları',
#   'gördüm',
#   'vodofoneda',
#   'ben',
#   'dahil',
#   'sorun',
#   'yaşamdm'],
#  ["bihter'cim",
#   'cumartesi',
#   'parandan',
#   'kesicem',
#   'haberin',
#   'olsun.',
#   'zira',
#   'sana',
#   'attığım',
#   "sms'in",
#   'haddi',
#   'hesabı',
#   'yok.',
#   'turkcell',
#   'ay',
#   'beni',
#   'öpecek.',
#   ':)'],
#  ['internet',
#   'pktm',
#   'bittti',
#   'yeniden',
#   'yaptım',
#   'cok',
#   'pahalı',
#   'öğrenciyi',
#   'düşünmüyo',
#   ':)'],
#  ['turkcell', 'fiyat', 'çekecekseniz', 'getirmeyin.'],
#  ['kampanya',
#   'iptali',
#   'teyidi',
#   '2',
#   'gün',
#   'telefon',
#   'etmesi',
#   'beklenilen,',
#   'sinirlenince',
#   'hattı',
#   'iptal',
#   'etme',
#   'başvurusunun',
#   '10.',
#   'dk.sında',
#   'arayan',
#   'firma'],
#  ['turkcell',
#   'interneti',
#   'kadar',
#   'yavas',
#   'evin',
#   'wifisi',
#   'bile',
#   'hizli'],
#  ['bugun',
#   '532',
#   'turkcell',
#   'musteri',
#   'hizmetlerinin',
#   'beni',
#   '5.',
#   'aramasi',
#   'bilgisayar',
#   'takildi',
#   'kaldi',
#   'sanirim',
#   'otomatige',
#   'bagladi',
#   'imdatt'],
#  ['erol',
#   'köse:turkcell',
#   'bayisinde',
#   "''kontör",
#   "bulunur''",
#   'yazısı',
#   'bana',
#   'aziz',
#   "nesin'i",
#   'hatirlatti..yok',
#   'molped',
#   'mi',
#   'saticaktiniz....'],
#  ['reklamlarınızdan', 'nefret', 'ediyorum'],
#  ['sevgili',
#   'turkcell',
#   'dandik',
#   'operatörler',
#   'metroda',
#   'çekiyor,',
#   'turkcell',
#   'çekmiyor',
#   ':('],
#  ['zuzu',
#   'turkcell',
#   '2',
#   'gündür',
#   'mesaj',
#   'atmıyo',
#   'kesin',
#   'baska',
#   'var',
#   ':('],
#  ['dur',
#   'bi',
#   'mesaj',
#   'atalimda',
#   'sevgilisinden',
#   'geldi',
#   'sansin',
#   '-turkcell'],
#  ['hahahaha',
#   'turkcell',
#   'i',
#   'örnek',
#   'alarak',
#   'sende',
#   'onları',
#   'soyuyorsun',
#   ':d'],
#  ['yanımda',
#   'oldu',
#   'hıcbır',
#   'zaman',
#   'benı',
#   'yanlız',
#   'bırakmadı',
#   'cok',
#   'duydugun',
#   'ısımdı',
#   'cunku',
#   'turkcell"',
#   'dı',
#   'sen',
#   'beklıyodun',
#   'kı',
#   'amk'],
#  ['superonline',
#   'adil',
#   'kullanım',
#   'hakkı',
#   'tam',
#   'bi',
#   'şark',
#   'kurnazlığı'],
#  ['20tl',
#   'mi',
#   '100',
#   'tl',
#   'yapmana',
#   'gerek',
#   'yok',
#   'turkcell',
#   'yukler',
#   'yuklemez',
#   '-563554',
#   'tl',
#   'yapmasan',
#   'yeterdi'],
#  ['bir',
#   'cihaz',
#   'kaydini',
#   '1,5',
#   'saatte',
#   'yaparak',
#   'cumle',
#   'bekleyenleri',
#   'cileden',
#   'cikaran',
#   'kanyon',
#   '#turkcell',
#   'i',
#   'yilin',
#   'musteri',
#   'hizmetleri',
#   'merkezi',
#   'ilan',
#   'ediyrm'],
#  ...]

# %%
#vocab size
len(w2v_model.wv.vocab)
#We have now represented each of 38071 words by a 100dim vector.
# Out:
# 14332

# %%
w2v_model.wv.vocab
# Out:
# {'dun': <gensim.models.keyedvectors.Vocab at 0x287e1ce1688>,
#  'turkcelle': <gensim.models.keyedvectors.Vocab at 0x287e1ce1908>,
#  'tepkilerimizden': <gensim.models.keyedvectors.Vocab at 0x287e1ce1988>,
#  'sonra': <gensim.models.keyedvectors.Vocab at 0x287e1ce10c8>,
#  'bugün': <gensim.models.keyedvectors.Vocab at 0x287e1ce1ac8>,
#  'turkcell': <gensim.models.keyedvectors.Vocab at 0x287e1ce1bc8>,
#  'twittera': <gensim.models.keyedvectors.Vocab at 0x287e1ce1b08>,
#  'sponsor': <gensim.models.keyedvectors.Vocab at 0x287e1ce1c08>,
#  'olmuş.': <gensim.models.keyedvectors.Vocab at 0x287e1ce1888>,
#  'tesadüf': <gensim.models.keyedvectors.Vocab at 0x287e1ce18c8>,
#  'değil': <gensim.models.keyedvectors.Vocab at 0x287e1ce1b48>,
#  'mi': <gensim.models.keyedvectors.Vocab at 0x287e1ce19c8>,
#  ':)': <gensim.models.keyedvectors.Vocab at 0x287e1ce1e08>,
#  'girmezmiyim..': <gensim.models.keyedvectors.Vocab at 0x287e1ce1c48>,
#  'kartim': <gensim.models.keyedvectors.Vocab at 0x287e1ce1f88>,
#  'bile': <gensim.models.keyedvectors.Vocab at 0x287e1ce1b88>,
#  'var..': <gensim.models.keyedvectors.Vocab at 0x287e1ce1948>,
#  'yarindan': <gensim.models.keyedvectors.Vocab at 0x287e1ce1f08>,
#  'itibaren': <gensim.models.keyedvectors.Vocab at 0x287e1ce1548>,
#  'onu': <gensim.models.keyedvectors.Vocab at 0x287e1ce1848>,
#  'takicam..': <gensim.models.keyedvectors.Vocab at 0x287e1ce1308>,
#  'twittersiz': <gensim.models.keyedvectors.Vocab at 0x287e1ce1a08>,
#  'denedim': <gensim.models.keyedvectors.Vocab at 0x287e1ce1e88>,
#  'sadece': <gensim.models.keyedvectors.Vocab at 0x287e1ce16c8>,
#  '3': <gensim.models.keyedvectors.Vocab at 0x287e1ce1fc8>,
#  'gun': <gensim.models.keyedvectors.Vocab at 0x287e1ce1dc8>,
#  'yapabildim:)))))': <gensim.models.keyedvectors.Vocab at 0x287e1ce1e48>,
#  'tam': <gensim.models.keyedvectors.Vocab at 0x287e1ce1248>,
#  'tünelden': <gensim.models.keyedvectors.Vocab at 0x287e1ce1d08>,
#  'gecerken': <gensim.models.keyedvectors.Vocab at 0x287e1ce1348>,
#  '3g': <gensim.models.keyedvectors.Vocab at 0x287e1ce1a48>,
#  'cekiyordu': <gensim.models.keyedvectors.Vocab at 0x287e1ce1508>,
#  ':d': <gensim.models.keyedvectors.Vocab at 0x287e1ce1cc8>,
#  "türkcell'in": <gensim.models.keyedvectors.Vocab at 0x287e1ce1d48>,
#  'reklamlari': <gensim.models.keyedvectors.Vocab at 0x287e1ce1c88>,
#  "vodafone'": <gensim.models.keyedvectors.Vocab at 0x287e1ce1d88>,
#  'harekete': <gensim.models.keyedvectors.Vocab at 0x287e1ce1a88>,
#  'gecirmis': <gensim.models.keyedvectors.Vocab at 0x287e1ce1ec8>,
#  'olmali:)': <gensim.models.keyedvectors.Vocab at 0x287e1b83288>,
#  'superonline': <gensim.models.keyedvectors.Vocab at 0x287e1b83108>,
#  'fiber': <gensim.models.keyedvectors.Vocab at 0x287e1b83d48>,
#  'internet': <gensim.models.keyedvectors.Vocab at 0x287e1b83b88>,
#  'adsl': <gensim.models.keyedvectors.Vocab at 0x287e1b83848>,
#  'sabit': <gensim.models.keyedvectors.Vocab at 0x287e1b836c8>,
#  'telefon': <gensim.models.keyedvectors.Vocab at 0x287e1b83608>,
#  'hizmetleri': <gensim.models.keyedvectors.Vocab at 0x287e1b83e88>,
#  'bence': <gensim.models.keyedvectors.Vocab at 0x287e1b83048>,
#  'gnçtrkcll': <gensim.models.keyedvectors.Vocab at 0x287e1b83488>,
#  'ark': <gensim.models.keyedvectors.Vocab at 0x287e1b838c8>,
#  'winterfest': <gensim.models.keyedvectors.Vocab at 0x287e1b83808>,
#  "2012'de": <gensim.models.keyedvectors.Vocab at 0x287e1b83e48>,
#  '1.olur': <gensim.models.keyedvectors.Vocab at 0x287e1b83148>,
#  'gelir': <gensim.models.keyedvectors.Vocab at 0x287e1b83c88>,
#  'sana': <gensim.models.keyedvectors.Vocab at 0x287e1b83cc8>,
#  'kıyak': <gensim.models.keyedvectors.Vocab at 0x287e1b83a08>,
#  'geçiyor': <gensim.models.keyedvectors.Vocab at 0x287e1b83388>,
#  'bağlan': <gensim.models.keyedvectors.Vocab at 0x287e1b86148>,
#  'hayata': <gensim.models.keyedvectors.Vocab at 0x287e1b86d48>,
#  'diyorum': <gensim.models.keyedvectors.Vocab at 0x287e1b86f48>,
#  ';)))': <gensim.models.keyedvectors.Vocab at 0x287e1b86cc8>,
#  'kimse': <gensim.models.keyedvectors.Vocab at 0x287e1b86488>,
#  'takmıyo': <gensim.models.keyedvectors.Vocab at 0x287e1b86f88>,
#  'beni': <gensim.models.keyedvectors.Vocab at 0x287e1b863c8>,
#  'yaaaaa,': <gensim.models.keyedvectors.Vocab at 0x287e1b86088>,
#  'bana': <gensim.models.keyedvectors.Vocab at 0x287e1b86108>,
#  'mesaj': <gensim.models.keyedvectors.Vocab at 0x287e1b86208>,
#  'aaat': <gensim.models.keyedvectors.Vocab at 0x287e1b86708>,
#  'pusula': <gensim.models.keyedvectors.Vocab at 0x287e1b86388>,
#  'uygulaması': <gensim.models.keyedvectors.Vocab at 0x287e1b86bc8>,
#  'iphone': <gensim.models.keyedvectors.Vocab at 0x287e1b861c8>,
#  'kullanıcıları': <gensim.models.keyedvectors.Vocab at 0x287e1b86948>,
#  'büyük': <gensim.models.keyedvectors.Vocab at 0x287e1b868c8>,
#  'nimet.': <gensim.models.keyedvectors.Vocab at 0x287e1b86788>,
#  'oturduğum': <gensim.models.keyedvectors.Vocab at 0x287e1b86b08>,
#  'yerden': <gensim.models.keyedvectors.Vocab at 0x287e1b86b48>,
#  'nöbetçi': <gensim.models.keyedvectors.Vocab at 0x287e1b86348>,
#  'eczane': <gensim.models.keyedvectors.Vocab at 0x287e1b86e08>,
#  'kaç': <gensim.models.keyedvectors.Vocab at 0x287e1b86fc8>,
#  'metre': <gensim.models.keyedvectors.Vocab at 0x287e1b867c8>,
#  'ötemde': <gensim.models.keyedvectors.Vocab at 0x287e1b86888>,
#  'söylüyor.': <gensim.models.keyedvectors.Vocab at 0x287e1b86288>,
#  'zaman': <gensim.models.keyedvectors.Vocab at 0x287e1b864c8>,
#  'sorun': <gensim.models.keyedvectors.Vocab at 0x287e1b865c8>,
#  'yok': <gensim.models.keyedvectors.Vocab at 0x287e1b86688>,
#  'bende': <gensim.models.keyedvectors.Vocab at 0x287e1b86ec8>,
#  'iyi': <gensim.models.keyedvectors.Vocab at 0x287e1b86ac8>,
#  'bir': <gensim.models.keyedvectors.Vocab at 0x287e1b86d88>,
#  'tarife': <gensim.models.keyedvectors.Vocab at 0x287e1b862c8>,
#  'arıyorum': <gensim.models.keyedvectors.Vocab at 0x287e1b86e88>,
#  'yapsam': <gensim.models.keyedvectors.Vocab at 0x287e1b86508>,
#  'karar': <gensim.models.keyedvectors.Vocab at 0x287e1b86b88>,
#  'veremedim': <gensim.models.keyedvectors.Vocab at 0x287e1b869c8>,
#  'fikir': <gensim.models.keyedvectors.Vocab at 0x287e1b86808>,
#  'versene:)': <gensim.models.keyedvectors.Vocab at 0x287e1b86f08>,
#  'samsung': <gensim.models.keyedvectors.Vocab at 0x287e1b86408>,
#  'turkcell’den': <gensim.models.keyedvectors.Vocab at 0x287e1b86c88>,
#  'kaçırılmayacak': <gensim.models.keyedvectors.Vocab at 0x287e1b86648>,
#  'kampanya:': <gensim.models.keyedvectors.Vocab at 0x287e1b86d08>,
#  'an': <gensim.models.keyedvectors.Vocab at 0x287e1b86248>,
#  'bağlantıda': <gensim.models.keyedvectors.Vocab at 0x287e1b86e48>,
#  'kalmanızı': <gensim.models.keyedvectors.Vocab at 0x287e1b86a08>,
#  'sağlayan': <gensim.models.keyedvectors.Vocab at 0x287e1b86dc8>,
#  'qwerty': <gensim.models.keyedvectors.Vocab at 0x287e1b86748>,
#  'klavyeli': <gensim.models.keyedvectors.Vocab at 0x287e1b86c08>,
#  '...': <gensim.models.keyedvectors.Vocab at 0x287e1b86908>,
#  'i̇novasyon': <gensim.models.keyedvectors.Vocab at 0x287e1b86448>,
#  'ödülü': <gensim.models.keyedvectors.Vocab at 0x287e1b866c8>,
#  "'turkcell'in": <gensim.models.keyedvectors.Vocab at 0x287e1b86548>,
#  'pazar': <gensim.models.keyedvectors.Vocab at 0x287e1b86608>,
#  'gunlerı': <gensim.models.keyedvectors.Vocab at 0x287e1b86a48>,
#  'sanslı': <gensim.models.keyedvectors.Vocab at 0x287e1b86588>,
#  'gunummuss': <gensim.models.keyedvectors.Vocab at 0x287e1b86c48>,
#  'turkcellılerle': <gensim.models.keyedvectors.Vocab at 0x287e1b86188>,
#  'bedava': <gensim.models.keyedvectors.Vocab at 0x287e1b86048>,
#  'konuscakmısımm': <gensim.models.keyedvectors.Vocab at 0x287e1b86308>,
#  'sagol': <gensim.models.keyedvectors.Vocab at 0x287e1a04348>,
#  'varol': <gensim.models.keyedvectors.Vocab at 0x287e1ce5308>,
#  '\x1a': <gensim.models.keyedvectors.Vocab at 0x287e1ce5188>,
#  'kahrol': <gensim.models.keyedvectors.Vocab at 0x287e1ce5388>,
#  'avea': <gensim.models.keyedvectors.Vocab at 0x287e1ce5c48>,
#  'ödül': <gensim.models.keyedvectors.Vocab at 0x287e1ce5208>,
#  "teknoloji'ye": <gensim.models.keyedvectors.Vocab at 0x287e1ce5108>,
#  'hadi': <gensim.models.keyedvectors.Vocab at 0x287e1ce5048>,
#  'yine': <gensim.models.keyedvectors.Vocab at 0x287e1ce5888>,
#  'süpersiniz,': <gensim.models.keyedvectors.Vocab at 0x287e1ce5148>,
#  'sıyırdınız.': <gensim.models.keyedvectors.Vocab at 0x287e1ce54c8>,
#  '4s': <gensim.models.keyedvectors.Vocab at 0x287e1ce5088>,
#  'olayından': <gensim.models.keyedvectors.Vocab at 0x287e1ce50c8>,
#  'hizmeti': <gensim.models.keyedvectors.Vocab at 0x287e1ce53c8>,
#  'adresinizde': <gensim.models.keyedvectors.Vocab at 0x287e1ce5b48>,
#  'varsa': <gensim.models.keyedvectors.Vocab at 0x287e1ce5448>,
#  'tavsiye': <gensim.models.keyedvectors.Vocab at 0x287e1ce51c8>,
#  'ederim': <gensim.models.keyedvectors.Vocab at 0x287e1ce5408>,
#  'cok': <gensim.models.keyedvectors.Vocab at 0x287e1ce5548>,
#  'hizli': <gensim.models.keyedvectors.Vocab at 0x287e1ce5988>,
#  'hesapli': <gensim.models.keyedvectors.Vocab at 0x287e1ce58c8>,
#  'kesilmiyor': <gensim.models.keyedvectors.Vocab at 0x287e1ce5c08>,
#  'aramiyor': <gensim.models.keyedvectors.Vocab at 0x287e1ce5748>,
#  'arada': <gensim.models.keyedvectors.Vocab at 0x287e1ce5ec8>,
#  '++': <gensim.models.keyedvectors.Vocab at 0x287e1ce5688>,
#  'kesinlikle': <gensim.models.keyedvectors.Vocab at 0x287e1ce5b88>,
#  'süperonline.hatta': <gensim.models.keyedvectors.Vocab at 0x287e1ce5c88>,
#  'tivibuyu': <gensim.models.keyedvectors.Vocab at 0x287e1ce5f88>,
#  'öneririm.gayet': <gensim.models.keyedvectors.Vocab at 0x287e1ce5b08>,
#  'güzel': <gensim.models.keyedvectors.Vocab at 0x287e1ce5908>,
#  'imkanları': <gensim.models.keyedvectors.Vocab at 0x287e1ce5e08>,
#  'var;)': <gensim.models.keyedvectors.Vocab at 0x287e1ce5648>,
#  'hayat': <gensim.models.keyedvectors.Vocab at 0x287e1ce5488>,
#  'paylaşınca': <gensim.models.keyedvectors.Vocab at 0x287e1ce5a88>,
#  'la': <gensim.models.keyedvectors.Vocab at 0x287e1ce5288>,
#  'laaa': <gensim.models.keyedvectors.Vocab at 0x287e1ce5ac8>,
#  'laa': <gensim.models.keyedvectors.Vocab at 0x287e1ce52c8>,
#  '((:': <gensim.models.keyedvectors.Vocab at 0x287e1ce5e48>,
#  'özturkcell': <gensim.models.keyedvectors.Vocab at 0x287e1ce5cc8>,
#  'seninle': <gensim.models.keyedvectors.Vocab at 0x287e1ce5248>,
#  'ölmeye': <gensim.models.keyedvectors.Vocab at 0x287e1ce5dc8>,
#  'geldik': <gensim.models.keyedvectors.Vocab at 0x287e1ce5f48>,
#  'özturkceeeeeellllll': <gensim.models.keyedvectors.Vocab at 0x287e1ce5d88>,
#  ':)))': <gensim.models.keyedvectors.Vocab at 0x287e1ce5608>,
#  'hasan': <gensim.models.keyedvectors.Vocab at 0x287e1ce5588>,
#  'doğan': <gensim.models.keyedvectors.Vocab at 0x287e1ce5fc8>,
#  'spor': <gensim.models.keyedvectors.Vocab at 0x287e1ce55c8>,
#  'kompleksi)': <gensim.models.keyedvectors.Vocab at 0x287e1ce5708>,
#  'eyvallah,': <gensim.models.keyedvectors.Vocab at 0x287e1ce5348>,
#  ':))': <gensim.models.keyedvectors.Vocab at 0x287e1ce5bc8>,
#  'bi': <gensim.models.keyedvectors.Vocab at 0x287e1ce5e88>,
#  'coca-cola': <gensim.models.keyedvectors.Vocab at 0x287e1ce5f08>,
#  'reklamları': <gensim.models.keyedvectors.Vocab at 0x287e1ce5948>,
#  'derinden': <gensim.models.keyedvectors.Vocab at 0x287e1ce5d48>,
#  'etkliyo': <gensim.models.keyedvectors.Vocab at 0x287e1ce5788>,
#  'lan': <gensim.models.keyedvectors.Vocab at 0x287e1ce5a48>,
#  'teşekkür': <gensim.models.keyedvectors.Vocab at 0x287e1b76ac8>,
#  'selocan:))': <gensim.models.keyedvectors.Vocab at 0x287e1b76d88>,
#  'akşam': <gensim.models.keyedvectors.Vocab at 0x287e1b76588>,
#  'belejj': <gensim.models.keyedvectors.Vocab at 0x287e1b76248>,
#  'film': <gensim.models.keyedvectors.Vocab at 0x287e1b76f08>,
#  'gecesi,yani': <gensim.models.keyedvectors.Vocab at 0x287e1b769c8>,
#  'gnç': <gensim.models.keyedvectors.Vocab at 0x287e1b76ec8>,
#  'şifresi': <gensim.models.keyedvectors.Vocab at 0x287e1b76148>,
#  'paylaşım': <gensim.models.keyedvectors.Vocab at 0x287e1b76708>,
#  'gecesi,': <gensim.models.keyedvectors.Vocab at 0x287e1b76cc8>,
#  'katkılarınızı': <gensim.models.keyedvectors.Vocab at 0x287e1b76f48>,
#  'bekliorum,': <gensim.models.keyedvectors.Vocab at 0x287e1b76d08>,
#  'sanata': <gensim.models.keyedvectors.Vocab at 0x287e1b76508>,
#  'sinemaya': <gensim.models.keyedvectors.Vocab at 0x287e1b767c8>,
#  'katkı': <gensim.models.keyedvectors.Vocab at 0x287e1b76108>,
#  'babında': <gensim.models.keyedvectors.Vocab at 0x287e1b764c8>,
#  'evet': <gensim.models.keyedvectors.Vocab at 0x287e1b76048>,
#  'sıkıntı': <gensim.models.keyedvectors.Vocab at 0x287e1b76c48>,
#  'çıkmadı': <gensim.models.keyedvectors.Vocab at 0x287e1b76848>,
#  'jb': <gensim.models.keyedvectors.Vocab at 0x287e1b76308>,
#  'herhangi': <gensim.models.keyedvectors.Vocab at 0x287e1b76b88>,
#  'çözüm': <gensim.models.keyedvectors.Vocab at 0x287e1b76f88>,
#  'varmı': <gensim.models.keyedvectors.Vocab at 0x287e1b76888>,
#  '#avea': <gensim.models.keyedvectors.Vocab at 0x287e1b76688>,
#  '#aveadestek': <gensim.models.keyedvectors.Vocab at 0x287e1b761c8>,
#  'manga': <gensim.models.keyedvectors.Vocab at 0x287e1b76c08>,
#  'konseri,': <gensim.models.keyedvectors.Vocab at 0x287e1b76348>,
#  'saat': <gensim.models.keyedvectors.Vocab at 0x287e1b76bc8>,
#  "15:00'te": <gensim.models.keyedvectors.Vocab at 0x287e1b76548>,
#  'canlı': <gensim.models.keyedvectors.Vocab at 0x287e1b76088>,
#  'yayınla': <gensim.models.keyedvectors.Vocab at 0x287e1b76dc8>,
#  'adresinde!': <gensim.models.keyedvectors.Vocab at 0x287e1b76648>,
#  'müziği': <gensim.models.keyedvectors.Vocab at 0x287e1b76788>,
#  'çakma': <gensim.models.keyedvectors.Vocab at 0x287e1b765c8>,
#  "i̇phone4'üm": <gensim.models.keyedvectors.Vocab at 0x287e1b76e08>,
#  'var': <gensim.models.keyedvectors.Vocab at 0x287e1b76e48>,
#  '1gb': <gensim.models.keyedvectors.Vocab at 0x287e1b763c8>,
#  'tel': <gensim.models.keyedvectors.Vocab at 0x287e1b76488>,
#  'i̇nterneti̇m': <gensim.models.keyedvectors.Vocab at 0x287e1b760c8>,
#  'sabah': <gensim.models.keyedvectors.Vocab at 0x287e1b76d48>,
#  'buradayim': <gensim.models.keyedvectors.Vocab at 0x287e1b76188>,
#  'süper': <gensim.models.keyedvectors.Vocab at 0x287e1b76a88>,
#  'li̇mi̇t': <gensim.models.keyedvectors.Vocab at 0x287e1b76388>,
#  'kesi̇nti̇': <gensim.models.keyedvectors.Vocab at 0x287e1b768c8>,
#  '"sağol': <gensim.models.keyedvectors.Vocab at 0x287e1b76c88>,
#  'çi̇n+turkcell"': <gensim.models.keyedvectors.Vocab at 0x287e1b76448>,
#  'emekli̇ğe': <gensim.models.keyedvectors.Vocab at 0x287e1b76948>,
#  'kiyak!!': <gensim.models.keyedvectors.Vocab at 0x287e1b76208>,
#  'yanlızken': <gensim.models.keyedvectors.Vocab at 0x287e1b76408>,
#  'mutlu': <gensim.models.keyedvectors.Vocab at 0x287e1b76808>,
#  'olmuşki': <gensim.models.keyedvectors.Vocab at 0x287e1b766c8>,
#  'seen': <gensim.models.keyedvectors.Vocab at 0x287e1b76fc8>,
#  'olasın': <gensim.models.keyedvectors.Vocab at 0x287e1b7f288>,
#  'kendini': <gensim.models.keyedvectors.Vocab at 0x287e1b7f688>,
#  'kandırma': <gensim.models.keyedvectors.Vocab at 0x287e1b7f5c8>,
#  'bak': <gensim.models.keyedvectors.Vocab at 0x287e1b7f748>,
#  'sertb': <gensim.models.keyedvectors.Vocab at 0x287e1b7f888>,
#  'abla': <gensim.models.keyedvectors.Vocab at 0x287e1b7fb88>,
#  'diyo': <gensim.models.keyedvectors.Vocab at 0x287e1b7ff08>,
#  'haydi': <gensim.models.keyedvectors.Vocab at 0x287e1b7f988>,
#  'gel': <gensim.models.keyedvectors.Vocab at 0x287e1b7fb48>,
#  'paketi..': <gensim.models.keyedvectors.Vocab at 0x287e1b7f4c8>,
#  'enfes..': <gensim.models.keyedvectors.Vocab at 0x287e1b7f0c8>,
#  'photo:': <gensim.models.keyedvectors.Vocab at 0x287e1b7f948>,
#  '”dünyaya': <gensim.models.keyedvectors.Vocab at 0x287e1b7fc48>,
#  'liderlik': <gensim.models.keyedvectors.Vocab at 0x287e1b7f488>,
#  'eden': <gensim.models.keyedvectors.Vocab at 0x287e1b7fa88>,
#  'operatörler”den': <gensim.models.keyedvectors.Vocab at 0x287e1b7f708>,
#  'türk': <gensim.models.keyedvectors.Vocab at 0x287e1b7fdc8>,
#  'internette': <gensim.models.keyedvectors.Vocab at 0x287e1b7fd48>,
#  'dünya': <gensim.models.keyedvectors.Vocab at 0x287e1b7ffc8>,
#  'lideri...': <gensim.models.keyedvectors.Vocab at 0x287e1b7f188>,
#  'tl': <gensim.models.keyedvectors.Vocab at 0x287e1b7f148>,
#  'hediye': <gensim.models.keyedvectors.Vocab at 0x287e1b7fbc8>,
#  'etse': <gensim.models.keyedvectors.Vocab at 0x287e1b7fc08>,
#  'olur': <gensim.models.keyedvectors.Vocab at 0x287e1b7f508>,
#  '=)': <gensim.models.keyedvectors.Vocab at 0x287e1b7f108>,
#  'yedekleme': <gensim.models.keyedvectors.Vocab at 0x287e1b7f9c8>,
#  'yi': <gensim.models.keyedvectors.Vocab at 0x287e1b7fe48>,
#  'kullanmak': <gensim.models.keyedvectors.Vocab at 0x287e1b7fec8>,
#  'pratik': <gensim.models.keyedvectors.Vocab at 0x287e1b7f608>,
#  'olabilir': <gensim.models.keyedvectors.Vocab at 0x287e1b7fcc8>,
#  'fiyat': <gensim.models.keyedvectors.Vocab at 0x287e1b7fc88>,
#  'basl': <gensim.models.keyedvectors.Vocab at 0x287e1b7f908>,
#  'peki': <gensim.models.keyedvectors.Vocab at 0x287e1b7fd08>,
#  'cokmu': <gensim.models.keyedvectors.Vocab at 0x287e1b7f2c8>,
#  'azmi.': <gensim.models.keyedvectors.Vocab at 0x287e1b7fa08>,
#  'alablrzz': <gensim.models.keyedvectors.Vocab at 0x287e1b7f8c8>,
#  'uygunsaa': <gensim.models.keyedvectors.Vocab at 0x287e1b7f588>,
#  'tarafından': <gensim.models.keyedvectors.Vocab at 0x287e1b7f808>,
#  'çekilişe': <gensim.models.keyedvectors.Vocab at 0x287e1b7f1c8>,
#  'katıldığım': <gensim.models.keyedvectors.Vocab at 0x287e1b7f448>,
#  'tebrik': <gensim.models.keyedvectors.Vocab at 0x287e1b7f7c8>,
#  'aldım.': <gensim.models.keyedvectors.Vocab at 0x287e1b7fa48>,
#  'anladım': <gensim.models.keyedvectors.Vocab at 0x287e1b7f248>,
#  'benim': <gensim.models.keyedvectors.Vocab at 0x287e1b7f548>,
#  'küçük': <gensim.models.keyedvectors.Vocab at 0x287e1b7f788>,
#  'insanlık,': <gensim.models.keyedvectors.Vocab at 0x287e1b7ff88>,
#  'adım': <gensim.models.keyedvectors.Vocab at 0x287e1b7f348>,
#  'atmışım.': <gensim.models.keyedvectors.Vocab at 0x287e1b7f048>,
#  'ufunett': <gensim.models.keyedvectors.Vocab at 0x287e1b7f408>,
#  'bastıı': <gensim.models.keyedvectors.Vocab at 0x287e1b7f648>,
#  'yine..keşkee': <gensim.models.keyedvectors.Vocab at 0x287e1b7ff48>,
#  'olsann..tarifeni': <gensim.models.keyedvectors.Vocab at 0x287e1b7f088>,
#  'değiştirsene': <gensim.models.keyedvectors.Vocab at 0x287e1b7fb08>,
#  'sen': <gensim.models.keyedvectors.Vocab at 0x287e1b7fac8>,
#  'yaa..=)': <gensim.models.keyedvectors.Vocab at 0x287e1b7fe88>,
#  'geçen': <gensim.models.keyedvectors.Vocab at 0x287e1b7f308>,
#  'hafta': <gensim.models.keyedvectors.Vocab at 0x287e1b7fe08>,
#  'yapıyordu': <gensim.models.keyedvectors.Vocab at 0x287e1b7fd88>,
#  'superonline.': <gensim.models.keyedvectors.Vocab at 0x287e1b98708>,
#  'rahat': <gensim.models.keyedvectors.Vocab at 0x287e1b98548>,
#  'girebiliyorum': <gensim.models.keyedvectors.Vocab at 0x287e1b98e88>,
#  'o_o': <gensim.models.keyedvectors.Vocab at 0x287e1b98d08>,
#  'farkettim': <gensim.models.keyedvectors.Vocab at 0x287e1b98c48>,
#  'kullanıyor:)': <gensim.models.keyedvectors.Vocab at 0x287e1b98dc8>,
#  'hahaha': <gensim.models.keyedvectors.Vocab at 0x287e1b98188>,
#  'seviyo': <gensim.models.keyedvectors.Vocab at 0x287e1b98148>,
#  'gecedn': <gensim.models.keyedvectors.Vocab at 0x287e1b98648>,
#  'beri': <gensim.models.keyedvectors.Vocab at 0x287e1b98488>,
#  'mustri': <gensim.models.keyedvectors.Vocab at 0x287e1b989c8>,
#  'hzmetlerndeki': <gensim.models.keyedvectors.Vocab at 0x287e1b98f88>,
#  'kadinla': <gensim.models.keyedvectors.Vocab at 0x287e1b98808>,
#  'ask': <gensim.models.keyedvectors.Vocab at 0x287e1b98948>,
#  'yasiyrz': <gensim.models.keyedvectors.Vocab at 0x287e1b983c8>,
#  'sonunda': <gensim.models.keyedvectors.Vocab at 0x287e1b98e48>,
#  'oldu': <gensim.models.keyedvectors.Vocab at 0x287e1b98a88>,
#  'oh': <gensim.models.keyedvectors.Vocab at 0x287e1b98908>,
#  'be:))': <gensim.models.keyedvectors.Vocab at 0x287e1b98fc8>,
#  '#mutluyum': <gensim.models.keyedvectors.Vocab at 0x287e1b98448>,
#  '#mutlusun': <gensim.models.keyedvectors.Vocab at 0x287e1b98d48>,
#  '#mutluyuz': <gensim.models.keyedvectors.Vocab at 0x287e1b986c8>,
#  'lalalalaaaa': <gensim.models.keyedvectors.Vocab at 0x287e1b98748>,
#  '#2012hayallerimin': <gensim.models.keyedvectors.Vocab at 0x287e1b98588>,
#  'ilk': <gensim.models.keyedvectors.Vocab at 0x287e1b98e08>,
#  'sırasında': <gensim.models.keyedvectors.Vocab at 0x287e1b987c8>,
#  'aylardır': <gensim.models.keyedvectors.Vocab at 0x287e1b98ec8>,
#  'söyleyip': <gensim.models.keyedvectors.Vocab at 0x287e1b98c88>,
#  'durduğum': <gensim.models.keyedvectors.Vocab at 0x287e1b98f48>,
#  'numaramı': <gensim.models.keyedvectors.Vocab at 0x287e1b988c8>,
#  "turkcell'e": <gensim.models.keyedvectors.Vocab at 0x287e1b98b08>,
#  'taşımak': <gensim.models.keyedvectors.Vocab at 0x287e1b98688>,
#  'var.': <gensim.models.keyedvectors.Vocab at 0x287e1906bc8>,
#  'hayal': <gensim.models.keyedvectors.Vocab at 0x287dfae2c48>,
#  'olarak': <gensim.models.keyedvectors.Vocab at 0x287dfae2cc8>,
#  'kalmasın': <gensim.models.keyedvectors.Vocab at 0x287dfb2ce88>,
#  'ama.': <gensim.models.keyedvectors.Vocab at 0x287dfb2cd88>,
#  'nioğğlur.': <gensim.models.keyedvectors.Vocab at 0x287d2b81f08>,
#  "turkcell'in": <gensim.models.keyedvectors.Vocab at 0x287e187cf48>,
#  'hızı': <gensim.models.keyedvectors.Vocab at 0x287e18a5608>,
#  "abd'de": <gensim.models.keyedvectors.Vocab at 0x287dfae6708>,
#  'deki': <gensim.models.keyedvectors.Vocab at 0x287dfae62c8>,
#  "4g'den": <gensim.models.keyedvectors.Vocab at 0x287df326488>,
#  'hızlı': <gensim.models.keyedvectors.Vocab at 0x287e19ff288>,
#  'müzik': <gensim.models.keyedvectors.Vocab at 0x287e19ff208>,
#  'muhabbetini': <gensim.models.keyedvectors.Vocab at 0x287dfaeed88>,
#  'sevdim': <gensim.models.keyedvectors.Vocab at 0x287df2f8d88>,
#  'mahalleden': <gensim.models.keyedvectors.Vocab at 0x287e1ab1a88>,
#  'geçse': <gensim.models.keyedvectors.Vocab at 0x287d2b9b588>,
#  'iyiymiş.': <gensim.models.keyedvectors.Vocab at 0x287e1861dc8>,
#  'e': <gensim.models.keyedvectors.Vocab at 0x287df3f4b08>,
#  'geciş': <gensim.models.keyedvectors.Vocab at 0x287dfc907c8>,
#  'yap': <gensim.models.keyedvectors.Vocab at 0x287e1863148>,
#  ';)': <gensim.models.keyedvectors.Vocab at 0x287e04962c8>,
#  'lan.durduk': <gensim.models.keyedvectors.Vocab at 0x287dfccde08>,
#  'yere': <gensim.models.keyedvectors.Vocab at 0x287dfc203c8>,
#  'atıyor,': <gensim.models.keyedvectors.Vocab at 0x287e04a6408>,
#  'kampanyalarıyla': <gensim.models.keyedvectors.Vocab at 0x287e04a6a08>,
#  'ediyor': <gensim.models.keyedvectors.Vocab at 0x287dfd4ef08>,
#  'falan.sevgilim': <gensim.models.keyedvectors.Vocab at 0x287dfc7b4c8>,
#  'gorup': <gensim.models.keyedvectors.Vocab at 0x287df3e0448>,
#  'kıskanır': <gensim.models.keyedvectors.Vocab at 0x287e1ce83c8>,
#  'umarım.': <gensim.models.keyedvectors.Vocab at 0x287dfaf1f48>,
#  'hayatın': <gensim.models.keyedvectors.Vocab at 0x287dfad0288>,
#  'beleşçilik': <gensim.models.keyedvectors.Vocab at 0x287dfad06c8>,
#  'git': <gensim.models.keyedvectors.Vocab at 0x287df319348>,
#  "turkcell'den": <gensim.models.keyedvectors.Vocab at 0x287e19701c8>,
#  'al.': <gensim.models.keyedvectors.Vocab at 0x287dfc13808>,
#  '4': <gensim.models.keyedvectors.Vocab at 0x287dfc13388>,
#  'çekiyo': <gensim.models.keyedvectors.Vocab at 0x287e1a085c8>,
#  'yavruş': <gensim.models.keyedvectors.Vocab at 0x287e1a08b88>,
#  ':o': <gensim.models.keyedvectors.Vocab at 0x287e1a08408>,
#  'selam': <gensim.models.keyedvectors.Vocab at 0x287e1a08f48>,
#  'yeniden': <gensim.models.keyedvectors.Vocab at 0x287e1a087c8>,
#  'haxball.': <gensim.models.keyedvectors.Vocab at 0x287e1a08cc8>,
#  'canını': <gensim.models.keyedvectors.Vocab at 0x287e1a08a48>,
#  'yiyeyim': <gensim.models.keyedvectors.Vocab at 0x287e1862fc8>,
#  'ben': <gensim.models.keyedvectors.Vocab at 0x287e1862788>,
#  'subtta': <gensim.models.keyedvectors.Vocab at 0x287e1862388>,
#  'iphne': <gensim.models.keyedvectors.Vocab at 0x287e1862e88>,
#  'alcm': <gensim.models.keyedvectors.Vocab at 0x287e1862ec8>,
#  '"trkcel"': <gensim.models.keyedvectors.Vocab at 0x287e1862508>,
#  'gold/platinum': <gensim.models.keyedvectors.Vocab at 0x287e17e7508>,
#  'kullanıcısı': <gensim.models.keyedvectors.Vocab at 0x287e17e7208>,
#  'isen': <gensim.models.keyedvectors.Vocab at 0x287e17e7988>,
#  '%50': <gensim.models.keyedvectors.Vocab at 0x287e17e7b48>,
#  'indirim': <gensim.models.keyedvectors.Vocab at 0x287e1b96e08>,
#  'hakkı..': <gensim.models.keyedvectors.Vocab at 0x287e1b96648>,
#  "mart'a": <gensim.models.keyedvectors.Vocab at 0x287e1b96a88>,
#  'kadar': <gensim.models.keyedvectors.Vocab at 0x287e1b96948>,
#  'kullanma': <gensim.models.keyedvectors.Vocab at 0x287e1b96fc8>,
#  'hakkın': <gensim.models.keyedvectors.Vocab at 0x287e1b96c48>,
#  'sayın': <gensim.models.keyedvectors.Vocab at 0x287e1b96808>,
#  'süreyya': <gensim.models.keyedvectors.Vocab at 0x287e1b960c8>,
#  "ciliv'e": <gensim.models.keyedvectors.Vocab at 0x287e1b968c8>,
#  "türkiye'ye": <gensim.models.keyedvectors.Vocab at 0x287e1b96548>,
#  'değer': <gensim.models.keyedvectors.Vocab at 0x287e1b96148>,
#  'katanlar': <gensim.models.keyedvectors.Vocab at 0x287e1b96588>,
#  'takdim': <gensim.models.keyedvectors.Vocab at 0x287e1b963c8>,
#  'ediliyor.': <gensim.models.keyedvectors.Vocab at 0x287e1b96188>,
#  'teşekkürler': <gensim.models.keyedvectors.Vocab at 0x287e1b96108>,
#  'heryone': <gensim.models.keyedvectors.Vocab at 0x287e1b966c8>,
#  'degilim': <gensim.models.keyedvectors.Vocab at 0x287e1b96f88>,
#  'yuzden': <gensim.models.keyedvectors.Vocab at 0x287e1b96b88>,
#  'iyisi': <gensim.models.keyedvectors.Vocab at 0x287e1b96708>,
#  'yarın': <gensim.models.keyedvectors.Vocab at 0x287e1b96048>,
#  'gidiyim': <gensim.models.keyedvectors.Vocab at 0x287e1b96c88>,
#  "turkcell'deyim": <gensim.models.keyedvectors.Vocab at 0x287e1b96e48>,
#  'şimdi.': <gensim.models.keyedvectors.Vocab at 0x287e1b96b08>,
#  'karşılaşırız': <gensim.models.keyedvectors.Vocab at 0x287e1b96d08>,
#  "bi'yerlerde": <gensim.models.keyedvectors.Vocab at 0x287e1b96688>,
#  'ederim.': <gensim.models.keyedvectors.Vocab at 0x287e1b96208>,
#  'üzerinden': <gensim.models.keyedvectors.Vocab at 0x287e1b96ec8>,
#  'internete': <gensim.models.keyedvectors.Vocab at 0x287e1b96f08>,
#  'bağlanırken': <gensim.models.keyedvectors.Vocab at 0x287e1b962c8>,
#  'yaşadm': <gensim.models.keyedvectors.Vocab at 0x287e1b96508>,
#  'anlam': <gensim.models.keyedvectors.Vocab at 0x287e1b96bc8>,
#  'veremedim..': <gensim.models.keyedvectors.Vocab at 0x287e1b96748>,
#  'geçti..': <gensim.models.keyedvectors.Vocab at 0x287e1b96308>,
#  'teşekkürlerr..': <gensim.models.keyedvectors.Vocab at 0x287e1b961c8>,
#  '#osesturkiye': <gensim.models.keyedvectors.Vocab at 0x287e1b96408>,
#  'sponsorlugunun': <gensim.models.keyedvectors.Vocab at 0x287e1b96888>,
#  'dibine': <gensim.models.keyedvectors.Vocab at 0x287e1b96088>,
#  'vurulmus': <gensim.models.keyedvectors.Vocab at 0x287e1b964c8>,
#  '..': <gensim.models.keyedvectors.Vocab at 0x287e1b96a48>,
#  'gormeyen': <gensim.models.keyedvectors.Vocab at 0x287e1b96a08>,
#  'kalmadi': <gensim.models.keyedvectors.Vocab at 0x287e1b965c8>,
#  'sunucudan': <gensim.models.keyedvectors.Vocab at 0x287e1b96d88>,
#  'buyuk': <gensim.models.keyedvectors.Vocab at 0x287e1b96b48>,
#  'gnctrkcll': <gensim.models.keyedvectors.Vocab at 0x287e1b967c8>,
#  'yazisini': <gensim.models.keyedvectors.Vocab at 0x287e1b96e88>,
#  'güzel...la': <gensim.models.keyedvectors.Vocab at 0x287e1b96cc8>,
#  'la...': <gensim.models.keyedvectors.Vocab at 0x287e1b969c8>,
#  'yeni': <gensim.models.keyedvectors.Vocab at 0x287e1b96dc8>,
#  'yıl': <gensim.models.keyedvectors.Vocab at 0x287e1b96c08>,
#  'reklamı': <gensim.models.keyedvectors.Vocab at 0x287e1b96988>,
#  'harika': <gensim.models.keyedvectors.Vocab at 0x287e1b96848>,
#  '!!': <gensim.models.keyedvectors.Vocab at 0x287e062fc88>,
#  'bos': <gensim.models.keyedvectors.Vocab at 0x287dfb3dc88>,
#  '1': <gensim.models.keyedvectors.Vocab at 0x287dfb3de88>,
#  'numara': <gensim.models.keyedvectors.Vocab at 0x287dfb3dd48>,
#  '#3kelimeyle2011': <gensim.models.keyedvectors.Vocab at 0x287dfb3d688>,
#  'gelecek': <gensim.models.keyedvectors.Vocab at 0x287dfb3da48>,
#  'quiknet': <gensim.models.keyedvectors.Vocab at 0x287dfb3d088>,
#  'wınnımda': <gensim.models.keyedvectors.Vocab at 0x287dfb3dfc8>,
#  '64': <gensim.models.keyedvectors.Vocab at 0x287df31b188>,
#  'k': <gensim.models.keyedvectors.Vocab at 0x287e1bee888>,
#  'lik': <gensim.models.keyedvectors.Vocab at 0x287e1bee188>,
#  'micro': <gensim.models.keyedvectors.Vocab at 0x287e1bee8c8>,
#  'sim': <gensim.models.keyedvectors.Vocab at 0x287e1bee808>,
#  'imde': <gensim.models.keyedvectors.Vocab at 0x287e1bee708>,
#  'i': <gensim.models.keyedvectors.Vocab at 0x287e1bee748>,
#  'pad': <gensim.models.keyedvectors.Vocab at 0x287e1bee608>,
#  'çeker:)': <gensim.models.keyedvectors.Vocab at 0x287e1beec48>,
#  'yarin': <gensim.models.keyedvectors.Vocab at 0x287e1beed48>,
#  'kendime': <gensim.models.keyedvectors.Vocab at 0x287e1bee908>,
#  'turksel': <gensim.models.keyedvectors.Vocab at 0x287e1beea48>,
#  'hat': <gensim.models.keyedvectors.Vocab at 0x287e1bee448>,
#  'sey': <gensim.models.keyedvectors.Vocab at 0x287e1bee508>,
#  'aldircaem,': <gensim.models.keyedvectors.Vocab at 0x287e1bee588>,
#  'veririm': <gensim.models.keyedvectors.Vocab at 0x287e1bee3c8>,
#  'reklamlarını': <gensim.models.keyedvectors.Vocab at 0x287e1bee688>,
#  'çağrıştırdı.': <gensim.models.keyedvectors.Vocab at 0x287e1bee2c8>,
#  'çağrışımı': <gensim.models.keyedvectors.Vocab at 0x287e1beec88>,
#  'yaratan': <gensim.models.keyedvectors.Vocab at 0x287e1beecc8>,
#  'turkcellse': <gensim.models.keyedvectors.Vocab at 0x287e1beebc8>,
#  'başarılı': <gensim.models.keyedvectors.Vocab at 0x287e1bee088>,
#  'olan': <gensim.models.keyedvectors.Vocab at 0x287e1bee408>,
#  'haliyle': <gensim.models.keyedvectors.Vocab at 0x287e1bee288>,
#  'o!': <gensim.models.keyedvectors.Vocab at 0x287e1bee6c8>,
#  'mi?': <gensim.models.keyedvectors.Vocab at 0x287e1beee08>,
#  'asil': <gensim.models.keyedvectors.Vocab at 0x287e1beef48>,
#  'koruosn': <gensim.models.keyedvectors.Vocab at 0x287e1beefc8>,
#  'reklama': <gensim.models.keyedvectors.Vocab at 0x287e1beef08>,
#  'taktim': <gensim.models.keyedvectors.Vocab at 0x287e1beee48>,
#  'insana': <gensim.models.keyedvectors.Vocab at 0x287e1beee88>,
#  "avea'yi": <gensim.models.keyedvectors.Vocab at 0x287e1beef88>,
#  'degil': <gensim.models.keyedvectors.Vocab at 0x287e1beed88>,
#  'direk': <gensim.models.keyedvectors.Vocab at 0x287e1beeec8>,
#  "turkcell'i": <gensim.models.keyedvectors.Vocab at 0x287e1beedc8>,
#  'dusunduruyo': <gensim.models.keyedvectors.Vocab at 0x287de280e88>,
#  'yarında': <gensim.models.keyedvectors.Vocab at 0x287dfb8b4c8>,
#  'perşembeeee..oohhhhh': <gensim.models.keyedvectors.Vocab at 0x287dfb8b648>,
#  'şükür..': <gensim.models.keyedvectors.Vocab at 0x287e1951a48>,
#  '[gnctrkcll]': <gensim.models.keyedvectors.Vocab at 0x287e1951548>,
#  'is': <gensim.models.keyedvectors.Vocab at 0x287e1cd9988>,
#  'uretemedikleri': <gensim.models.keyedvectors.Vocab at 0x287e1cd99c8>,
#  'ortada..': <gensim.models.keyedvectors.Vocab at 0x287e1cd9e48>,
#  "avea'yla": <gensim.models.keyedvectors.Vocab at 0x287e1cd9b48>,
#  'vodafone': <gensim.models.keyedvectors.Vocab at 0x287e1cd96c8>,
#  'yerde': <gensim.models.keyedvectors.Vocab at 0x287e1cd91c8>,
#  'çekiyor': <gensim.models.keyedvectors.Vocab at 0x287e1cd9308>,
#  'bilemem': <gensim.models.keyedvectors.Vocab at 0x287e1cd9548>,
#  'ikisinin': <gensim.models.keyedvectors.Vocab at 0x287e1cd9f88>,
#  'hala': <gensim.models.keyedvectors.Vocab at 0x287e1cd9188>,
#  'çekemediği': <gensim.models.keyedvectors.Vocab at 0x287e1cd92c8>,
#  'net."': <gensim.models.keyedvectors.Vocab at 0x287e1cd9a88>,
#  'iyiki': <gensim.models.keyedvectors.Vocab at 0x287e1cd9208>,
#  'varsınız': <gensim.models.keyedvectors.Vocab at 0x287e1cd94c8>,
#  'olmasanız': <gensim.models.keyedvectors.Vocab at 0x287e1cd9248>,
#  'geleceği': <gensim.models.keyedvectors.Vocab at 0x287e1cd9d08>,
#  'yok,telefon': <gensim.models.keyedvectors.Vocab at 0x287e1cde748>,
#  'özelliğini': <gensim.models.keyedvectors.Vocab at 0x287e1cdef48>,
#  'unutacak': <gensim.models.keyedvectors.Vocab at 0x287e1cdef08>,
#  'nerdeyse.': <gensim.models.keyedvectors.Vocab at 0x287e1cdee88>,
#  'yalnızım:)': <gensim.models.keyedvectors.Vocab at 0x287e1cde7c8>,
#  'ipad': <gensim.models.keyedvectors.Vocab at 0x287e1cde888>,
#  "2'yi": <gensim.models.keyedvectors.Vocab at 0x287e1cde248>,
#  'almışım.': <gensim.models.keyedvectors.Vocab at 0x287e1cde788>,
#  'cam': <gensim.models.keyedvectors.Vocab at 0x287e1cde288>,
#  'lig': <gensim.models.keyedvectors.Vocab at 0x287e1cde808>,
#  'tv': <gensim.models.keyedvectors.Vocab at 0x287e1cde5c8>,
#  'lalalalalalalalalal': <gensim.models.keyedvectors.Vocab at 0x287e1cde608>,
#  'oturduğunuz': <gensim.models.keyedvectors.Vocab at 0x287e1cde1c8>,
#  'bolgede': <gensim.models.keyedvectors.Vocab at 0x287e1cdee48>,
#  'net': <gensim.models.keyedvectors.Vocab at 0x287e1cdea08>,
#  'geçmelisiniz.': <gensim.models.keyedvectors.Vocab at 0x287e1cdec08>,
#  'komısyon': <gensim.models.keyedvectors.Vocab at 0x287e1cdee08>,
#  'baglamalı': <gensim.models.keyedvectors.Vocab at 0x287e1cdea88>,
#  'artık': <gensim.models.keyedvectors.Vocab at 0x287e1cde988>,
#  'kacıncı': <gensim.models.keyedvectors.Vocab at 0x287e1cdeb08>,
#  'musterısını': <gensim.models.keyedvectors.Vocab at 0x287e1cde508>,
#  'kazandırdım': <gensim.models.keyedvectors.Vocab at 0x287e1cde148>,
#  ':dd': <gensim.models.keyedvectors.Vocab at 0x287e1cdedc8>,
#  'yila': <gensim.models.keyedvectors.Vocab at 0x287e1cde908>,
#  'kadarki': <gensim.models.keyedvectors.Vocab at 0x287e1cdec48>,
#  'yilbasi': <gensim.models.keyedvectors.Vocab at 0x287e1cde448>,
#  'reklam': <gensim.models.keyedvectors.Vocab at 0x287e1cde348>,
#  'sarkisi': <gensim.models.keyedvectors.Vocab at 0x287e1cdef88>,
#  "'bu": <gensim.models.keyedvectors.Vocab at 0x287e3616088>,
#  'sene': <gensim.models.keyedvectors.Vocab at 0x287e36161c8>,
#  'cebin': <gensim.models.keyedvectors.Vocab at 0x287e36162c8>,
#  'olsun': <gensim.models.keyedvectors.Vocab at 0x287e3616388>,
#  'calain': <gensim.models.keyedvectors.Vocab at 0x287e3616588>,
#  'arayan': <gensim.models.keyedvectors.Vocab at 0x287e3616408>,
#  "olsun...'": <gensim.models.keyedvectors.Vocab at 0x287e3616208>,
#  'baslayandir!': <gensim.models.keyedvectors.Vocab at 0x287e3616108>,
#  'coco': <gensim.models.keyedvectors.Vocab at 0x287e36163c8>,
#  'cola,turkcell,vestel': <gensim.models.keyedvectors.Vocab at 0x287e3616488>,
#  'reklamda': <gensim.models.keyedvectors.Vocab at 0x287e36160c8>,
#  'onculer': <gensim.models.keyedvectors.Vocab at 0x287e3616448>,
#  '#turkcellmuzik': <gensim.models.keyedvectors.Vocab at 0x287e3616248>,
#  'bengü': <gensim.models.keyedvectors.Vocab at 0x287e3616548>,
#  'bitmesinn': <gensim.models.keyedvectors.Vocab at 0x287e3616348>,
#  'seni': <gensim.models.keyedvectors.Vocab at 0x287e3616ac8>,
#  'seviyorummm': <gensim.models.keyedvectors.Vocab at 0x287e36165c8>,
#  'türkcell': <gensim.models.keyedvectors.Vocab at 0x287e3616648>,
#  'teşkkürler': <gensim.models.keyedvectors.Vocab at 0x287e3616288>,
#  'bize': <gensim.models.keyedvectors.Vocab at 0x287e3616708>,
#  'böyle': <gensim.models.keyedvectors.Vocab at 0x287e3616688>,
#  'anı': <gensim.models.keyedvectors.Vocab at 0x287e36167c8>,
#  'yaşattıgın': <gensim.models.keyedvectors.Vocab at 0x287e3616848>,
#  'kendimi': <gensim.models.keyedvectors.Vocab at 0x287e3616788>,
#  'in': <gensim.models.keyedvectors.Vocab at 0x287e3616908>,
#  'şarkısını': <gensim.models.keyedvectors.Vocab at 0x287e3616888>,
#  'söylemekten': <gensim.models.keyedvectors.Vocab at 0x287e36169c8>,
#  'alikoyamiyorum.': <gensim.models.keyedvectors.Vocab at 0x287e3616948>,
#  'oha': <gensim.models.keyedvectors.Vocab at 0x287e3616808>,
#  'çalışıyo': <gensim.models.keyedvectors.Vocab at 0x287e3616a08>,
#  'resmen': <gensim.models.keyedvectors.Vocab at 0x287e3616a48>,
#  '487': <gensim.models.keyedvectors.Vocab at 0x287e3616748>,
#  'dakika': <gensim.models.keyedvectors.Vocab at 0x287e3616608>,
#  'vermiş': <gensim.models.keyedvectors.Vocab at 0x287e3616148>,
#  '#vodafone': <gensim.models.keyedvectors.Vocab at 0x287e3616b08>,
#  'icin': <gensim.models.keyedvectors.Vocab at 0x287e3616bc8>,
#  'eksiklik.': <gensim.models.keyedvectors.Vocab at 0x287e3616c88>,
#  'apple': <gensim.models.keyedvectors.Vocab at 0x287e3616d08>,
#  'urunlerinde': <gensim.models.keyedvectors.Vocab at 0x287e3616a88>,
#  'kullanilmak': <gensim.models.keyedvectors.Vocab at 0x287e3616988>,
#  'uzere': <gensim.models.keyedvectors.Vocab at 0x287e3616b88>,
#  '#turkcell': <gensim.models.keyedvectors.Vocab at 0x287e3616b48>,
#  'online': <gensim.models.keyedvectors.Vocab at 0x287e3616cc8>,
#  'islem': <gensim.models.keyedvectors.Vocab at 0x287e36168c8>,
#  'app': <gensim.models.keyedvectors.Vocab at 0x287e3616e08>,
#  'yapmadilar,': <gensim.models.keyedvectors.Vocab at 0x287e3616d48>,
#  'yapamadilar.': <gensim.models.keyedvectors.Vocab at 0x287e3616ec8>,
#  'sağ': <gensim.models.keyedvectors.Vocab at 0x287e3616f48>,
#  'aradığınızı': <gensim.models.keyedvectors.Vocab at 0x287e3616d88>,
#  'belirtti': <gensim.models.keyedvectors.Vocab at 0x287e3616e48>,
#  'mesajla.': <gensim.models.keyedvectors.Vocab at 0x287e3616f88>,
#  'i̇yi': <gensim.models.keyedvectors.Vocab at 0x287e3616e88>,
#  'seneler': <gensim.models.keyedvectors.Vocab at 0x287e3616f08>,
#  'diler': <gensim.models.keyedvectors.Vocab at 0x287e3616188>,
#  'sağlık,mutluluk': <gensim.models.keyedvectors.Vocab at 0x287e3616308>,
#  'bol': <gensim.models.keyedvectors.Vocab at 0x287e3616dc8>,
#  'kazançlı': <gensim.models.keyedvectors.Vocab at 0x287e36164c8>,
#  'dilerim.': <gensim.models.keyedvectors.Vocab at 0x287e3616c08>,
#  'bahçeşehir': <gensim.models.keyedvectors.Vocab at 0x287e36166c8>,
#  "üniversitesi'nden": <gensim.models.keyedvectors.Vocab at 0x287e3616c48>,
#  'özel': <gensim.models.keyedvectors.Vocab at 0x287e3616508>,
#  "2012'ye": <gensim.models.keyedvectors.Vocab at 0x287e3616fc8>,
#  'sms': <gensim.models.keyedvectors.Vocab at 0x287e18fafc8>,
#  'hakkinizi': <gensim.models.keyedvectors.Vocab at 0x287dfafa508>,
#  'kullanabilirsin': <gensim.models.keyedvectors.Vocab at 0x287dfafaa48>,
#  'diyen': <gensim.models.keyedvectors.Vocab at 0x287e197e408>,
#  'sevgili': <gensim.models.keyedvectors.Vocab at 0x287dfb31708>,
#  '"allah': <gensim.models.keyedvectors.Vocab at 0x287dfb31248>,
#  'razii': <gensim.models.keyedvectors.Vocab at 0x287dfb318c8>,
#  'olsun,': <gensim.models.keyedvectors.Vocab at 0x287e1a24bc8>,
#  'olmasan': <gensim.models.keyedvectors.Vocab at 0x287dfbf11c8>,
#  'napardim"': <gensim.models.keyedvectors.Vocab at 0x287dfbf1048>,
#  'demek': <gensim.models.keyedvectors.Vocab at 0x287dfbf1108>,
#  'istedim.': <gensim.models.keyedvectors.Vocab at 0x287dfbf1088>,
#  'alabilirim': <gensim.models.keyedvectors.Vocab at 0x287dfbf10c8>,
#  '-,-': <gensim.models.keyedvectors.Vocab at 0x287dfbf1208>,
#  'univ': <gensim.models.keyedvectors.Vocab at 0x287dfbf19c8>,
#  'tesekkurler..': <gensim.models.keyedvectors.Vocab at 0x287dfbf1288>,
#  'türkiye': <gensim.models.keyedvectors.Vocab at 0x287dfbf1388>,
#  'ye': <gensim.models.keyedvectors.Vocab at 0x287dfbf1308>,
#  'deger': <gensim.models.keyedvectors.Vocab at 0x287dfbf1448>,
#  'ceo': <gensim.models.keyedvectors.Vocab at 0x287dfbf13c8>,
#  'sureyya': <gensim.models.keyedvectors.Vocab at 0x287dfbf1508>,
#  'ciliv\'e.."': <gensim.models.keyedvectors.Vocab at 0x287dfbf1488>,
#  'i̇zmir': <gensim.models.keyedvectors.Vocab at 0x287dfbf15c8>,
#  'arena': <gensim.models.keyedvectors.Vocab at 0x287dfbf1548>,
#  'inanilmazdin..tum': <gensim.models.keyedvectors.Vocab at 0x287dfbf1688>,
#  'ekibine': <gensim.models.keyedvectors.Vocab at 0x287dfbf1608>,
#  'sonsuz': <gensim.models.keyedvectors.Vocab at 0x287dfbf1748>,
#  'tesekkurler:)': <gensim.models.keyedvectors.Vocab at 0x287dfbf16c8>,
#  'başka': <gensim.models.keyedvectors.Vocab at 0x287dfbf1808>,
#  'olacaktı': <gensim.models.keyedvectors.Vocab at 0x287dfbf1788>,
#  'yerinde': <gensim.models.keyedvectors.Vocab at 0x287dfbf18c8>,
#  'olsam': <gensim.models.keyedvectors.Vocab at 0x287dfbf1848>,
#  'dakikası': <gensim.models.keyedvectors.Vocab at 0x287dfbf1708>,
#  '5-10': <gensim.models.keyedvectors.Vocab at 0x287dfbf1908>,
#  'liraya': <gensim.models.keyedvectors.Vocab at 0x287dfbf17c8>,
#  'konuştururum': <gensim.models.keyedvectors.Vocab at 0x287dfbf1988>,
#  'saatten': <gensim.models.keyedvectors.Vocab at 0x287dfbf1888>,
#  'murat': <gensim.models.keyedvectors.Vocab at 0x287dfbf1588>,
#  'erkan:': <gensim.models.keyedvectors.Vocab at 0x287dfbf1948>,
#  "''turkcell": <gensim.models.keyedvectors.Vocab at 0x287dfbf1408>,
#  'misyonumuz': <gensim.models.keyedvectors.Vocab at 0x287dfbf1648>,
#  'operatörlerin': <gensim.models.keyedvectors.Vocab at 0x287dfbf12c8>,
#  'operatörü': <gensim.models.keyedvectors.Vocab at 0x287dfbf1a08>,
#  "olmak.''": <gensim.models.keyedvectors.Vocab at 0x287dfbf1ac8>,
#  'kamil': <gensim.models.keyedvectors.Vocab at 0x287dfbf1e88>,
#  'koç': <gensim.models.keyedvectors.Vocab at 0x287dfbf1148>,
#  'un': <gensim.models.keyedvectors.Vocab at 0x287dfbf14c8>,
#  'kornası': <gensim.models.keyedvectors.Vocab at 0x287dfbf1b48>,
#  'olmuş': <gensim.models.keyedvectors.Vocab at 0x287dfbf1a88>,
#  'kutlama': <gensim.models.keyedvectors.Vocab at 0x287dfbf1c48>,
#  "msg'ını": <gensim.models.keyedvectors.Vocab at 0x287dfbf1bc8>,
#  'teşekkürler..': <gensim.models.keyedvectors.Vocab at 0x287dfbf1d08>,
#  'lala': <gensim.models.keyedvectors.Vocab at 0x287dfbf1c88>,
#  'perşembe': <gensim.models.keyedvectors.Vocab at 0x287dfbf1dc8>,
#  'sinema': <gensim.models.keyedvectors.Vocab at 0x287dfbf1c08>,
#  'günleri': <gensim.models.keyedvectors.Vocab at 0x287dfbf1d88>,
#  '....': <gensim.models.keyedvectors.Vocab at 0x287dfbf1cc8>,
#  'sinemada': <gensim.models.keyedvectors.Vocab at 0x287dfbf1e48>,
#  "sherlock'ta": <gensim.models.keyedvectors.Vocab at 0x287dfbf1d48>,
#  'lazım': <gensim.models.keyedvectors.Vocab at 0x287dfbf1188>,
#  'gençler.': <gensim.models.keyedvectors.Vocab at 0x287dfbf1e08>,
#  'el': <gensim.models.keyedvectors.Vocab at 0x287dfbf1348>,
#  'atıverin': <gensim.models.keyedvectors.Vocab at 0x287dfbf1b08>,
#  'hadi.': <gensim.models.keyedvectors.Vocab at 0x287dfbf1a48>,
#  'askim': <gensim.models.keyedvectors.Vocab at 0x287dfbf1ec8>,
#  'nasil': <gensim.models.keyedvectors.Vocab at 0x287dfbf1f08>,
#  'yollicaksin': <gensim.models.keyedvectors.Vocab at 0x287dfbf1248>,
#  'banaaa': <gensim.models.keyedvectors.Vocab at 0x287dfbf1b88>,
#  'alirim': <gensim.models.keyedvectors.Vocab at 0x287dfbf1f48>,
#  'kolay': <gensim.models.keyedvectors.Vocab at 0x287dfbf1f88>,
#  'sagolasin': <gensim.models.keyedvectors.Vocab at 0x287dfbf1fc8>,
#  'öpenlerin': <gensim.models.keyedvectors.Vocab at 0x287dfbda108>,
#  'den': <gensim.models.keyedvectors.Vocab at 0x287dfbda588>,
#  'beles': <gensim.models.keyedvectors.Vocab at 0x287dfbda048>,
#  'gelsin': <gensim.models.keyedvectors.Vocab at 0x287dfbda1c8>,
#  'beğendik': <gensim.models.keyedvectors.Vocab at 0x287dfbda288>,
#  'bide': <gensim.models.keyedvectors.Vocab at 0x287dfbda3c8>,
#  ',twitter': <gensim.models.keyedvectors.Vocab at 0x287dfbda348>,
#  'paketi': <gensim.models.keyedvectors.Vocab at 0x287dfbda488>,
#  'bekliyoruz': <gensim.models.keyedvectors.Vocab at 0x287dfbda408>,
#  'den...sınırsız': <gensim.models.keyedvectors.Vocab at 0x287dfbda2c8>,
#  'twit': <gensim.models.keyedvectors.Vocab at 0x287dfbda4c8>,
#  'iki': <gensim.models.keyedvectors.Vocab at 0x287dfbda388>,
#  'gene': <gensim.models.keyedvectors.Vocab at 0x287dfbda548>,
#  'benimki': <gensim.models.keyedvectors.Vocab at 0x287dfbda448>,
#  'ayda': <gensim.models.keyedvectors.Vocab at 0x287dfbda148>,
#  'gelmişti.turkcell': <gensim.models.keyedvectors.Vocab at 0x287dfbda508>,
#  'sağolsun:d': <gensim.models.keyedvectors.Vocab at 0x287dfbda308>,
#  'off': <gensim.models.keyedvectors.Vocab at 0x287dfbda208>,
#  'ali': <gensim.models.keyedvectors.Vocab at 0x287dfbda188>,
#  'sbh': <gensim.models.keyedvectors.Vocab at 0x287dfbda088>,
#  'güldürdün': <gensim.models.keyedvectors.Vocab at 0x287dfbda5c8>,
#  'art': <gensim.models.keyedvectors.Vocab at 0x287dfbda248>,
#  'ık': <gensim.models.keyedvectors.Vocab at 0x287dfbda648>,
#  'facebooktanda': <gensim.models.keyedvectors.Vocab at 0x287dfbda0c8>,
#  'ilişkisi': <gensim.models.keyedvectors.Vocab at 0x287dfbda6c8>,
#  'war': <gensim.models.keyedvectors.Vocab at 0x287dfbda608>,
#  'yaparsın': <gensim.models.keyedvectors.Vocab at 0x287dfbda748>,
#  '"çekemeyen': <gensim.models.keyedvectors.Vocab at 0x287dfbda788>,
#  'anten': <gensim.models.keyedvectors.Vocab at 0x287dfbda848>,
#  'taksın"': <gensim.models.keyedvectors.Vocab at 0x287dfbda908>,
#  'sticker': <gensim.models.keyedvectors.Vocab at 0x287dfbda9c8>,
#  'dağıtmış,': <gensim.models.keyedvectors.Vocab at 0x287dfbdad08>,
#  'yaptırcam': <gensim.models.keyedvectors.Vocab at 0x287dfbda8c8>,
#  'opuldun': <gensim.models.keyedvectors.Vocab at 0x287dfbda988>,
#  'bebegim': <gensim.models.keyedvectors.Vocab at 0x287dfbda948>,
#  'tebrikler!': <gensim.models.keyedvectors.Vocab at 0x287dfbda688>,
#  'size': <gensim.models.keyedvectors.Vocab at 0x287dfbdaac8>,
#  'ozel': <gensim.models.keyedvectors.Vocab at 0x287dfbdaa08>,
#  'ay': <gensim.models.keyedvectors.Vocab at 0x287dfbdabc8>,
#  'boyunca': <gensim.models.keyedvectors.Vocab at 0x287dfbdac48>,
#  'yurtici': <gensim.models.keyedvectors.Vocab at 0x287dfbdaa88>,
#  '100': <gensim.models.keyedvectors.Vocab at 0x287dfbdac08>,
#  '300': <gensim.models.keyedvectors.Vocab at 0x287dfbdab48>,
#  'kazandiniz.': <gensim.models.keyedvectors.Vocab at 0x287dfbdab88>,
#  'gule': <gensim.models.keyedvectors.Vocab at 0x287dfbda888>,
#  'kullanin!': <gensim.models.keyedvectors.Vocab at 0x287dfbdac88>,
#  'divane': <gensim.models.keyedvectors.Vocab at 0x287dfbdacc8>,
#  'asik': <gensim.models.keyedvectors.Vocab at 0x287dfbdaa48>,
#  'blog': <gensim.models.keyedvectors.Vocab at 0x287dfbdab08>,
#  'odullerinde': <gensim.models.keyedvectors.Vocab at 0x287dfbdae08>,
#  'son': <gensim.models.keyedvectors.Vocab at 0x287dfbdad88>,
#  '10`a': <gensim.models.keyedvectors.Vocab at 0x287dfbdaec8>,
#  'kalmis.': <gensim.models.keyedvectors.Vocab at 0x287dfbdae48>,
#  'destek': <gensim.models.keyedvectors.Vocab at 0x287dfbdaf88>,
#  'veren': <gensim.models.keyedvectors.Vocab at 0x287dfbdad48>,
#  'herkese': <gensim.models.keyedvectors.Vocab at 0x287dfbdadc8>,
#  'tesekkurler...': <gensim.models.keyedvectors.Vocab at 0x287dfbdae88>,
#  'aynen': <gensim.models.keyedvectors.Vocab at 0x287dfbdaf08>,
#  'kanka': <gensim.models.keyedvectors.Vocab at 0x287dfbda7c8>,
#  'iyı': <gensim.models.keyedvectors.Vocab at 0x287dfbdaf48>,
#  'ani': <gensim.models.keyedvectors.Vocab at 0x287dfbdafc8>,
#  'yasarken': <gensim.models.keyedvectors.Vocab at 0x287dfbda808>,
#  'cekemem.': <gensim.models.keyedvectors.Vocab at 0x287dfbda708>,
#  'ihtiyaçlarınızın': <gensim.models.keyedvectors.Vocab at 0x287dfbd2288>,
#  '(dinleme,': <gensim.models.keyedvectors.Vocab at 0x287dfbd2188>,
#  'indirme,': <gensim.models.keyedvectors.Vocab at 0x287dfbd2108>,
#  'keşfetme': <gensim.models.keyedvectors.Vocab at 0x287dfbd2208>,
#  'vb.)': <gensim.models.keyedvectors.Vocab at 0x287dfbd2048>,
#  'kalitesiyle': <gensim.models.keyedvectors.Vocab at 0x287dfbd21c8>,
#  'tek': <gensim.models.keyedvectors.Vocab at 0x287dfbd22c8>,
#  'uygulamada': <gensim.models.keyedvectors.Vocab at 0x287dfbd2388>,
#  'toplanmış': <gensim.models.keyedvectors.Vocab at 0x287dfbd2488>,
#  'olması': <gensim.models.keyedvectors.Vocab at 0x287dfbd2508>,
#  'fena': <gensim.models.keyedvectors.Vocab at 0x287dfbd20c8>,
#  'mı?': <gensim.models.keyedvectors.Vocab at 0x287dfbd2248>,
#  'komedi': <gensim.models.keyedvectors.Vocab at 0x287dfbd2088>,
#  'tweetlerini': <gensim.models.keyedvectors.Vocab at 0x287dfbd23c8>,
#  'sabahtan': <gensim.models.keyedvectors.Vocab at 0x287dfbd2348>,
#  'toplayamadığım': <gensim.models.keyedvectors.Vocab at 0x287dfbd2588>,
#  'odamdan': <gensim.models.keyedvectors.Vocab at 0x287dfbd2448>,
#  'takip': <gensim.models.keyedvectors.Vocab at 0x287dfbd2688>,
#  'ediyorum': <gensim.models.keyedvectors.Vocab at 0x287dfbd25c8>,
#  '140': <gensim.models.keyedvectors.Vocab at 0x287dfbd2748>,
#  'karakteri': <gensim.models.keyedvectors.Vocab at 0x287dfbd27c8>,
#  'güzel.': <gensim.models.keyedvectors.Vocab at 0x287dfbd2148>,
#  '#pazarlamakonferansi': <gensim.models.keyedvectors.Vocab at 0x287dfbd2408>,
#  'akademinin': <gensim.models.keyedvectors.Vocab at 0x287dfbd2308>,
#  'duzenledigi': <gensim.models.keyedvectors.Vocab at 0x287dfbd24c8>,
#  'konferansin': <gensim.models.keyedvectors.Vocab at 0x287dfbd2648>,
#  'baslamasini': <gensim.models.keyedvectors.Vocab at 0x287dfbd2548>,
#  'zaten': <gensim.models.keyedvectors.Vocab at 0x287dfbd2608>,
#  'baktım.': <gensim.models.keyedvectors.Vocab at 0x287dfbd2788>,
#  'vazgeçmem': <gensim.models.keyedvectors.Vocab at 0x287dfbd2808>,
#  'türlü': <gensim.models.keyedvectors.Vocab at 0x287dfbd2f08>,
#  'kaliteli': <gensim.models.keyedvectors.Vocab at 0x287dfbd2888>,
# ...
#  'gelirler': <gensim.models.keyedvectors.Vocab at 0x287dfbd2ec8>,
#  'demişti.': <gensim.models.keyedvectors.Vocab at 0x287dfbd2dc8>,
#  'önemli': <gensim.models.keyedvectors.Vocab at 0x287dfbd2ac8>,
#  'mutluluğu.': <gensim.models.keyedvectors.Vocab at 0x287dfbd2e88>,
#  'kafama': <gensim.models.keyedvectors.Vocab at 0x287dfbd2948>,
#  'takilan': <gensim.models.keyedvectors.Vocab at 0x287dfbd28c8>,
#  'konu': <gensim.models.keyedvectors.Vocab at 0x287dfbd2708>,
#  'gsm': <gensim.models.keyedvectors.Vocab at 0x287dfbd2fc8>,
#  'operatorlerinin': <gensim.models.keyedvectors.Vocab at 0x287dfbd2a08>,
#  'mobil': <gensim.models.keyedvectors.Vocab at 0x287dfbd2f88>,
#  'site': <gensim.models.keyedvectors.Vocab at 0x287dfbd2848>,
#  'destegi': <gensim.models.keyedvectors.Vocab at 0x287dfbd26c8>,
#  'uygulamalarinin': <gensim.models.keyedvectors.Vocab at 0x287dfbd2f48>,
#  'olmamasi.': <gensim.models.keyedvectors.Vocab at 0x287dfbd2b88>,
#  'istisna': <gensim.models.keyedvectors.Vocab at 0x287dfb7e348>,
#  'tabi': <gensim.models.keyedvectors.Vocab at 0x287dfb7e0c8>,
#  'dogum': <gensim.models.keyedvectors.Vocab at 0x287dfb7e1c8>,
#  'gunu': <gensim.models.keyedvectors.Vocab at 0x287dfb7e208>,
#  'pastasi': <gensim.models.keyedvectors.Vocab at 0x287dfb7e088>,
#  'tesekkurler.': <gensim.models.keyedvectors.Vocab at 0x287dfb7e2c8>,
#  'simartiyosun': <gensim.models.keyedvectors.Vocab at 0x287dfb7e508>,
#  'kami̇l': <gensim.models.keyedvectors.Vocab at 0x287dfb7e248>,
#  "koç'tan": <gensim.models.keyedvectors.Vocab at 0x287dfb7e388>,
#  'kampanyasi': <gensim.models.keyedvectors.Vocab at 0x287dfb7e408>,
#  "koridorda''turkcell": <gensim.models.keyedvectors.Vocab at 0x287dfb7e048>,
#  'sesimden': <gensim.models.keyedvectors.Vocab at 0x287dfb7e4c8>,
#  "tanir''": <gensim.models.keyedvectors.Vocab at 0x287dfb7e548>,
#  'bagirken': <gensim.models.keyedvectors.Vocab at 0x287dfb7e488>,
#  'buldum.bir': <gensim.models.keyedvectors.Vocab at 0x287dfb7e608>,
#  'insan': <gensim.models.keyedvectors.Vocab at 0x287dfb7e688>,
#  'neler': <gensim.models.keyedvectors.Vocab at 0x287dfb7e448>,
#  'yapiyo': <gensim.models.keyedvectors.Vocab at 0x287dfb7e188>,
#  '*hayat': <gensim.models.keyedvectors.Vocab at 0x287dfb7e3c8>,
#  'paylaşinca': <gensim.models.keyedvectors.Vocab at 0x287dfb7e288>,
#  'güzel!!!': <gensim.models.keyedvectors.Vocab at 0x287dfb7e148>,
#  '7.30dan': <gensim.models.keyedvectors.Vocab at 0x287dfb7ecc8>,
#  'tekrar': <gensim.models.keyedvectors.Vocab at 0x287dfb7e5c8>,
#  "turkcell'm": <gensim.models.keyedvectors.Vocab at 0x287dfb7e748>,
#  'bilginizee': <gensim.models.keyedvectors.Vocab at 0x287dfb7e6c8>,
#  'nihayet': <gensim.models.keyedvectors.Vocab at 0x287dfb7e808>,
#  'eve': <gensim.models.keyedvectors.Vocab at 0x287dfb7e788>,
#  'geldi.': <gensim.models.keyedvectors.Vocab at 0x287dfb7e8c8>,
#  'superonline,': <gensim.models.keyedvectors.Vocab at 0x287dfb7e848>,
#  "karamehmet'in": <gensim.models.keyedvectors.Vocab at 0x287dfb7e988>,
#  'yıllar': <gensim.models.keyedvectors.Vocab at 0x287dfb7e908>,
#  'önce': <gensim.models.keyedvectors.Vocab at 0x287dfb7ea48>,
#  'döşediği': <gensim.models.keyedvectors.Vocab at 0x287dfb7e9c8>,
#  'ağı': <gensim.models.keyedvectors.Vocab at 0x287dfb7eb08>,
#  'engellemeler': <gensim.models.keyedvectors.Vocab at 0x287dfb7ea88>,
#  'yüzünden': <gensim.models.keyedvectors.Vocab at 0x287dfb7ebc8>,
#  'anca': <gensim.models.keyedvectors.Vocab at 0x287dfb7eb48>,
#  'devreye': <gensim.models.keyedvectors.Vocab at 0x287dfb7ea08>,
#  'sokabildi.': <gensim.models.keyedvectors.Vocab at 0x287dfb7ec08>,
#  'aramız': <gensim.models.keyedvectors.Vocab at 0x287dfb7eac8>,
#  'olmasa': <gensim.models.keyedvectors.Vocab at 0x287dfb7ec88>,
#  'hediyeler': <gensim.models.keyedvectors.Vocab at 0x287dfb7eb88>,
#  'verdikce': <gensim.models.keyedvectors.Vocab at 0x287dfb7e888>,
#  'gözüme': <gensim.models.keyedvectors.Vocab at 0x287dfb7ec48>,
#  'giriyorlar': <gensim.models.keyedvectors.Vocab at 0x287dfb7e708>,
#  'cüzdanı': <gensim.models.keyedvectors.Vocab at 0x287dfb7e948>,
#  'evde': <gensim.models.keyedvectors.Vocab at 0x287dfb7e588>,
#  'unuttum': <gensim.models.keyedvectors.Vocab at 0x287dfb7e7c8>,
#  'imza': <gensim.models.keyedvectors.Vocab at 0x287dfb7e108>,
#  'sayesinde': <gensim.models.keyedvectors.Vocab at 0x287dfb7e648>,
#  "garanti'den": <gensim.models.keyedvectors.Vocab at 0x287dfb7ed48>,
#  'para': <gensim.models.keyedvectors.Vocab at 0x287dfb7e308>,
#  'çekip': <gensim.models.keyedvectors.Vocab at 0x287dfb7edc8>,
#  'gunumu': <gensim.models.keyedvectors.Vocab at 0x287dfb7ed08>,
#  'sorunsuz': <gensim.models.keyedvectors.Vocab at 0x287dfb7ee48>,
#  'götürüyorum': <gensim.models.keyedvectors.Vocab at 0x287dfb7ed88>,
#  'zekice': <gensim.models.keyedvectors.Vocab at 0x287dfb7eec8>,
#  '"1': <gensim.models.keyedvectors.Vocab at 0x287dfb7ef08>,
#  'vizyone': <gensim.models.keyedvectors.Vocab at 0x287dfb7ef88>,
#  'girerken,': <gensim.models.keyedvectors.Vocab at 0x287dfb7ee08>,
#  'milyon': <gensim.models.keyedvectors.Vocab at 0x287dfb7ee88>,
#  'kişi': <gensim.models.keyedvectors.Vocab at 0x287dfb7ef48>,
#  'var."': <gensim.models.keyedvectors.Vocab at 0x287dfb7efc8>,
#  'ahaha': <gensim.models.keyedvectors.Vocab at 0x287dfb70048>,
#  'güzel:)': <gensim.models.keyedvectors.Vocab at 0x287dfb70148>,
#  'faturalı': <gensim.models.keyedvectors.Vocab at 0x287dfb70108>,
#  'hatlarda': <gensim.models.keyedvectors.Vocab at 0x287dfb70288>,
#  'esnek': <gensim.models.keyedvectors.Vocab at 0x287dfb700c8>,
#  'avantajların': <gensim.models.keyedvectors.Vocab at 0x287dfb701c8>,
#  'olmasını': <gensim.models.keyedvectors.Vocab at 0x287dfb70208>,
#  'başarılarınızın': <gensim.models.keyedvectors.Vocab at 0x287dfb70088>,
#  'devamını': <gensim.models.keyedvectors.Vocab at 0x287dfb702c8>,
#  'dilerim': <gensim.models.keyedvectors.Vocab at 0x287dfb70308>,
#  'hoşçakalın..': <gensim.models.keyedvectors.Vocab at 0x287dfb70408>,
#  'telefonda': <gensim.models.keyedvectors.Vocab at 0x287dfb704c8>,
#  "'a": <gensim.models.keyedvectors.Vocab at 0x287dfb709c8>,
#  'transfer': <gensim.models.keyedvectors.Vocab at 0x287dfb70448>,
#  'oldum.20': <gensim.models.keyedvectors.Vocab at 0x287dfb70488>,
#  'mgpt': <gensim.models.keyedvectors.Vocab at 0x287dfb70388>,
#  'sınırsız': <gensim.models.keyedvectors.Vocab at 0x287dfb705c8>,
#  '44': <gensim.models.keyedvectors.Vocab at 0x287dfb70508>,
#  'vergiler': <gensim.models.keyedvectors.Vocab at 0x287dfb70688>,
#  'dahil': <gensim.models.keyedvectors.Vocab at 0x287dfb70608>,
#  '7,5': <gensim.models.keyedvectors.Vocab at 0x287dfb70748>,
#  'kr': <gensim.models.keyedvectors.Vocab at 0x287dfb706c8>,
#  'ücret': <gensim.models.keyedvectors.Vocab at 0x287dfb70808>,
#  'şener': <gensim.models.keyedvectors.Vocab at 0x287dfb70788>,
#  'şen': <gensim.models.keyedvectors.Vocab at 0x287dfb708c8>,
#  'ceza': <gensim.models.keyedvectors.Vocab at 0x287dfb70848>,
#  'olgun': <gensim.models.keyedvectors.Vocab at 0x287dfb70988>,
#  'şi̇mşek': <gensim.models.keyedvectors.Vocab at 0x287dfb70188>,
#  'binnur': <gensim.models.keyedvectors.Vocab at 0x287dfb70348>,
#  'kaya': <gensim.models.keyedvectors.Vocab at 0x287dfb70d08>,
#  'söylüyorum': <gensim.models.keyedvectors.Vocab at 0x287dfb703c8>,
#  'firmanın': <gensim.models.keyedvectors.Vocab at 0x287dfb70948>,
#  'reklamına': <gensim.models.keyedvectors.Vocab at 0x287dfb70648>,
#  'çıkmayın': <gensim.models.keyedvectors.Vocab at 0x287dfb70588>,
#  'yaşasin': <gensim.models.keyedvectors.Vocab at 0x287dfb70a88>,
#  'biliriz': <gensim.models.keyedvectors.Vocab at 0x287dfb70248>,
#  'çileyi': <gensim.models.keyedvectors.Vocab at 0x287dfb70b48>,
#  'zamanında': <gensim.models.keyedvectors.Vocab at 0x287dfb70ac8>,
#  'çektik': <gensim.models.keyedvectors.Vocab at 0x287dfb70c08>,
#  'sizede': <gensim.models.keyedvectors.Vocab at 0x287dfb70b88>,
#  'alalım': <gensim.models.keyedvectors.Vocab at 0x287dfb70a08>,
#  'phone': <gensim.models.keyedvectors.Vocab at 0x287dfb70c48>,
#  'application..': <gensim.models.keyedvectors.Vocab at 0x287dfb70b08>,
#  'mutlaka': <gensim.models.keyedvectors.Vocab at 0x287dfb70cc8>,
#  'deneyin...': <gensim.models.keyedvectors.Vocab at 0x287dfb70bc8>,
#  '1,5': <gensim.models.keyedvectors.Vocab at 0x287dfb70708>,
#  'süper..': <gensim.models.keyedvectors.Vocab at 0x287dfb70c88>,
#  'normalde': <gensim.models.keyedvectors.Vocab at 0x287dfb70888>,
#  'atatürkden': <gensim.models.keyedvectors.Vocab at 0x287dfb70548>,
#  'gidiyorum': <gensim.models.keyedvectors.Vocab at 0x287dfb70a48>,
#  'sunexpress': <gensim.models.keyedvectors.Vocab at 0x287dfb707c8>,
#  'kampanyasından': <gensim.models.keyedvectors.Vocab at 0x287dfb70d88>,
#  'yararlandım': <gensim.models.keyedvectors.Vocab at 0x287dfb70908>,
#  'ucuza': <gensim.models.keyedvectors.Vocab at 0x287dfb70e08>,
#  'geldi': <gensim.models.keyedvectors.Vocab at 0x287dfb70d48>,
#  'baya': <gensim.models.keyedvectors.Vocab at 0x287dfb70e88>,
#  'toplu': <gensim.models.keyedvectors.Vocab at 0x287dfb70ec8>,
#  'tasima': <gensim.models.keyedvectors.Vocab at 0x287dfb70f08>,
#  'aracinda': <gensim.models.keyedvectors.Vocab at 0x287dfb70f88>,
#  '"turkcell': <gensim.models.keyedvectors.Vocab at 0x287dfb70fc8>,
#  'bemi': <gensim.models.keyedvectors.Vocab at 0x287dfb70dc8>,
#  'tanır"': <gensim.models.keyedvectors.Vocab at 0x287dfb70f48>,
#  'cilginliginida': <gensim.models.keyedvectors.Vocab at 0x287dfb70e48>,
#  'yapti': <gensim.models.keyedvectors.Vocab at 0x287dfbc4148>,
#  '#pes': <gensim.models.keyedvectors.Vocab at 0x287dfbc4048>,
#  'sahan': <gensim.models.keyedvectors.Vocab at 0x287dfbc4248>,
#  'oynadığı': <gensim.models.keyedvectors.Vocab at 0x287dfbc4308>,
#  'güldüm': <gensim.models.keyedvectors.Vocab at 0x287dfbc4688>,
#  'bsbdbdhdfnbzhgczzvzvzjddhdjdjzg': <gensim.models.keyedvectors.Vocab at 0x287dfbc4448>,
#  'yöne': <gensim.models.keyedvectors.Vocab at 0x287dfbc4388>,
#  '12': <gensim.models.keyedvectors.Vocab at 0x287dfbc4188>,
#  'bakınız': <gensim.models.keyedvectors.Vocab at 0x287dfbc4408>,
#  "i̇phone'un": <gensim.models.keyedvectors.Vocab at 0x287dfbc44c8>,
#  'modeli': <gensim.models.keyedvectors.Vocab at 0x287dfbc43c8>,
#  'i̇phone': <gensim.models.keyedvectors.Vocab at 0x287dfbc4588>,
#  '4s,': <gensim.models.keyedvectors.Vocab at 0x287dfbc4508>,
#  'satışa': <gensim.models.keyedvectors.Vocab at 0x287dfbc4348>,
#  'sunulacak.': <gensim.models.keyedvectors.Vocab at 0x287dfbc45c8>,
#  'divandan': <gensim.models.keyedvectors.Vocab at 0x287dfbc4488>,
#  'gondermek!': <gensim.models.keyedvectors.Vocab at 0x287dfbc4548>,
#  'valla': <gensim.models.keyedvectors.Vocab at 0x287dfbc4608>,
#  'sasirdim': <gensim.models.keyedvectors.Vocab at 0x287dfbc4208>,
#  'tesekkurler': <gensim.models.keyedvectors.Vocab at 0x287dfbc4648>,
#  ':):)': <gensim.models.keyedvectors.Vocab at 0x287dfbc4108>,
#  'adam': <gensim.models.keyedvectors.Vocab at 0x287dfbc41c8>,
#  'vardı': <gensim.models.keyedvectors.Vocab at 0x287dfbc40c8>,
#  'canı': <gensim.models.keyedvectors.Vocab at 0x287dfbc4088>,
#  'sıkılıyordu.': <gensim.models.keyedvectors.Vocab at 0x287dfbc46c8>,
#  'izledi': <gensim.models.keyedvectors.Vocab at 0x287dfbc4708>,
#  'can': <gensim.models.keyedvectors.Vocab at 0x287dfbc4cc8>,
#  'sıkıntısı': <gensim.models.keyedvectors.Vocab at 0x287dfbc4788>,
#  'gitti.': <gensim.models.keyedvectors.Vocab at 0x287dfbc4888>,
#  'eski': <gensim.models.keyedvectors.Vocab at 0x287dfbc4808>,
#  'hey': <gensim.models.keyedvectors.Vocab at 0x287dfbc4948>,
#  'gidi': <gensim.models.keyedvectors.Vocab at 0x287dfbc48c8>,
#  'günler': <gensim.models.keyedvectors.Vocab at 0x287dfbc4a08>,
#  'haneye': <gensim.models.keyedvectors.Vocab at 0x287dfbc4988>,
#  'i̇nterneti': <gensim.models.keyedvectors.Vocab at 0x287dfbc4ac8>,
#  'taşıdı,': <gensim.models.keyedvectors.Vocab at 0x287dfbc4a48>,
#  'taşımada': <gensim.models.keyedvectors.Vocab at 0x287dfbc4b88>,
#  'lider': <gensim.models.keyedvectors.Vocab at 0x287dfbc4c08>,
#  'oldu.': <gensim.models.keyedvectors.Vocab at 0x287dfbc4a88>,
#  '2012de': <gensim.models.keyedvectors.Vocab at 0x287dfbc4bc8>,
#  'sevgililerimi': <gensim.models.keyedvectors.Vocab at 0x287dfbc4b08>,
#  'buldum:': <gensim.models.keyedvectors.Vocab at 0x287dfbc4c88>,
#  '(galp)': <gensim.models.keyedvectors.Vocab at 0x287dfbc49c8>,
#  'wikipedia': <gensim.models.keyedvectors.Vocab at 0x287dfbc4848>,
#  'google': <gensim.models.keyedvectors.Vocab at 0x287dfbc4288>,
#  '#finallergeliyorhaci': <gensim.models.keyedvectors.Vocab at 0x287dfbc4d48>,
#  '2': <gensim.models.keyedvectors.Vocab at 0x287dfbc42c8>,
#  'gundur': <gensim.models.keyedvectors.Vocab at 0x287dfbc4e08>,
#  'yayını': <gensim.models.keyedvectors.Vocab at 0x287dfbc4d88>,
#  ':(': <gensim.models.keyedvectors.Vocab at 0x287dfbc4ec8>,
#  'yapardım': <gensim.models.keyedvectors.Vocab at 0x287dfbc4f48>,
#  ':/': <gensim.models.keyedvectors.Vocab at 0x287dfbc4e88>,
#  '\x1a\x1a\x1a': <gensim.models.keyedvectors.Vocab at 0x287dfbc4d08>,
#  'dan': <gensim.models.keyedvectors.Vocab at 0x287dfbc4dc8>,
#  '250': <gensim.models.keyedvectors.Vocab at 0x287dfbc4e48>,
#  'fatura': <gensim.models.keyedvectors.Vocab at 0x287dfbc47c8>,
#  'gelcek': <gensim.models.keyedvectors.Vocab at 0x287dfbc4b48>,
#  ':((': <gensim.models.keyedvectors.Vocab at 0x287dfbc4c48>,
#  'geri': <gensim.models.keyedvectors.Vocab at 0x287dfbc4f08>,
#  'dönmeyi': <gensim.models.keyedvectors.Vocab at 0x287dfbc4f88>,
#  'düşünüyorum': <gensim.models.keyedvectors.Vocab at 0x287dfbc4fc8>,
#  'mesela': <gensim.models.keyedvectors.Vocab at 0x287dfbc4908>,
#  'onda': <gensim.models.keyedvectors.Vocab at 0x287dfbc4748>,
#  'soru': <gensim.models.keyedvectors.Vocab at 0x287dfbbb208>,
#  'ttnet': <gensim.models.keyedvectors.Vocab at 0x287dfbbb048>,
#  'insanı': <gensim.models.keyedvectors.Vocab at 0x287dfbbb0c8>,
#  'baymıyor': <gensim.models.keyedvectors.Vocab at 0x287dfbbb188>,
#  'ah': <gensim.models.keyedvectors.Vocab at 0x287dfbbb108>,
#  'hemende': <gensim.models.keyedvectors.Vocab at 0x287dfbbb088>,
#  'duydu': <gensim.models.keyedvectors.Vocab at 0x287dfbbb288>,
#  'sesimiii:))': <gensim.models.keyedvectors.Vocab at 0x287dfbbb348>,
#  'yaptığın': <gensim.models.keyedvectors.Vocab at 0x287dfbbb408>,
#  'haksızlığı': <gensim.models.keyedvectors.Vocab at 0x287dfbbb388>,
#  'unutturmayacağım..hani': <gensim.models.keyedvectors.Vocab at 0x287dfbbb2c8>,
#  '150': <gensim.models.keyedvectors.Vocab at 0x287dfbbb948>,
#  'kampanyası..artık': <gensim.models.keyedvectors.Vocab at 0x287dfbbb4c8>,
#  'yaşasın': <gensim.models.keyedvectors.Vocab at 0x287dfbbb448>,
#  'turkcell.seni': <gensim.models.keyedvectors.Vocab at 0x287dfbbb148>,
#  'terkediyom': <gensim.models.keyedvectors.Vocab at 0x287dfbbb588>,
#  'avea..': <gensim.models.keyedvectors.Vocab at 0x287dfbbb488>,
#  'üzülme': <gensim.models.keyedvectors.Vocab at 0x287dfbbb648>,
#  'tabiki': <gensim.models.keyedvectors.Vocab at 0x287dfbbb5c8>,
#  'bizim': <gensim.models.keyedvectors.Vocab at 0x287dfbbb708>,
#  'malum': <gensim.models.keyedvectors.Vocab at 0x287dfbbb688>,
#  '#gnctrkcll': <gensim.models.keyedvectors.Vocab at 0x287dfbbb7c8>,
#  'cuma': <gensim.models.keyedvectors.Vocab at 0x287dfbbb848>,
#  'sabahı': <gensim.models.keyedvectors.Vocab at 0x287dfbbb788>,
#  'hallederiz': <gensim.models.keyedvectors.Vocab at 0x287dfbbb6c8>,
#  '#yeniyildanistegim': <gensim.models.keyedvectors.Vocab at 0x287dfbbb888>,
#  'paylaşmayı': <gensim.models.keyedvectors.Vocab at 0x287dfbbbbc8>,
#  'bilen': <gensim.models.keyedvectors.Vocab at 0x287dfbbb308>,
#  'dünya...': <gensim.models.keyedvectors.Vocab at 0x287dfbbb608>,
#  '#turkcellfestival': <gensim.models.keyedvectors.Vocab at 0x287dfbbb248>,
#  'konser': <gensim.models.keyedvectors.Vocab at 0x287dfbbb1c8>,
#  'model': <gensim.models.keyedvectors.Vocab at 0x287dfbbb9c8>,
#  'seçimi': <gensim.models.keyedvectors.Vocab at 0x287dfbbba48>,
#  'olmuş!!!': <gensim.models.keyedvectors.Vocab at 0x287dfbbb988>,
#  'şarkı': <gensim.models.keyedvectors.Vocab at 0x287dfbbbb08>,
#  'sözleri': <gensim.models.keyedvectors.Vocab at 0x287dfbbb508>,
#  'sound': <gensim.models.keyedvectors.Vocab at 0x287dfbbba08>,
#  'iyi.': <gensim.models.keyedvectors.Vocab at 0x287dfbbbb48>,
#  'devam': <gensim.models.keyedvectors.Vocab at 0x287dfbbbec8>,
#  'model!': <gensim.models.keyedvectors.Vocab at 0x287dfbbb3c8>,
#  'aradiigimda': <gensim.models.keyedvectors.Vocab at 0x287dfbbb808>,
#  'musteri': <gensim.models.keyedvectors.Vocab at 0x287dfbbbc08>,
#  ...}

# %%
# Making histogram for no of words in news shows that all news article are under 20 words.
# Lets keep each news small and truncate all news to 20 while tokenizing
plt.hist([len(j) for j in words], bins = 100)
plt.show()

# %%
tokenizer = text.Tokenizer(num_words=35000)
tokenizer.fit_on_texts(words)
tokenized_train = tokenizer.texts_to_sequences(words)
x = sequence.pad_sequences(tokenized_train, maxlen = 20)

# %%
# Adding 1 because of reserved 0 index
# Embedding Layer creates one more vector for "UNKNOWN" words, or padded words (0s). This Vector is filled with zeros.
# Thus our vocab size inceeases by 1
vocab_size = len(tokenizer.word_index) + 1

# %%
vocab_size
# Out:
# 14333

# %%
# Function to create weight matrix from word2vec gensim model
def get_weight_matrix(model, vocab):
    # total vocabulary size plus 0 for unknown words
    vocab_size = len(vocab) + 1
    # define weight matrix dimensions with all 0
    weight_matrix = np.zeros((vocab_size, EMBEDDING_DIM))
    # step vocab, store vectors using the Tokenizer's integer mapping
    for word, i in vocab.items():
        weight_matrix[i] = model[word]
    return weight_matrix

# %%
#Getting embedding vectors from word2vec and usings it as weights of non-trainable keras embedding layer
embedding_vectors = get_weight_matrix(w2v_model, tokenizer.word_index)
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   if __name__ == '__main__':

# %%
#TRAINING WORD2VEC MODEL

# %%
#Defining Neural Network
model = Sequential()
#Non-trainable embeddidng layer
model.add(Embedding(vocab_size, output_dim=EMBEDDING_DIM, weights=[embedding_vectors], input_length=20, trainable=True))
#LSTM 
model.add(LSTM(units=128))
model.add(Dropout(0.4))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc'])

del embedding_vectors

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 20, 100)           1433300
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 128)               117248
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 1,550,677
# Trainable params: 1,550,677
# Non-trainable params: 0
# _________________________________________________________________

# %%
x_train, x_test, y_train, y_test = train_test_split(x, df.durum , test_size = 0.3 , random_state = 0)

# %%
history = model.fit(x_train, y_train, batch_size = 128 , validation_data = (x_test,y_test) , epochs = 5)
# Out:
# D:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\framework\indexed_slices.py:433: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 2099 samples, validate on 900 samples
# Epoch 1/5
# 2099/2099 [==============================] - 1s 697us/step - loss: -2.0133 - acc: 0.2415 - val_loss: -10.3451 - val_acc: 0.2656
# Epoch 2/5
# 2099/2099 [==============================] - 1s 445us/step - loss: -14.6197 - acc: 0.2463 - val_loss: -17.1765 - val_acc: 0.2656
# Epoch 3/5
# 2099/2099 [==============================] - 1s 452us/step - loss: -19.5673 - acc: 0.2463 - val_loss: -20.4100 - val_acc: 0.2656
# Epoch 4/5
# 2099/2099 [==============================] - 1s 457us/step - loss: -22.7020 - acc: 0.2463 - val_loss: -23.1819 - val_acc: 0.2656
# Epoch 5/5
# 2099/2099 [==============================] - 1s 432us/step - loss: -25.6406 - acc: 0.2463 - val_loss: -25.8223 - val_acc: 0.2656

# %%
print("Accuracy of the model on Training Data is - " , model.evaluate(x_train,y_train)[1]*100)
print("Accuracy of the model on Testing Data is - " , model.evaluate(x_test,y_test)[1]*100)
# Out:
# 2099/2099 [==============================] - 0s 135us/step
# Accuracy of the model on Training Data is -  24.630776047706604
# 900/900 [==============================] - 0s 125us/step
# Accuracy of the model on Testing Data is -  26.555556058883667

# %%
#ANALYSIS AFTER TRAINING OF WORD2VEC MODEL

# %%
epochs = [i for i in range(5)]
fig , ax = plt.subplots(1,2)
train_acc = history.history['acc']
train_loss = history.history['loss']
val_acc = history.history['val_acc']
val_loss = history.history['val_loss']
fig.set_size_inches(20,10)

ax[0].plot(epochs , train_acc , 'go-' , label = 'Training Accuracy')
ax[0].plot(epochs , val_acc , 'ro-' , label = 'Testing Accuracy')
ax[0].set_title('Training & Testing Accuracy')
ax[0].legend()
ax[0].set_xlabel("Epochs")
ax[0].set_ylabel("Accuracy")

ax[1].plot(epochs , train_loss , 'go-' , label = 'Training Loss')
ax[1].plot(epochs , val_loss , 'ro-' , label = 'Testing Loss')
ax[1].set_title('Training & Testing Loss')
ax[1].legend()
ax[1].set_xlabel("Epochs")
ax[1].set_ylabel("Loss")
plt.show()

# %%
pred = model.predict_classes(x_test)
pred[:5]
# Out:
# array([[1],
#        [1],
#        [1],
#        [1],
#        [1]])

# %%
cm = confusion_matrix(y_test,pred)
cm
# Out:
# array([[239,   0,   0],
#        [393,   0,   0],
#        [268,   0,   0]], dtype=int64)

# %%
cm = pd.DataFrame(cm , index = ['Not Sarcastic','Sarcastic','amam'] , columns = ['Not Sarcastic','Sarcastic','amam'])
plt.figure(figsize = (10,10))
sns.heatmap(cm,cmap= "Blues", linecolor = 'black' , linewidth = 1 , annot = True, fmt='' , xticklabels = ['Not Sarcastic','Sarcastic','amam'] , yticklabels = ['Not Sarcastic','Sarcastic','amam'])
